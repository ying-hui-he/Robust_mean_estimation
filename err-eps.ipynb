# %%
import numpy as np
import scipy
import robust_mean_estimate as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'Arial'

# %%
"loss vs eps -- Pareto -- dense biased -- set data -- inf"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 2.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Top_K_GD, rl.Full_Filter]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename = 'data/error-vs-eps-Pareto-full-inf-test.pkl'
data_eps = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
data_eps.setdata_tofile(filename = inputfilename, xvar_name = 'eps', trials = trials, xs = xs)

# %%
"loss vs eps -- Pareto -- dense biased -- plot -- inf"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 2.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.GDAlgs_npre, rl.Top_K, rl.Top_K_GD, rl.Full_Filter, rl.RME_sp]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/error-vs-eps-Pareto-full-inf-test.pkl'
outputfilename = 'figs/loss-vs-eps-Pareto-full-inf-test.pdf'

title = 'Pareto'
xlabel = '$\epsilon$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- Pareto -- dense biased -- set data"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename = 'data/error-vs-eps-Pareto-full.pkl'
data_eps = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
data_eps.setdata_tofile(filename = inputfilename, xvar_name = 'eps', trials = trials, xs = xs)

# %%
"loss vs eps -- Pareto -- dense biased -- plot"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/error-vs-eps-Pareto-full.pkl'
outputfilename = 'figs/loss-vs-eps-Pareto-full.pdf'

title = 'Pareto'
xlabel = '$\epsilon$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- Fisk -- dense biased -- set data -- inf"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 2.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Top_K_GD, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename = 'data/error-vs-eps-Fisk-full-inf-test.pkl'
data_eps = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
data_eps.setdata_tofile(filename = inputfilename, xvar_name = 'eps', trials = trials, xs = xs)

# %%
"loss vs eps -- Fisk -- dense biased -- plot -- inf"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 2.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Top_K_GD, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/error-vs-eps-Fisk-full-inf-test.pkl'
outputfilename = 'figs/loss-vs-eps-Fisk-full-inf-test.pdf'

title = 'Fisk'
xlabel = '$\epsilon$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- Fisk -- dense biased -- set data"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename = 'data/error-vs-eps-Fisk-full.pkl'
data_eps = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
data_eps.setdata_tofile(filename = inputfilename, xvar_name = 'eps', trials = trials, xs = xs)

# %%
"loss vs eps -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/error-vs-eps-Fisk-full.pkl'
outputfilename = 'figs/loss-vs-eps-Fisk-full.pdf'

title = 'Fisk'
xlabel = '$\epsilon$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el208771404423568909288208900638"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el208771404423568909288208900638", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el20877140442356890928", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
# ...

# %%
"loss vs eps -- T -- dense biased -- set data -- inf"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 2.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Top_K_GD, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename = 'data/error-vs-eps-T-full-inf-test.pkl'
data_eps = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
data_eps.setdata_tofile(filename = inputfilename, xvar_name = 'eps', trials = trials, xs = xs)

# %%
"loss vs eps -- T -- dense biased -- plot -- inf"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 2.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Top_K_GD, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/error-vs-eps-T-full-inf-test.pkl'
outputfilename = 'figs/loss-vs-eps-T-full-inf-test.pdf'

title = 'T'
xlabel = '$\epsilon$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el208771404418204929446009702544"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el208771404418204929446009702544", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el20877140441820492944", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
# ...

# %%
"loss vs eps -- T -- dense biased -- set data"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename = 'data/error-vs-eps-T-full.pkl'
data_eps = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
data_eps.setdata_tofile(filename = inputfilename, xvar_name = 'eps', trials = trials, xs = xs)

# %%
"loss vs eps -- T -- dense biased -- plot"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/error-vs-eps-T-full.pkl'
outputfilename = 'figs/loss-vs-eps-T-full.pdf'

title = 'T'
xlabel = '$\epsilon$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el208771404418192768649398479752"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el208771404418192768649398479752", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el20877140441819276864", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
# ...

# %%
"loss vs eps -- Lognormal -- dense biased -- set data"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename = 'data/error-vs-eps-Lognormal-full.pkl'
data_eps = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
data_eps.setdata_tofile(filename = inputfilename, xvar_name = 'eps', trials = trials, xs = xs)

# %%
"loss vs eps -- Lognormal -- dense biased -- plot"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/error-vs-eps-Lognormal-full.pkl'
outputfilename = 'figs/loss-vs-eps-Lognormal-full.pdf'

title = 'Lognormal'
xlabel = '$\epsilon$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- Gaussian -- dense biased -- set data"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.GaussianModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename = 'data/error-vs-eps-Gaussian-full.pkl'
data_eps = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
data_eps.setdata_tofile(filename = inputfilename, xvar_name = 'eps', trials = trials, xs = xs)

# %%
"loss vs eps -- Gaussian -- dense biased -- plot"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 3.1
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.GaussianModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/error-vs-eps-Gaussian-full.pkl'
outputfilename = 'figs/loss-vs-eps-Gaussian-full.pdf'

title = 'Gaussian'
xlabel = '$\epsilon$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- all three -- plot"

il.reload(rl)

trials = 10

d, k, m, param = 100, 4, 600, 2
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Top_K_GD, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename1 = 'data/error-vs-eps-Fisk-full-inf-test.pkl'
inputfilename2 = 'data/error-vs-eps-Pareto-full-inf-test.pkl'
inputfilename3 = 'data/error-vs-eps-T-full-inf-test.pkl'
outputfilename = 'figs/appendix/error-eps-3-inf.pdf'

title = ['Fisk ($c=2$)', 'Pareto ($b=2$)', "Student $t$ ($\\nu=2$)"]
xlabel = ['$\\epsilon$', '$\\epsilon$', '$\\epsilon$']
ylabel = '$\\ell_2$ error'
xlim = (0.01, 0.2)

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_3_fromfile(outputfilename = outputfilename, filename1 = inputfilename1, filename2 = inputfilename2, filename3 = inputfilename3, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname, xlim=xlim)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el208771404428836336484942496607"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el208771404428836336484942496607", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el20877140442883633648", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
# ...
