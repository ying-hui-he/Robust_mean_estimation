# %%
import numpy as np
import scipy
import robust_mean_estimate as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'Arial'

# %%
"loss, time vs dimension -- Fisk -- dense biased -- set data"

il.reload(rl)

trials = 50

m, k, eps, param = 600, 4, 0.1, 2
xs = list(np.arange(10, 200, 10))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, k = k, eps = eps, param = param)

inputfilename = 'data/loss-time-vs-dimension-Fisk.pkl'
plot_d = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_d.setdata_tofile(filename = inputfilename, xvar_name = 'd', trials = trials, xs = xs)

# %%
"loss vs dimension -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 50

m, k, eps, param = 600, 4, 0.1, 2
xs = list(np.arange(10, 200, 10))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, k = k, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-dimension-Fisk.pkl'
outputfilename = 'figs/loss-vs-dimension-Fisk.pdf'

title = 'm = {m}, k = {k}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(m = m, k = k, eps = eps)
xlabel = 'd'
ylabel = 'L2 error'

plot_d_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_d_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs dimension -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

m, k, eps, param = 600, 4, 0.1, 2
xs = list(np.arange(10, 200, 10))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.Top_K_Filtered, rl.GDAlgs_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, k = k, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-dimension-Fisk.pkl'
outputfilename = 'figs/loss-vs-dimension-Fisk-detailed.pdf'

title = 'm = {m}, k = {k}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(m = m, k = k, eps = eps)
xlabel = 'd'
ylabel = 'L2 error'

plot_d_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_d_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"time vs dimension -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 50

m, k, eps, param = 600, 4, 0.1, 2
xs = list(np.arange(10, 200, 10))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, k = k, eps = eps, param = param)

outputfilename = 'figs/time-vs-dimension-Fisk.pdf'
inputfilename = 'data/loss-time-vs-dimension-Fisk.pkl'
title = 'm = {m}, k = {k}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(m = m, k = k, eps = eps)
xlabel = 'd'
ylabel = 'Time'

plot_d_time = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_d_time.plotxy_fromfile_time(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"time vs dimension -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

m, k, eps, param = 600, 4, 0.1, 2
xs = list(np.arange(10, 200, 10))

keys = [rl.Oracle, rl.RME_sp, rl.RME]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, k = k, eps = eps, param = param)

outputfilename = 'figs/time-vs-dimension-Fisk-detailed.pdf'
inputfilename = 'data/loss-time-vs-dimension-Fisk.pkl'
title = 'm = {m}, k = {k}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(m = m, k = k, eps = eps)
xlabel = 'd'
ylabel = 'Time'

plot_d_time = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_d_time.plotxy_fromfile_time(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss, time vs sparsity -- Fisk -- dense biased -- set data"

il.reload(rl)

trials = 50

m, d, eps, param = 3000, 100, 0.1, 2
xs = list(np.arange(4, 100, 4))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, d = d, eps = eps, param = param)

inputfilename = 'data/loss-time-vs-sparsity-Fisk.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'k', trials = trials, xs = xs)

# %%
"loss vs sparsity -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 50

m, d, eps, param = 600, 100, 0.1, 2
xs = list(np.arange(4, 100, 4))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, d = d, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sparsity-Fisk.pkl'
outputfilename = 'figs/loss-vs-sparsity-Fisk.pdf'

title = 'm = {m}, d = {d}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(m = m, d = d, eps = eps)
xlabel = 'k'
ylabel = 'L2 error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sparsity -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

m, d, eps, param = 600, 100, 0.1, 2
xs = list(np.arange(4, 100, 4))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.Top_K_Filtered, rl.GDAlgs_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, d = d, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sparsity-Fisk.pkl'
outputfilename = 'figs/loss-vs-sparsity-Fisk-detailed.pdf'

title = 'm = {m}, d = {d}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(m = m, d = d, eps = eps)
xlabel = 'k'
ylabel = 'L2 error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"time vs sparsity -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 50

m, d, eps, param = 600, 100, 0.1, 2
xs = list(np.arange(4, 100, 4))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, d = d, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sparsity-Fisk.pkl'
outputfilename = 'figs/time-vs-sparsity-Fisk.pdf'

title = 'm = {m}, d = {d}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(m = m, d = d, eps = eps)
xlabel = 'k'
ylabel = 'Time'

plot_k_time = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_time.plotxy_fromfile_time(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"time vs sparsity -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

m, d, eps, param = 600, 100, 0.1, 2
xs = list(np.arange(4, 100, 4))

keys = [rl.Oracle, rl.RME_sp, rl.RME]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, d = d, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sparsity-Fisk.pkl'
outputfilename = 'figs/time-vs-sparsity-Fisk-detailed.pdf'

title = 'm = {m}, d = {d}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(m = m, d = d, eps = eps)
xlabel = 'k'
ylabel = 'Time'

plot_k_time = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_time.plotxy_fromfile_time(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss, time vs sample -- Fisk -- dense biased -- set data"

il.reload(rl)

trials = 50

d, k, eps, param = 100, 4, 0.1, 2
xs = list(np.arange(50, 1000, 50))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, eps = eps, param = param)

inputfilename = 'data/loss-time-vs-sample-Fisk.pkl'
plot_m = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_m.setdata_tofile(filename = inputfilename, xvar_name = 'm', trials = trials, xs = xs)

# %%
"loss vs sample -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 50

d, k, eps, param = 100, 4, 0.1, 2
xs = list(np.arange(50, 1000, 50))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sample-Fisk.pkl'
outputfilename = 'figs/loss-vs-sample-Fisk.pdf'

title = 'd = {d}, k = {k}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, eps = eps)
xlabel = 'm'
ylabel = 'L2 error'

plot_m_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_m_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sample -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, eps, param = 100, 4, 0.1, 2
xs = list(np.arange(50, 1000, 50))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.Top_K_Filtered, rl.RME, rl.GDAlgs_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sample-Fisk.pkl'
outputfilename = 'figs/loss-vs-sample-Fisk-detailed.pdf'

title = 'd = {d}, k = {k}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, eps = eps)
xlabel = 'm'
ylabel = 'L2 error'

plot_m_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_m_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"time vs sample -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 50

d, k, eps, param = 100, 4, 0.1, 2
xs = list(np.arange(50, 1000, 50))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sample-Fisk.pkl'
outputfilename = 'figs/time-vs-sample-Fisk.pdf'

title = 'd = {d}, k = {k}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, eps = eps)
xlabel = 'm'
ylabel = 'Time'

plot_m_time = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_m_time.plotxy_fromfile_time(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"time vs sample -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, eps, param = 100, 4, 0.1, 2
xs = list(np.arange(50, 1000, 50))

keys = [rl.Oracle, rl.RME_sp, rl.RME]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sample-Fisk.pkl'
outputfilename = 'figs/time-vs-sample-Fisk-detailed.pdf'

title = 'd = {d}, k = {k}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, eps = eps)
xlabel = 'm'
ylabel = 'Time'

plot_m_time = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_m_time.plotxy_fromfile_time(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss, time vs eps -- Fisk -- dense biased -- set data"

il.reload(rl)

trials = 50

d, k, m, param= 100, 4, 600, 2
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)

inputfilename = 'data/loss-time-vs-eps-Fisk.pkl'
plot_m = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_m.setdata_tofile(filename = inputfilename, xvar_name = 'eps', trials = trials, xs = xs)

# %%
"loss vs eps -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 50

d, k, m, param= 100, 4, 600, 2
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/loss-time-vs-eps-Fisk.pkl'
outputfilename = 'figs/loss-vs-eps-Fisk.pdf'

title = 'd = {d}, k = {k}, m = {m}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, m = m)
xlabel = 'eps'
ylabel = 'L2 error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, param= 100, 4, 600, 2
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.Top_K_Filtered, rl.RME_sp]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/loss-time-vs-eps-Fisk.pkl'
outputfilename = 'figs/loss-vs-eps-Fisk-detailed.pdf'

title = 'd = {d}, k = {k}, m = {m}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, m = m)
xlabel = 'eps'
ylabel = 'L2 error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"time vs eps -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 50

d, k, m, param= 100, 4, 600, 2
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/loss-time-vs-eps-Fisk.pkl'
outputfilename = 'figs/time-vs-eps-Fisk.pdf'

title = 'd = {d}, k = {k}, m = {m}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, m = m)
xlabel = 'eps'
ylabel = 'Time'

plot_eps_time = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_time.plotxy_fromfile_time(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"time vs eps -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, param= 100, 4, 600, 2
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/loss-time-vs-eps-Fisk.pkl'
outputfilename = 'figs/time-vs-eps-Fisk-detailed.pdf'

title = 'd = {d}, k = {k}, m = {m}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, m = m)
xlabel = 'eps'
ylabel = 'Time'

plot_eps_time = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_time.plotxy_fromfile_time(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss, time vs param -- Fisk -- dense biased -- set data"

il.reload(rl)

trials = 50

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.1, 0.1))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)

inputfilename = 'data/loss-time-vs-param-Fisk.pkl'
plot_m = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_m.setdata_tofile(filename = inputfilename, xvar_name = 'param', trials = trials, xs = xs)

# %%
"loss vs param -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 50

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.1, 0.1))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.RME_sp, rl.Top_K_Filtered, rl.RME, rl.RME_npre, rl.GDAlgs_npre, rl.RME_sp_npre]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename = 'data/loss-time-vs-param-Fisk.pkl'
outputfilename = 'figs/loss-vs-param-Fisk.pdf'

title = 'd = {d}, k = {k}, m = {m}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, m = m, eps = eps)
xlabel = 'param'
ylabel = 'L2 error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(yscale = 'log', outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs param -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.1, 0.1))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD, rl.GDAlgs, rl.Top_K_Filtered]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename = 'data/loss-time-vs-param-Fisk.pkl'
outputfilename = 'figs/loss-vs-param-Fisk-detailed.pdf'

title = 'd = {d}, k = {k}, m = {m}, eps = {eps}. Model is Fisk. Noise is constant -2 biased.'.format(d = d, k = k, m = m, eps = eps)
xlabel = 'param'
ylabel = 'L2 error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)
