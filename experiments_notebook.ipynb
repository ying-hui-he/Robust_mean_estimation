# %%
import numpy as np
import scipy
import robustlib as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'serif'

# %%
il.reload(rl)

keys_pca1 = [rl.RSPCAb, rl.RSPCAdense] 

d_pca1, k_pca1, eps_pca1, mass_pca1 = 200, 4, 0.1, 10

tv_pca1 = np.append(np.ones(k_pca1), np.zeros(d_pca1-k_pca1))/np.sqrt(k_pca1)
fv_pca1 = np.append(np.zeros(d_pca1-k_pca1), np.ones(k_pca1))

params_pca1 = rl.Params(d = d_pca1, k = k_pca1, eps = eps_pca1, mass = mass_pca1, tv = tv_pca1, fv = fv_pca1)
ylims_pca1 = (0, 0.7)
model_pca1 = rl.RSPCA_MixtureModel()
trials_pca1 = 10

m_bounds_pca1 = (10, 5000, 1000)

plot_m_loss_pca1 = rl.load_data(model_pca1, params_pca1, rl.err_rspca, keys_pca1)
plot_m_loss_pca1.unknown_norm = False

inputfilename_pca1 = 'data/mixture-rspca-loss-vs-m.pkl'

plot_m_loss_pca1.setdata_tofile(inputfilename_pca1, 'm', m_bounds_pca1, trials_pca1, ylims_pca1, y_is_m = False)

# %%
inputfilename_pca1 = 'data/mixture-rspca-loss-vs-m.pkl'
outputfilename_pca1 = 'figs/mixture-rspca-loss-vs-m.pdf'

keys_pca1 = [rl.RSPCAb, rl.RSPCAdense] 

d_pca1, k_pca1, eps_pca1, mass_pca1 = 200, 4, 0.1, 10

tv_pca1 = np.append(np.ones(k_pca1), np.zeros(d_pca1-k_pca1))/np.sqrt(k_pca1)
fv_pca1 = np.append(np.zeros(d_pca1-k_pca1), np.ones(k_pca1))

params_pca1 = rl.Params(d = d_pca1, k = k_pca1, eps = eps_pca1, mass = mass_pca1, tv = tv_pca1, fv = fv_pca1)
ylims_pca1 = (0, 0.7)
model_pca1 = rl.RSPCA_MixtureModel()
trials_pca1 = 10

m_bounds_pca1 = (10, 5000, 1000)

plot_m_loss_pca1 = rl.plot_data(model_pca1, params_pca1, rl.err_rspca, keys_pca1)

xs = []
xlabel_pca1 = 'm'
ylabel_pca1 = 'L2 Loss'
title_pca1 = 'd = {d}, k = {k}, eps = {eps}'.format(d=d_pca1, k=k_pca1, eps=eps_pca1)

plot_m_loss_pca1.plotxy_fromfile(outputfilename_pca1, inputfilename_pca1, 'm', m_bounds_pca1, (0, 1), title_pca1, xlabel_pca1, ylabel_pca1, figsize = figsize, fsize = fsize, fpad = fpad, fontname = fontname, explicit_xs = False, xs = xs)

# %%
il.reload(rl)


keys_pca2 = [rl.RSPCAb, rl.RSPCAdense] 

d_pca2, eps_pca2, mass_pca2, m_pca2 = 300, 0.1, 2, 2000

params_pca2 = rl.Params(d = d_pca2,  eps = eps_pca2, mass = mass_pca2, m = m_pca2)
ylims_pca2 = (0, 0.7)
model_pca2 = rl.RSPCA_MixtureModel()
trials_pca2 = 30

k_bounds_pca2 = (1, 31, 3)

plot_m_loss_pca2 = rl.load_data(model_pca2, params_pca2, rl.err_rspca, keys_pca2)
plot_m_loss_pca2.unknown_norm = False

inputfilename_pca2 = 'data/mixture-rspca-loss-vs-k.pkl'

plot_m_loss_pca2.setdata_tofile(inputfilename_pca2, 'k', k_bounds_pca2, trials_pca2, ylims_pca2, y_is_m = False)

# %%
il.reload(rl)


keys_pca2 = [rl.RSPCAb, rl.RSPCAdense] 

d_pca2, eps_pca2, mass_pca2, m_pca2 = 300, 0.1, 2, 2000

params_pca2 = rl.Params(d = d_pca2,  eps = eps_pca2, mass = mass_pca2, m = m_pca2)
ylims_pca2 = (0, 0.7)
model_pca2 = rl.RSPCA_MixtureModel()
trials_pca2 = 30

k_bounds_pca2 = (1, 31, 3)

plot_m_loss_pca2 = rl.load_data(model_pca2, params_pca2, rl.err_rspca, keys_pca2)
plot_m_loss_pca2.unknown_norm = False
outputfilename_pca2 = 'figs/mixture-rspca-loss-vs-k.pdf'

xlabel_pca2 = 'k'
ylabel_pca2 = 'L2 Loss'
title_pca2 = 'd = {d}, eps = {eps}, m = {m}'.format(d=d_pca2, eps=eps_pca2, m=m_pca2)

plot_m_loss_pca2_plt = rl.plot_data(model_pca2, params_pca2, rl.err_rspca, keys_pca2)



plot_m_loss_pca2_plt.plotxy_fromfile(outputfilename_pca2, inputfilename_pca2, 'k', k_bounds_pca2, (0, 1), title_pca2, xlabel_pca2, ylabel_pca2, figsize = figsize, fsize = fsize, fontname = fontname, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"loss vs sample complexity"

il.reload(rl)

trials_rsm1 = 10
d_rsm1, k_rsm1, eps_rsm1 = 10, 1, 0.1
xs = []

m_bounds_rsm1 = (2, 1000, 10)

model_rsm1 = rl.TailFlipModel()
keys_rsm1 = [rl.Oracle, rl.RME_sp]
model_params_rsm1 = rl.Params(d=d_rsm1, k=k_rsm1, eps=eps_rsm1)
ylims_rsm1 = (0, 1)

inputfilename_rsm1 = 'data/tflipping-loss-vs-k.pkl'
plot_m_loss_rsm1 = rl.load_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)
plot_m_loss_rsm1.setdata_tofile(inputfilename_rsm1, 'm', m_bounds_rsm1, trials_rsm1, ylims_rsm1, explicit_xs = False, xs = xs)

# %%
outputfilename_rsm1 = 'figs/tflipping-loss-vs-k.pdf'

title_rsm1 = 'd = {d}, k = {k}, eps = {eps}. Noise is tail-flipping.'.format(d=d_rsm1,k=k_rsm1,eps=eps_rsm1)
xlabel_rsm1 = 'm'
ylabel_rsm1 = 'L2 Loss'
plot_m_loss_rsm1_plt = rl.plot_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)


plot_m_loss_rsm1_plt.plotxy_fromfile(outputfilename_rsm1, inputfilename_rsm1,'m', m_bounds_rsm1, (0, 0.8), title_rsm1, xlabel_rsm1, ylabel_rsm1, figsize = figsize, fontname = fontname, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"loss vs sample complexity -- dense biased"

il.reload(rl)

trials_rsm2 = 10

d_rsm2, k_rsm2, eps_rsm2 = 300, 10, 0.1
xs_rsm2 = list(np.arange(5,350, 25))

keys_rsm2 = [rl.Oracle, rl.RME, rl.NP_sp, rl.RME_sp, rl.ransacGaussianMean]

model_rsm2 = rl.DenseNoiseModel(-2)
model_params_rsm2 = rl.Params(d=d_rsm2, k=k_rsm2, eps=eps_rsm2)
m_bounds_rsm2 = (1,1)
ylims_rsm2 = (0,1)

inputfilename_rsm2 = 'data/constant-loss-vs-m.pkl'
plot_m_loss_rsm2 = rl.load_data(model_rsm2, model_params_rsm2, rl.err, keys_rsm2)
plot_m_loss_rsm2.setdata_tofile(inputfilename_rsm2, 'm', m_bounds_rsm2, trials_rsm2, ylims_rsm2, explicit_xs = True, xs = xs_rsm2)
print(plot_m_loss_rsm2.Run.runs)
# Out:
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Could not filter
# Linear filter...
# Filtered out 0/4, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 2/4, 2.0 false (1.00 vs 0.1)
# condition 2 4
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# ransacN 2
# thresh 317.3205080756888
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# 2 4
# 4
# ...

# %%
"loss vs sample complexity -- dense biased"

il.reload(rl)

trials_rsm2 = 10

d_rsm2, k_rsm2, eps_rsm2 = 300, 10, 0.1
xs_rsm2 = list(np.arange(5,350, 25))

keys_rsm2 = [rl.Oracle, rl.RME, rl.NP_sp, rl.RME_sp, rl.ransacGaussianMean]

model_rsm2 = rl.DenseNoiseModel(-2)
model_params_rsm2 = rl.Params(d=d_rsm2, k=k_rsm2, eps=eps_rsm2)
m_bounds_rsm2 = (1,1)
ylims_rsm2 = (0,1)

outputfilename_rsm2 = 'figs/constant-loss-vs-m.pdf'

title_rsm2 = 'd = {d}, k = {k}, eps = {eps}. Noise is constant +2 biased.'.format(d=d_rsm2,k=k_rsm2,eps=eps_rsm2)
xlabel_rsm2 = 'm'
ylabel_rsm2 = 'L2 Loss'

plot_m_loss_rsm2_plt = rl.plot_data(model_rsm2, model_params_rsm2, rl.err, keys_rsm2)


plot_m_loss_rsm2_plt.plotxy_fromfile(outputfilename_rsm2, inputfilename_rsm2, 'm', m_bounds_rsm2, (0, 2.4), title_rsm2, xlabel_rsm2, ylabel_rsm2, figsize = figsize, fsize = fsize, fpad = fpad, explicit_xs = True, xs = xs_rsm2, fontname = fontname)
# Out:
# Running cells with '/usr/local/bin/python3' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
"loss vs sample complexity"

il.reload(rl)

trials_rsm3 = 10
d_rsm3, k_rsm3, eps_rsm3 = 1000, 40, 0.1

m_bounds_rsm3 = (1000, 13000, 1000)

model_rsm3 = rl.BimodalModel()

keys_rsm3 = [rl.Oracle, rl.RME_sp_L, rl.RME_sp, rl.NP_sp, rl.RME]
model_params_rsm3 = rl.Params(d=d_rsm3, k=k_rsm3, eps=eps_rsm3)
ylims_rsm3 = (0, 1)
xs = []

inputfilename_rsm3 = 'data/lhiding-loss-vs-m.pkl'

plot_m_loss_rsm3 = rl.load_data(model_rsm3, model_params_rsm3, rl.err, keys_rsm3)
plot_m_loss_rsm3.setdata_tofile(inputfilename_rsm3, 'm', m_bounds_rsm3, trials_rsm3, ylims_rsm3, explicit_xs = False, xs = xs)

# %%
il.reload(rl)

trials_rsm3 = 10
d_rsm3, k_rsm3, eps_rsm3 = 1000, 40, 0.1

m_bounds_rsm3 = (1000, 13000, 1000)

model_rsm3 = rl.BimodalModel()

keys_rsm3 = [rl.Oracle, rl.RME_sp_L, rl.RME_sp, rl.NP_sp, rl.RME]
model_params_rsm3 = rl.Params(d=d_rsm3, k=k_rsm3, eps=eps_rsm3)
ylims_rsm3 = (0, 1)
xs = []

outputfilename_rsm3 = 'figs/lhiding-loss-vs-m.pdf'
inputfilename_rsm3 = 'data/lhiding-loss-vs-m.pkl'


title_rsm3 = 'd = {d}, k = {k}, eps = {eps}. Noise is linear-hiding.'.format(d=d_rsm3,k=k_rsm3,eps=eps_rsm3)
xlabel_rsm3 = 'm'
ylabel_rsm3 = 'L2 Loss'

plot_m_loss_rsm3.keys = [rl.Oracle, rl.RME_sp_L, rl.RME_sp, rl.NP_sp]
plot_m_loss_rsm3_plt = rl.plot_data(model_rsm3, model_params_rsm3, rl.err, keys_rsm3)


plot_m_loss_rsm3_plt.plotxy_fromfile(outputfilename_rsm3, inputfilename_rsm3, 'm', m_bounds_rsm3, (0, 1), title_rsm3, xlabel_rsm3, ylabel_rsm3, figsize = figsize, fsize = fsize, fpad = fpad, fontname = fontname, explicit_xs = False, xs = xs)
plt.savefig('lhiding-loss-vs-m')

# %%
"loss vs sample complexity"

il.reload(rl)

trials_rsm3 = 10
d_rsm3, k_rsm3, eps_rsm3 = 100, 3, 0.1

m_bounds_rsm3 = (3, 500, 10)

model_rsm3 = rl.BimodalModel()

keys_rsm3 = [rl.Oracle, rl.RME_sp_L, rl.RME_sp, rl.NP_sp, rl.RME]
model_params_rsm3 = rl.Params(d=d_rsm3, k=k_rsm3, eps=eps_rsm3)
ylims_rsm3 = (0, 1)
xs = []

inputfilename_rsm3 = 'data/lhiding-loss-vs-m-testing.pkl'

plot_m_loss_rsm3 = rl.load_data(model_rsm3, model_params_rsm3, rl.err, keys_rsm3)
plot_m_loss_rsm3.setdata_tofile(inputfilename_rsm3, 'm', m_bounds_rsm3, trials_rsm3, ylims_rsm3, explicit_xs = False, xs = xs)

# %%
il.reload(rl)

trials_rsm3 = 10
d_rsm3, k_rsm3, eps_rsm3 = 1000, 40, 0.1

m_bounds_rsm3 = (1000, 13000, 1000)

model_rsm3 = rl.BimodalModel()

keys_rsm3 = [rl.Oracle, rl.RME_sp_L, rl.RME_sp, rl.NP_sp, rl.RME]
model_params_rsm3 = rl.Params(d=d_rsm3, k=k_rsm3, eps=eps_rsm3)
ylims_rsm3 = (0, 1)
xs = []

outputfilename_rsm3 = 'figs/lhiding-loss-vs-m-testing.pdf'
inputfilename_rsm3 = 'data/lhiding-loss-vs-m-testing.pkl'


title_rsm3 = 'd = {d}, k = {k}, eps = {eps}. Noise is linear-hiding.'.format(d=d_rsm3,k=k_rsm3,eps=eps_rsm3)
xlabel_rsm3 = 'm'
ylabel_rsm3 = 'L2 Loss'

plot_m_loss_rsm3.keys = [rl.Oracle, rl.RME_sp_L, rl.RME_sp, rl.NP_sp]
plot_m_loss_rsm3_plt = rl.plot_data(model_rsm3, model_params_rsm3, rl.err, keys_rsm3)


plot_m_loss_rsm3_plt.plotxy_fromfile(outputfilename_rsm3, inputfilename_rsm3, 'm', m_bounds_rsm3, (0, 1), title_rsm3, xlabel_rsm3, ylabel_rsm3, figsize = figsize, fsize = fsize, fpad = fpad, fontname = fontname, explicit_xs = False, xs = xs)
plt.savefig('lhiding-loss-vs-m')

# %%
"sparsity vs sample complexity for RME_sp -- "

il.reload(rl)

d_rsm_m_1, eps_rsm_m_1 = 200, 0.1
params_rsm_m_1 = rl.Params(d=d_rsm_m_1, eps=eps_rsm_m_1)
trials_rsm_m_1 = 10

model_rsm_m_1 = rl.DenseNoiseModel(2)

inp, S, indicator, tm = model_rsm_m_1.generate(params_rsm_m_1)

keys_rsm_m_1 = [rl.RME_sp]
ylims_rsm_m_1 = (0, 100)
k_bounds_rsm_m_1 = (1, 20, 1)

inputfilename_m_loss_rsm_m_1 = 'data/constant-m-vs-k.pkl'

plot_m_loss_rsm_m_1 = rl.load_data(model_rsm_m_1, params_rsm_m_1, rl.err, keys_rsm_m_1)
plot_m_loss_rsm_m_1.setdata_tofile(inputfilename_m_loss_rsm_m_1, 'k', k_bounds_rsm_m_1, trials_rsm_m_1, ylims_rsm_m_1, y_is_m = True, mrange = (2,200), medianerr = True)

# %%
il.reload(rl)

d_rsm_m_1, eps_rsm_m_1 = 200, 0.1
params_rsm_m_1 = rl.Params(d=d_rsm_m_1, eps=eps_rsm_m_1)
trials_rsm_m_1 = 10
xs = []

model_rsm_m_1 = rl.DenseNoiseModel(2)

inp, S, indicator, tm = model_rsm_m_1.generate(params_rsm_m_1)

keys_rsm_m_1 = [rl.RME_sp]
ylims_rsm_m_1 = (0, 100)
k_bounds_rsm_m_1 = (1, 20, 1)

outputfilename_rsm_m_1 = 'figs/constant-m-vs-k.pdf'
inputfilename_m_loss_rsm_m_1 = 'data/constant-m-vs-k.pkl'

xlabel_rsm_m_1 = 'k'
ylabel_rsm_m_1 = 'samples'
title_rsm_m_1 = 'd = {d}, eps = {eps}. Noise is a constant +2 biased.'.format(d=d_rsm_m_1,eps=eps_rsm_m_1)
plot_m_loss_rsm_m_1_plt = rl.plot_data(model_rsm_m_1, params_rsm_m_1, rl.err, keys_rsm_m_1)


plot_m_loss_rsm_m_1_plt.plotxy_fromfile(outputfilename_rsm_m_1, inputfilename_m_loss_rsm_m_1, 'k', k_bounds_rsm_m_1, (0, 150), title_rsm_m_1, xlabel_rsm_m_1, ylabel_rsm_m_1, fontname = fontname,  figsize = figsize, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"sparsity vs sample complexity for RME_sp -- "

il.reload(rl)

d_rsm_m_1, eps_rsm_m_1 = 200, 0.1
params_rsm_m_1 = rl.Params(d=d_rsm_m_1, eps=eps_rsm_m_1)
trials_rsm_m_1 = 10

model_rsm_m_1 = rl.DenseNoiseModel(2)

inp, S, indicator, tm = model_rsm_m_1.generate(params_rsm_m_1)

keys_rsm_m_1 = [rl.RME_sp]
ylims_rsm_m_1 = (0, 100)
k_bounds_rsm_m_1 = (1, 20, 1)

inputfilename_m_loss_rsm_m_1 = 'data/constant-rspca-m-vs-k-medianerr.pkl'

plot_m_loss_rsm_m_1 = rl.load_data(model_rsm_m_1, params_rsm_m_1, rl.err_rspca, keys_rsm_m_1)
plot_m_loss_rsm_m_1.setdata_tofile(inputfilename_m_loss_rsm_m_1, 'k', k_bounds_rsm_m_1, trials_rsm_m_1, ylims_rsm_m_1, y_is_m = True, medianerr= True, mrange = (2,200))

# %%
il.reload(rl)

d_rsm_m_1, eps_rsm_m_1 = 200, 0.1
params_rsm_m_1 = rl.Params(d=d_rsm_m_1, eps=eps_rsm_m_1)
trials_rsm_m_1 = 10

model_rsm_m_1 = rl.DenseNoiseModel(2)

inp, S, indicator, tm = model_rsm_m_1.generate(params_rsm_m_1)

xs = []

keys_rsm_m_1 = [rl.RME_sp]
ylims_rsm_m_1 = (0, 100)
k_bounds_rsm_m_1 = (1, 20, 1)

outputfilename_rsm_m_1 = 'figs/constant-rspca-m-vs-k-medianerr.pdf'
inputfilename_m_loss_rsm_m_1 = 'data/constant-rspca-m-vs-k-medianerr.pkl'

xlabel_rsm_m_1 = 'k'
ylabel_rsm_m_1 = 'samples'
title_rsm_m_1 = 'd = {d}, eps = {eps}. Noise is a constant +2 biased. (medianerr < 0.8)'.format(d=d_rsm_m_1,eps=eps_rsm_m_1)

plot_m_loss_rsm_m_1 = rl.plot_data(model_rsm_m_1, params_rsm_m_1, rl.err_rspca, keys_rsm_m_1)
plot_m_loss_rsm_m_1.plotxy_fromfile(outputfilename_rsm_m_1, inputfilename_m_loss_rsm_m_1, 'k', k_bounds_rsm_m_1, (0, 1300), title_rsm_m_1, xlabel_rsm_m_1, ylabel_rsm_m_1, figsize = figsize, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"sparsity vs sample complexity for RME_sp -- "

il.reload(rl)

d_rsm_m_2, eps_rsm_m_2 = 300, 0.1
params_rsm_m_2 = rl.Params(d=d_rsm_m_2, eps=eps_rsm_m_2)
trials_rsm_m_2 = 10

model_rsm_m_2 = rl.BimodalModel()

inp, S, indicator, tm = model_rsm_m_2.generate(params_rsm_m_2)

keys_rsm_m_2 = [rl.RME_sp]
ylims_rsm_m_2 = (0, 100)
k_bounds_rsm_m_2 = (20, 35, 1)

inputfilename_m_loss_rsm_m_2 = 'data/lhiding-m-vs-k-medianerr.pkl'

plot_m_loss_rsm_m_2 = rl.load_data(model_rsm_m_2, params_rsm_m_2, rl.err, keys_rsm_m_2)
plot_m_loss_rsm_m_2.setdata_tofile(inputfilename_m_loss_rsm_m_2, 'k', k_bounds_rsm_m_2, trials_rsm_m_2, ylims_rsm_m_2, y_is_m = True, medianerr= True, mrange = (2,200))

# %%
il.reload(rl)

d_rsm_m_2, eps_rsm_m_2 = 300, 0.1
params_rsm_m_2 = rl.Params(d=d_rsm_m_2, eps=eps_rsm_m_2)
trials_rsm_m_2 = 10

model_rsm_m_2 = rl.BimodalModel()

xs = []

inp, S, indicator, tm = model_rsm_m_2.generate(params_rsm_m_2)

keys_rsm_m_2 = [rl.RME_sp]
ylims_rsm_m_2 = (0, 100)
k_bounds_rsm_m_2 = (20, 35, 1)

outputfilename_rsm_m_2 = 'figs/lhiding-m-vs-k-medianerr.pdf'
inputfilename_m_loss_rsm_m_2 = 'data/lhiding-m-vs-k-medianerr.pkl'



xlabel_rsm_m_2 = 'k'

ylabel_rsm_m_2 = 'samples'
title_rsm_m_2 = 'd = {d}, eps = {eps}. Noise is linear-hiding. (medianerr < 0.3)'.format(d=d_rsm_m_2,eps=eps_rsm_m_2)

plot_m_loss_rsm_m_2_plt = rl.plot_data(model_rsm_m_2, params_rsm_m_2, rl.err, keys_rsm_m_2)
plot_m_loss_rsm_m_2_plt.plotxy_fromfile( outputfilename_rsm_m_2, inputfilename_m_loss_rsm_m_2, 'k', k_bounds_rsm_m_2, (0, 3150), title_rsm_m_2, xlabel_rsm_m_2, ylabel_rsm_m_2, figsize = figsize, fontname = fontname, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"sparsity vs sample complexity for RME_sp -- "

il.reload(rl)

d_rsm_m_2, eps_rsm_m_2 = 200, 0.1
params_rsm_m_2 = rl.Params(d=d_rsm_m_2, eps=eps_rsm_m_2)
trials_rsm_m_2 = 10

model_rsm_m_2 = rl.BimodalModel()

inp, S, indicator, tm = model_rsm_m_2.generate(params_rsm_m_2)

keys_rsm_m_2 = [rl.RME_sp]
ylims_rsm_m_2 = (0, 100)
k_bounds_rsm_m_2 = (1, 20, 1)

inputfilename_m_loss_rsm_m_2 = 'data/lhiding-rspca-m-vs-k.pkl'

plot_m_loss_rsm_m_2 = rl.load_data(model_rsm_m_2, params_rsm_m_2, rl.err, keys_rsm_m_2)
plot_m_loss_rsm_m_2.setdata_tofile(inputfilename_m_loss_rsm_m_2, 'k', k_bounds_rsm_m_2, trials_rsm_m_2, ylims_rsm_m_2, y_is_m = True, mrange = (2,200))

# %%
il.reload(rl)

d_rsm_m_2, eps_rsm_m_2 = 200, 0.1
params_rsm_m_2 = rl.Params(d=d_rsm_m_2, eps=eps_rsm_m_2)
trials_rsm_m_2 = 10

model_rsm_m_2 = rl.BimodalModel()

inp, S, indicator, tm = model_rsm_m_2.generate(params_rsm_m_2)

keys_rsm_m_2 = [rl.RME_sp]
ylims_rsm_m_2 = (0, 100)
k_bounds_rsm_m_2 = (1, 20, 1)

outputfilename_rsm_m_2 = 'figs/lhiding-rspca-m-vs-k.pdf'
inputfilename_m_loss_rsm_m_2 = 'data/lhiding-rspca-m-vs-k.pkl'



xlabel_rsm_m_2 = 'k'
ylabel_rsm_m_2 = 'samples'
title_rsm_m_2 = 'd = {d}, eps = {eps}. Noise is linear-hiding.'.format(d=d_rsm_m_2,eps=eps_rsm_m_2)

plot_m_loss_rsm_m_2_plt = rl.plot_data(model_rsm_m_2, params_rsm_m_2, rl.err, keys_rsm_m_2)

plot_m_loss_rsm_m_2_plt.plotxy_fromfile( outputfilename_rsm_m_2, inputfilename_m_loss_rsm_m_2, 'k', k_bounds_rsm_m_2, (0, 70), title_rsm_m_2, xlabel_rsm_m_2, ylabel_rsm_m_2, figsize = figsize, fontname = fontname, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"Loss vs eps"

il.reload(rl)

trials_f = 10
d_f, k_f, m_f = 10, 1, 5000
eps_bounds_f = (0, 0.5, 0.01)
# model = rl.DenseNoiseModel(-100)

model_f = rl.TailFlipModel()
keys_f = [rl.Oracle, rl.RME_sp]
model_params_f = rl.Params(d=d_f, k=k_f, m=m_f)
ylims_f = (0, 1)

inputfilename_m_loss_f = 'data/tflipping-loss-vs-eps.pkl'
plot_m_loss_f = rl.load_data(model_f, model_params_f, rl.err, keys_f)
plot_m_loss_f.setdata_tofile(inputfilename_m_loss_f, 'eps', eps_bounds_f, trials_f, ylims_f, relative=False)

# %%
outputfilename_m_loss_f = 'figs/tflipping-loss-vs-eps.pdf'

xlabel_f = 'eps'
ylabel_f = 'L2 Loss'
title_f = 'd = {d}, k = {k}, m = {m}. Noise is tail-flipping'.format(d=d_f,k=k_f,m=m_f)
xs = []
plot_m_loss_f_plt = rl.plot_data(model_f, model_params_f, rl.err, keys_f)



plot_m_loss_f_plt.plotxy_fromfile(outputfilename_m_loss_f, inputfilename_m_loss_f, 'eps', eps_bounds_f, (0, 1), title_f, xlabel_f, ylabel_f, fontname = fontname, figsize = figsize, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"Loss vs sparsity"
il.reload(rl)

trials_k1 = 10

d_k1, eps_k1, m_k1 = 300, 0.1, 5000
k_bounds_k1 = (1, 100, 5)

model_k1 = rl.DenseNoiseModel(-2)

keys_k1 = [rl.RME_sp, rl.NP_sp, rl.ransacGaussianMean, rl.Oracle, rl.RME]
model_params_k1 = rl.Params(d = d_k1, eps = eps_k1, m = m_k1)
ylims_k1 = (0, 1)

inputfilename_m_loss_k1 = 'data/constant-loss-vs-k.pkl'

plot_m_loss_k1 = rl.load_data(model_k1, model_params_k1, rl.err, keys_k1)
plot_m_loss_k1.setdata_tofile(inputfilename_m_loss_k1, 'k', k_bounds_k1, trials_k1, ylims_k1)

# %%
il.reload(rl)

trials_k1 = 10

d_k1, eps_k1, m_k1 = 300, 0.1, 5000
k_bounds_k1 = (1, 100, 5)

model_k1 = rl.DenseNoiseModel(-2)

keys_k1 = [rl.RME_sp, rl.NP_sp, rl.ransacGaussianMean, rl.Oracle, rl.RME]
model_params_k1 = rl.Params(d = d_k1, eps = eps_k1, m = m_k1)
ylims_k1 = (0, 1)

outputfilename_m_loss_k1 = 'figs/constant-loss-vs-k.pdf'

xlabel_k1 = 'k'
ylabel_k1 = 'L2 Loss'
title_k1 = 'd = {d}, eps = {eps}, m = {m}. Noise is constant +2 biased'.format(d=d_k1,eps=eps_k1,m=m_k1)




plot_m_loss_k1_plt = rl.plot_data(model_k1, model_params_k1, rl.err, keys_k1)
plot_m_loss_k1_plt.plotxy_fromfile(outputfilename_m_loss_k1, inputfilename_m_loss_k1, 'k', k_bounds_k1, (0, 2), title_k1, xlabel_k1, ylabel_k1, figsize = figsize, fsize = fsize, fontname = fontname, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"Loss vs sparsity"
il.reload(rl)

trials_k2 = 10
d_k2, eps_k2, m_k2 = 300, 0.1, 5000
k_bounds_k2 = (1, 200, 20)

model_k2 = rl.BimodalModel()

keys_k2 = [rl.RME_sp, rl.NP_sp, rl.RME_sp_L, rl.Oracle, rl.RME]
model_params_k2 = rl.Params(d = d_k2, eps = eps_k2, m = m_k2)
ylims_k2 = (0, 1)

inputfilename_m_loss_k2 = 'data/lhiding-loss-vs-k.pkl'
plot_m_loss_k2 = rl.load_data(model_k2, model_params_k2, rl.err, keys_k2)
plot_m_loss_k2.setdata_tofile(inputfilename_m_loss_k2,'k', k_bounds_k2, trials_k2, ylims_k2)

# %%
il.reload(rl)

trials_k2 = 10
d_k2, eps_k2, m_k2 = 300, 0.1, 5000
k_bounds_k2 = (1, 200, 20)

model_k2 = rl.BimodalModel()

keys_k2 = [rl.RME_sp, rl.NP_sp, rl.RME_sp_L, rl.Oracle, rl.RME]
model_params_k2 = rl.Params(d = d_k2, eps = eps_k2, m = m_k2)
ylims_k2 = (0, 1)

inputfilename_m_loss_k2 = 'data/lhiding-loss-vs-k.pkl'
outputfilename_m_loss_k2 = 'figs/lhiding-loss-vs-k.pdf'

xlabel_k2 = 'k'
ylabel_k2 = 'L2 Loss'

plot_m_loss_k2_plt = rl.plot_data(model_k2, model_params_k2, rl.err, keys_k2)


plot_m_loss_k2_plt.keys = [rl.RME_sp, rl.NP_sp, rl.RME_sp_L, rl.Oracle]
title_k2 = 'd = {d}, eps = {eps}, m = {m}. Noise is linear-hiding'.format(d=d_k2,eps=eps_k2,m=m_k2)

plot_m_loss_k2_plt.plotxy_fromfile(outputfilename_m_loss_k2, inputfilename_m_loss_k2, 'k', k_bounds_k2, (0, 1.2), title_k2, xlabel_k2, ylabel_k2, figsize = figsize, fontname = fontname, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"<<<< ALL RELEVANT PLOTS SHOULD BE ABOVE >>>>"

# %%
""" Testing sparse mean stuff """

il.reload(rl)

d, k, eps = 300, 10, 0.1
m = 4000
params = rl.Params(d=d, k=k, eps=eps, m = m)


model = rl.DenseNoiseModel(-2)
# model = rl.BimodalModel()

print(f"Running on d={d}, k={k}, eps={eps}, m={m}")
inp, S, indicator, tm = model.generate(params)

A = rl.RME(inp)
A.do_plot_linear = False
ans = A.alg(S, indicator)
print(LA.norm(tm - ans))

# err = rl.get_error(f, inp, tm=tm)
# print(f'Error for {f.__name__}: {err}')


# for f in [rl.RME_sp]:
#     err = rl.get_error(f, *inp)
#     print(f'Error for {f.__name__}: {err}')

# %%
""" Testing sparse PCA stuff """
il.reload(rl)

d, k, eps, m, mass = 10, 1, 0.1, 1000, 2

tv = 0.5*np.append(np.ones(k), np.zeros(d-k))/np.sqrt(k)
fv = np.append(np.zeros(d-k), np.ones(k))

params = rl.Params(d = d, k = k, eps = eps, m = m, mass = mass, tv = tv, fv = fv )


model = rl.RSPCA_MixtureModel()

inp, S, indicator, tv = model.generate(params)

# A = rl.RSPCAdense(inp)
A = rl.RSPCAb(inp)
A.unknown_norm = True
A.is_sparse = True
A.biter = 2
A.do_plot_rspca = True
ans = A.alg(S, indicator)
print(LA.norm(np.outer(tv, tv) - np.outer(ans,ans)))
print(ans)

# %%
"loss vs sample complexity"

il.reload(rl)

trials_rsm3 = 20
d_rsm3, k_rsm3, eps_rsm3 = 200, 3, 0.1

m_bounds_rsm3 = (10, 600, 100)

model_rsm3 = rl.BimodalModel()

keys_rsm3 = [rl.Oracle, rl.RME_sp_L, rl.RME_sp, rl.NP_sp, rl.RME]
model_params_rsm3 = rl.Params(d=d_rsm3, k=k_rsm3, eps=eps_rsm3)
ylims_rsm3 = (0, 1)
xs = []

inputfilename_rsm3 = 'data/lhiding-loss-vs-m-test1.pkl'

plot_m_loss_rsm3 = rl.load_data(model_rsm3, model_params_rsm3, rl.err, keys_rsm3)
plot_m_loss_rsm3.setdata_tofile(inputfilename_rsm3, 'm', m_bounds_rsm3, trials_rsm3, ylims_rsm3, explicit_xs = False, xs = xs)

# %%
outputfilename_rsm3 = 'figs/lhiding-loss-vs-m-test1.pdf'
inputfilename_rsm3 = 'data/lhiding-loss-vs-m-test1.pkl'

title_rsm3 = 'd = {d}, k = {k}, eps = {eps}. Noise is linear-hiding.'.format(d=d_rsm3,k=k_rsm3,eps=eps_rsm3)
xlabel_rsm3 = 'm'
ylabel_rsm3 = 'L2 Loss'

plot_m_loss_rsm3.keys = [rl.Oracle, rl.RME_sp_L, rl.RME_sp, rl.NP_sp]
plot_m_loss_rsm3_plt = rl.plot_data(model_rsm3, model_params_rsm3, rl.err, keys_rsm3)


plot_m_loss_rsm3_plt.plotxy_fromfile(outputfilename_rsm3, inputfilename_rsm3, 'm', m_bounds_rsm3, (0, 1), title_rsm3, xlabel_rsm3, ylabel_rsm3, figsize = figsize, fsize = fsize, fpad = fpad, fontname = fontname, explicit_xs = False, xs = xs)
plt.savefig('lhiding-loss-vs-m-test1')

# %%
import numpy as np
import scipy
import robustlib as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
from cvxopt import matrix, solvers
mpld3.enable_notebook()

# %%
import numpy as np
from sklearn.datasets import make_friedman1
from sklearn.decomposition import SparsePCA
X = np.array([[1,0,0],[1,0,0],[1,0,0]])
transformer = SparsePCA(n_components=2, normalize_components=True, random_state=0)
transformer.fit(X) 
X_transformed = transformer.transform(X)
X_transformed.shape
print(transformer.get_params())
print(X)
print(X_transformed)

# %%
il.reload(rl)

d_rsm_m_1, eps_rsm_m_1 = 200, 0.1
params_rsm_m_1 = rl.Params(d=d_rsm_m_1, eps=eps_rsm_m_1)
trials_rsm_m_1 = 10
xs = []

model_rsm_m_1 = rl.DenseNoiseModel(2)

inp, S, indicator, tm = model_rsm_m_1.generate(params_rsm_m_1)

keys_rsm_m_1 = [rl.RME_sp]
ylims_rsm_m_1 = (0, 100)
k_bounds_rsm_m_1 = (20, 21, 1)

outputfilename_rsm_m_1 = 'figs/test.pdf'
inputfilename_m_loss_rsm_m_1 = 'data/test.pkl'

xlabel_rsm_m_1 = 'k'
ylabel_rsm_m_1 = 'samples'
title_rsm_m_1 = 'd = {d}, eps = {eps}. Noise is a constant +2 biased.'.format(d=d_rsm_m_1,eps=eps_rsm_m_1)
plot_m_loss_rsm_m_1_plt = rl.plot_data(model_rsm_m_1, params_rsm_m_1, rl.err, keys_rsm_m_1)


plot_m_loss_rsm_m_1_plt.plotxy_fromfile(outputfilename_rsm_m_1, inputfilename_m_loss_rsm_m_1, 'k', k_bounds_rsm_m_1, (0, 150), title_rsm_m_1, xlabel_rsm_m_1, ylabel_rsm_m_1, fontname = fontname,  figsize = figsize, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)

# %%
"sparsity vs sample complexity for RME_sp -- "

import time
il.reload(rl)

d_rsm_m_1, eps_rsm_m_1 = 1000, 0.1
params_rsm_m_1 = rl.Params(d=d_rsm_m_1, eps=eps_rsm_m_1, m = 8000)
trials_rsm_m_1 = 1

model_rsm_m_1 = rl.DenseNoiseModel(2)

inp, S, indicator, tm = model_rsm_m_1.generate(params_rsm_m_1)

keys_rsm_m_1 = [rl.RME_sp]
ylims_rsm_m_1 = (8000, 8001)
k_bounds_rsm_m_1 = (40, 41, 1)

inputfilename_m_loss_rsm_m_1 = 'data/test.pkl'

start_time = time.time()

plot_m_loss_rsm_m_1 = rl.load_data(model_rsm_m_1, params_rsm_m_1, rl.err, keys_rsm_m_1)


plot_m_loss_rsm_m_1.setdata_tofile(inputfilename_m_loss_rsm_m_1, 'k', k_bounds_rsm_m_1, trials_rsm_m_1, ylims_rsm_m_1, y_is_m = False, mrange = (8000,8001), medianerr = True)

print("--- %s seconds ---" % (time.time() - start_time))

# %%
import time
il.reload(rl)

d_rsm_m_1, eps_rsm_m_1 = 300, 0.1
params_rsm_m_1 = rl.Params(d=d_rsm_m_1, eps=eps_rsm_m_1, m = 50)
trials_rsm_m_1 = 1

model_rsm_m_1 = rl.DenseNoiseModel(2)

inp, S, indicator, tm = model_rsm_m_1.generate(params_rsm_m_1)

keys_rsm_m_1 = [rl.RME_sp]
ylims_rsm_m_1 = (8000, 8001)
k_bounds_rsm_m_1 = (40, 41, 1)

inputfilename_m_loss_rsm_m_1 = 'data/test.pkl'

start_time = time.time()

plot_m_loss_rsm_m_1 = rl.load_data(model_rsm_m_1, params_rsm_m_1, rl.err, keys_rsm_m_1)
plot_m_loss_rsm_m_1.setdata_tofile(inputfilename_m_loss_rsm_m_1, 'k', k_bounds_rsm_m_1, trials_rsm_m_1, ylims_rsm_m_1, y_is_m = False, mrange = (50,51), medianerr = True)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
import time
il.reload(rl)

d_rsm_m_1, eps_rsm_m_1 = 10, 0.1
params_rsm_m_1 = rl.Params(d=d_rsm_m_1, eps=eps_rsm_m_1, m = 50)
trials_rsm_m_1 = 1

model_rsm_m_1 = rl.DenseNoiseModel(2)

inp, S, indicator, tm = model_rsm_m_1.generate(params_rsm_m_1)

keys_rsm_m_1 = [rl.RME_sp]
ylims_rsm_m_1 = (8000, 8001)
k_bounds_rsm_m_1 = (2, 3, 1)

inputfilename_m_loss_rsm_m_1 = 'data/test.pkl'
# add comments


plot_m_loss_rsm_m_1 = rl.load_data(model_rsm_m_1, params_rsm_m_1, rl.err, keys_rsm_m_1)
plot_m_loss_rsm_m_1.setdata_tofile(inputfilename_m_loss_rsm_m_1, 'k', k_bounds_rsm_m_1, trials_rsm_m_1, ylims_rsm_m_1, y_is_m = False, mrange = (50,51), medianerr = True)

print("--- %s seconds ---" % (time.time() - start_time))
