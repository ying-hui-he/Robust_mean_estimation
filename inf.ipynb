# %%
import numpy as np
import scipy
import robust_mean_estimate as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'Arial'

# %%
"loss vs param -- Fisk -- dense biased -- set data"

il.reload(rl)

trials = 10

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.5, 0.1))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)

inputfilename = 'data/loss-vs-param-Fisk-full.pkl'
plot_m = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_m.setdata_tofile(filename = inputfilename, xvar_name = 'param', trials = trials, xs = xs)

# %%
"loss vs param -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 10

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.5, 0.1))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename = 'data/loss-vs-param-Fisk-full.pkl'
outputfilename = 'figs/err-vs-param-Fisk-full.pdf'

title = 'Fisk'
xlabel = '$c$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs param -- Pareto -- dense biased -- set data"

il.reload(rl)

trials = 10

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.5, 0.1))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)

inputfilename = 'data/loss-vs-param-Pareto-full.pkl'
plot_m = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_m.setdata_tofile(filename = inputfilename, xvar_name = 'param', trials = trials, xs = xs)

# %%
"loss vs param -- Pareto -- dense biased -- plot"

il.reload(rl)

trials = 10

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.5, 0.1))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename = 'data/loss-vs-param-Pareto-full.pkl'
outputfilename = 'figs/err-vs-param-Pareto-full.pdf'

title = 'Pareto'
xlabel = '$c$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs param -- T -- dense biased -- set data"

il.reload(rl)

trials = 10

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.5, 0.1))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)

inputfilename = 'data/loss-vs-param-T-full.pkl'
plot_m = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_m.setdata_tofile(filename = inputfilename, xvar_name = 'param', trials = trials, xs = xs)

# %%
"loss vs param -- T -- dense biased -- plot"

il.reload(rl)

trials = 10

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.5, 0.1))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename = 'data/loss-vs-param-T-full.pkl'
outputfilename = 'figs/err-vs-param-T-full.pdf'

title = 'T'
xlabel = '$c$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs param -- 3 -- dense biased -- plot"

il.reload(rl)

trials = 10

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.5, 0.1))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename = 'data/loss-vs-param-Fisk-full.pkl'
inputfilename1 = 'data/loss-vs-param-Fisk-full.pkl'
inputfilename2 = 'data/loss-vs-param-Pareto-full.pkl'
inputfilename3 = 'data/loss-vs-param-T-full.pkl'
outputfilename = 'figs/appendix/err-vs-param-3-full.pdf'

title = ['Fisk', 'Pareto', "Student $t$"]
xlabel = ['$c$', '$b$', '$\\nu$']
ylabel = '$\\ell_2$ error'
xlim = (1.1, 3.4)


plot_param_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_param_loss.plotxy_3_fromfile(outputfilename = outputfilename, filename1 = inputfilename1, filename2 = inputfilename2, filename3 = inputfilename3, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname, xlim=xlim)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el274201403525673278082602828650"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el274201403525673278082602828650", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el27420140352567327808", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
# ...
