# %%
import numpy as np
import scipy
import robust_mean_estimate as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'Arial'

# %%
"loss vs param -- T -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, eps = 100, 4, 400, 0.1
xs = list(np.arange(1.1, 3, 0.1))

keys = [rl.Top_K, rl.Top_K_Filtered, rl.Oracle]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename = 'data/loss-time-vs-param-T.pkl'
outputfilename = 'figs/loss-vs-param-T-detailed.pdf'

title = 'Student $t$'
xlabel = '$\\nu$'
ylabel = '$\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs param -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.1, 0.1))

keys = [rl.Top_K, rl.Top_K_Filtered, rl.Oracle]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename = 'data/loss-time-vs-param-Fisk.pkl'
outputfilename = 'figs/loss-vs-param-Fisk-detailed.pdf'

title = 'Fisk'
xlabel = '$c$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- Fisk -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, param= 100, 4, 600, 2
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/loss-time-vs-eps-Fisk.pkl'
outputfilename = 'figs/loss-vs-eps-Fisk-detailed.pdf'

title = 'Fisk'
xlabel = 'eps'
ylabel = 'L2 error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- T -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, param= 100, 4, 3000, 2
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/loss-time-vs-eps-T.pkl'
outputfilename = 'figs/loss-vs-eps-T-detailed.pdf'

title = 'Student t'
xlabel = 'eps'
ylabel = 'L2 error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- Pareto -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, param= 100, 4, 600, 2
xs = list(np.arange(0.01, 0.21, 0.005))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, param = param)
inputfilename = 'data/loss-time-vs-eps-Pareto.pkl'
outputfilename = 'figs/loss-vs-eps-Pareto-detailed.pdf'

title = 'Pareto'
xlabel = 'eps'
ylabel = 'L2 error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs eps -- lognormal -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m = 100, 4, 3000
xs = list(np.arange(0.01, 0.21, 0.01))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD]

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m)
inputfilename = 'data/loss-time-vs-eps-lognormal.pkl'
outputfilename = 'figs/loss-vs-eps-lognormal-detailed.pdf'

title = 'Lognormal'
xlabel = 'eps'
ylabel = 'L2 error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs var -- lognormal -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(0.1, 10.1, 0.1))

keys = [rl.Oracle, rl.Top_K, rl.Topk_GD]

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m)
inputfilename = 'data/loss-time-vs-var-lognormal.pkl'
outputfilename = 'figs/loss-vs-var-lognormal-detailed.pdf'

title = 'Lognormal'
xlabel = 'var'
ylabel = 'L2 error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sparsity -- T -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

m, d, eps, param = 600, 100, 0.1, 2
xs = list(np.arange(4, 100, 4))

keys = [rl.Top_K, rl.Topk_GD, rl.Oracle]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, d = d, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sparsity-T.pkl'
outputfilename = 'figs/loss-vs-sparsity-T-detailed.pdf'

title = 'Student $t$'
xlabel = '$k$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sparsity -- lognormal -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

m, d, eps = 600, 100, 0.1
xs = list(np.arange(4, 100, 4))

keys = [rl.Top_K, rl.Topk_GD, rl.Oracle]

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, d = d, eps = eps)
inputfilename = 'data/loss-time-vs-sparsity-lognormal.pkl'
outputfilename = 'figs/loss-vs-sparsity-lognormal-detailed.pdf'

title = 'Lognormal'
xlabel = '$k$'
ylabel = '$\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sparsity -- Pareto -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

m, d, eps, param = 600, 100, 0.1, 2
xs = list(np.arange(4, 100, 4))

keys = [rl.Top_K, rl.Topk_GD, rl.Oracle]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(m = m, d = d, eps = eps, param = param)
inputfilename = 'data/loss-time-vs-sparsity-Pareto.pkl'
outputfilename = 'figs/loss-vs-sparsity-Pareto-detailed.pdf'

title = 'Pareto'
xlabel = '$k$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs param -- Pareto -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, eps = 100, 4, 600, 0.1
xs = list(np.arange(1.1, 3.1, 0.1))

keys = [rl.Top_K, rl.Topk_GD, rl.Oracle]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename = 'data/loss-time-vs-param-Pareto.pkl'
outputfilename = 'figs/loss-vs-param-Pareto-detailed.pdf'

title = 'Pareto'
xlabel = '$b$'
ylabel = '$\\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sparsity -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 20

d, eps, param = 100, 0.1, 2
xs = list(np.arange(5, 105, 5))

keys = [rl.Top_K, rl.Top_K_Filtered_RME, rl.Oracle]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-m-k-Fisk_RME.pkl'
outputfilename = 'figs/error-m-k-Fisk_RME.pdf'

title = 'Fisk'
xlabel = '$k$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sparsity -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 20

d, eps, param = 100, 0.1, 2
xs = list(np.arange(5, 105, 5))

keys = [rl.Top_K, rl.Top_K_Filtered, rl.Oracle]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-m-k-Fisk.pkl'
outputfilename = 'figs/error-m-k-Fisk.pdf'

title = 'Fisk'
xlabel = '$k$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sparsity -- Lognormal -- dense biased -- plot"

il.reload(rl)

trials = 20

d, eps, param = 100, 0.1, 2
xs = list(np.arange(5, 105, 5))

keys = [rl.Top_K, rl.Top_K_Filtered, rl.Oracle]

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-m-k-Lognormal.pkl'
outputfilename = 'figs/error-m-k-Lognormal.pdf'

title = 'Lognormal'
xlabel = '$k$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sensitivity -- Fisk -- dense biased -- set data"

il.reload(rl)

trials = 20

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 101, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param, m = m)

inputfilename = 'data/error-sen-Fisk.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'sen', trials = trials, xs = xs)

# %%
"loss vs sparsity -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 20

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 101, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-sen-Fisk.pkl'
outputfilename = 'figs/error-sen-Fisk.pdf'

title = 'Fisk'
xlabel = '$k$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs param -- T -- dense biased -- plot -- detailed"

il.reload(rl)

trials = 50

d, k, m, eps = 100, 4, 400, 0.1
xs1 = list(np.arange(1.1, 3.1, 0.1))
xs2 = list(np.arange(1.1, 3.1, 0.1))
xs3 = list(np.arange(1.1, 3, 0.1))


keys = [rl.Top_K, rl.Top_K_Filtered, rl.Oracle]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, k = k, m = m, eps = eps)
inputfilename1 = 'data/loss-time-vs-param-Fisk.pkl'
inputfilename2 = 'data/loss-time-vs-param-Pareto.pkl'
inputfilename3 = 'data/loss-time-vs-param-T.pkl'
outputfilename = 'figs/loss-vs-param-3.pdf'

title = 'Student $t$'
xlabel = '$\\nu$'
ylabel = '$\ell_2$ error'

plot_eps_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_eps_loss.plotxy_3_fromfile(outputfilename = outputfilename, filename1 = inputfilename1, filename2 = inputfilename2, filename3 = inputfilename3, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs1 = xs1, xs2 = xs2, xs3 = xs3, fontname = fontname, xlim=(1.1, 2.9))
# Out:
# <style>
#
# </style>
#
# <div id="fig_el623081406271845639208604496752"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el623081406271845639208604496752", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el62308140627184563920", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#          mpld3.draw_figure("fig_el623081406271845639208604496752", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el62308140627184563920", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://d3js.org/d3.v5.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#                  mpld3.draw_figure("fig_el623081406271845639208604496752", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el62308140627184563920", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>
