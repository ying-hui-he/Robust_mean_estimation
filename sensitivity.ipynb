# %%
import numpy as np
import scipy
import robust_mean_estimate as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'Arial'

# %%
"loss vs sensitivity -- Fisk -- dense biased -- set data -- inf"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param, m = m)

inputfilename = 'data/error-sen-Fisk-inf.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'sen', trials = trials, xs = xs)

# %%
"loss vs sensitivity -- Fisk -- dense biased -- set data"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 3.1, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param, m = m)

inputfilename = 'data/error-sen-Fisk.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'sen', trials = trials, xs = xs)

# %%
"loss vs sensitivity -- Fisk -- dense biased -- plot -- inf"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-sen-Fisk-inf.pkl'
outputfilename = 'figs/error-sen-Fisk-inf.pdf'

title = 'Fisk'
xlabel = '$k\'$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sensitivity -- Fisk -- dense biased -- plot"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 3.1, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-sen-Fisk.pkl'
outputfilename = 'figs/error-sen-Fisk.pdf'

title = 'Fisk'
xlabel = '$k\'$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sensitivity -- Pareto -- dense biased -- set data -- inf"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param, m = m)

inputfilename = 'data/error-sen-Pareto-inf.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'sen', trials = trials, xs = xs)

# %%
"loss vs sensitivity -- Pareto -- dense biased -- set data"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 3.1, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param, m = m)

inputfilename = 'data/error-sen-Pareto.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'sen', trials = trials, xs = xs)

# %%
"loss vs sensitivity -- Pareto -- dense biased -- plot -- inf"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-sen-Pareto-inf.pkl'
outputfilename = 'figs/error-sen-Pareto-inf.pdf'

title = 'Pareto'
xlabel = '$k\'$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sensitivity -- Pareto -- dense biased -- plot"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 3.1, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-sen-Pareto.pkl'
outputfilename = 'figs/error-sen-Pareto.pdf'

title = 'Pareto'
xlabel = '$k\'$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sensitivity -- T -- dense biased -- set data -- inf"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param, m = m)

inputfilename = 'data/error-sen-T-inf.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'sen', trials = trials, xs = xs)

# %%
"loss vs sensitivity -- T -- dense biased -- set data"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 3.1, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param, m = m)

inputfilename = 'data/error-sen-T.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'sen', trials = trials, xs = xs)

# %%
"loss vs sensitivity -- T -- dense biased -- plot -- inf"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-sen-T-inf.pkl'
outputfilename = 'figs/error-sen-T-inf.pdf'

title = 'T'
xlabel = '$k\'$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sensitivity -- T -- dense biased -- plot"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 3.1, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-sen-T.pkl'
outputfilename = 'figs/error-sen-T.pdf'

title = 'T'
xlabel = '$k\'$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sensitivity -- Lognormal -- dense biased -- set data"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param, m = m)

inputfilename = 'data/error-sen-Lognormal.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'sen', trials = trials, xs = xs)

# %%
"loss vs sensitivity -- Lognormal -- dense biased -- plot"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-sen-Lognormal.pkl'
outputfilename = 'figs/error-sen-Lognormal.pdf'

title = 'Lognormal'
xlabel = '$k\'$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sensitivity -- Gaussian -- dense biased -- set data"

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.GaussianModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param, m = m)

inputfilename = 'data/error-sen-Gaussian.pkl'
plot_k = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_k.setdata_tofile(filename = inputfilename, xvar_name = 'sen', trials = trials, xs = xs)

# %%
"loss vs sensitivity -- Gaussian -- dense biased -- plot"

il.reload(rl)

trials = 20

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs, rl.Top_K, rl.Top_K_Filtered, rl.Topk_GD]

model = rl.GaussianModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
inputfilename = 'data/error-sen-Gaussian.pkl'
outputfilename = 'figs/error-sen-Gaussian.pdf'

title = 'Gaussian'
xlabel = '$k\'$'
ylabel = '$\\ell_2$ error'

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_fromfile(outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname)

# %%
"loss vs sensitivity -- all three -- plot"

inputfilename1 = 'data/error-sen-Fisk-inf.pkl'
inputfilename2 = 'data/error-sen-Pareto-inf.pkl'
inputfilename3 = 'data/error-sen-T-inf.pkl'
outputfilename = 'figs/appendix/error-sen-3-inf.pdf'

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 2, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
title = ['Fisk ($c=2$)', 'Pareto ($b=2$)', "Student $t$ ($\\nu=2$)"]
xlabel = ['$k\'$', '$k\'$', '$k\'$']
ylabel = '$\\ell_2$ error'
xlim = (10, 40)
ylim = (0, 4)

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_3_fromfile(outputfilename = outputfilename, filename1 = inputfilename1, filename2 = inputfilename2, filename3 = inputfilename3, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname, xlim=xlim, ylim=ylim)

# %%
"loss vs sensitivity -- all three -- plot"

inputfilename1 = 'data/error-sen-Fisk.pkl'
inputfilename2 = 'data/error-sen-Pareto.pkl'
inputfilename3 = 'data/error-sen-T.pkl'
outputfilename = 'figs/appendix/error-sen-3.pdf'

il.reload(rl)

trials = 10

d, eps, param, m = 100, 0.1, 3.1, 600
xs = list(np.arange(1, 41, 3))

keys = [rl.Oracle, rl.RME_sp, rl.GDAlgs_npre, rl.Top_K, rl.Full, rl.Full_Filter]

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(d = d, eps = eps, param = param)
title = ['Fisk ($c=3$)', 'Pareto ($b=3$)', "Student $t$ ($\\nu=3$)"]
xlabel = ['$k\'$', '$k\'$', '$k\'$']
ylabel = '$\\ell_2$ error'
xlim = (10, 40)
ylim = (0, 1.5)

plot_k_loss = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

plot_k_loss.plotxy_3_fromfile(outputfilename = outputfilename, filename1 = inputfilename1, filename2 = inputfilename2, filename3 = inputfilename3, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, fontname = fontname, xlim=xlim, ylim=ylim)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el28606140378057047536379392843"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el28606140378057047536379392843", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el28606140378057047536", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#          mpld3.draw_figure("fig_el28606140378057047536379392843", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el28606140378057047536", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://d3js.org/d3.v5.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#                  mpld3.draw_figure("fig_el28606140378057047536379392843", {"width": 1200.0, "height": 600.0, "axes": [], "data": {}, "id": "el28606140378057047536", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>
