# %%
import numpy as np
import scipy
import robust_mean_estimate as rl
import importlib as il
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'fantasy'
# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "Helvetica"
# })

# %%
"heatmap -- Lognormal -- dense biased -- set data -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d)

inputfilename = 'data/heatmap-Lognormal-TopK_GD.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print(plot_heatmap.Run.runs)

# %%
"heatmap -- Lognormal -- dense biased -- plot -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d)

inputfilename = 'data/heatmap-Lognormal-TopK_GD.pkl'
outputfilename = 'figs/heatmap-Lognormal-TopK_GD.pdf'

# title = 'eps = {eps}, d = {d}. Model is Lognormal. Noise is constant -2 biased.'.format(eps = eps, d = d)
title = 'Lognormal'
xlabel = 'n'
ylabel = 'k'

heatmap = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

heatmap.plotheatmap_fromfile(yscale = 'log', outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, ys = ys, fontname = fontname)

# %%
"heatmap -- Pareto -- dense biased -- set data -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2)

inputfilename = 'data/heatmap-Pareto-TopK_GD.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print(plot_heatmap.Run.runs)

# %%
"heatmap -- Pareto -- dense biased -- plot -- TopK_GD"

il.reload(rl)

trials = 10

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d)

inputfilename = 'data/heatmap-Pareto-TopK_GD.pkl'
outputfilename = 'figs/heatmap-Pareto-TopK_GD.pdf'

# title = 'eps = {eps}, d = {d}. Model is Pareto. Noise is constant -2 biased.'.format(eps = eps, d = d)
title = 'Pareto'
xlabel = 'n'
ylabel = 'k'

heatmap = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

heatmap.plotheatmap_fromfile(yscale = 'log', outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, ys = ys, fontname = fontname)

# %%
"heatmap -- StudentT -- dense biased -- set data -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2)

inputfilename = 'data/heatmap-StudentT-TopK_GD.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print(plot_heatmap.Run.runs)

# %%
"heatmap -- StudentT -- dense biased -- plot -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2.74)

inputfilename = 'data/heatmap-StudentT-TopK_GD.pkl'
outputfilename = 'figs/heatmap-StudentT-TopK_GD.pdf'

# title = 'eps = {eps}, d = {d}. Model is StudentT. Noise is constant -2 biased.'.format(eps = eps, d = d)
title = 'Student T'
xlabel = "n"
ylabel = "k"

heatmap = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

heatmap.plotheatmap_fromfile(yscale = 'log', outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, ys = ys, fontname = fontname)

# %%
"""Plot 3 heatmaps."""
il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2.74)

inputfilename1 = 'data/heatmap-Lognormal-TopK_GD.pkl'
inputfilename2 = 'data/heatmap-Pareto-TopK_GD.pkl'
inputfilename3 = 'data/heatmap-StudentT-TopK_GD.pkl'

outputfilename = 'figs/heatmap-3-TopK_GD.pdf'

# title = 'eps = {eps}, d = {d}. Model is StudentT. Noise is constant -2 biased.'.format(eps = eps, d = d)
title = '3 heatmaps'
xlabel = "sample size (n)"
ylabel = "sparsity (k)"

heatmap = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

heatmap.plotheatmap_3_fromfile(yscale = 'log', outputfilename = outputfilename, filename1 = inputfilename1, filename2 = inputfilename2, filename3 = inputfilename3, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, ys = ys, fontname = fontname)
# Out:
# heatmap input: [[0.71152094 0.61457121 0.59185231 0.55425707 0.55897987 0.55609795
#   0.57380435 0.54734607]
#  [0.6550088  0.58675802 0.55711527 0.53029617 0.55133198 0.50671832
#   0.53436671 0.54178108]
#  [0.58420293 0.5599881  0.53236076 0.50140301 0.47170027 0.47465073
#   0.47348189 0.48159477]
#  [0.51432181 0.49386759 0.45997491 0.44750214 0.44395634 0.44404966
#   0.41700218 0.4238171 ]
#  [0.44495843 0.4359392  0.42952787 0.40248763 0.41409731 0.39116788
#   0.39938387 0.39619735]]
# heatmap input: [[0.71332655 0.62032851 0.57804725 0.51822826 0.56096707 0.56300477
#   0.55814819 0.55364158]
#  [0.64441485 0.55063686 0.53620458 0.55136801 0.52221758 0.51605159
#   0.50824156 0.50555503]
#  [0.53505207 0.5045252  0.50747633 0.4897801  0.48924968 0.48015153
#   0.49378238 0.48208021]
#  [0.57511874 0.47172251 0.44799823 0.42875016 0.47259741 0.43256314
#   0.45416252 0.41448375]
#  [0.43130048 0.40830818 0.39605272 0.4126535  0.39369269 0.40997281
#   0.38353402 0.37890178]]
# heatmap input: [[0.66949923 0.56534751 0.59160624 0.56752241 0.54833447 0.55993729
#   0.56137536 0.56705058]
#  [0.57986452 0.49807157 0.52840162 0.49276775 0.48223488 0.497961
#   0.52212625 0.49444345]
#  [0.55759859 0.49056831 0.47880851 0.48939043 0.44827217 0.46193466
#   0.46073882 0.47853514]
#  [0.45485755 0.4659998  0.42337937 0.42421192 0.39514563 0.42292232
#   0.43098142 0.41404199]
#  [0.41269129 0.37335497 0.37111708 0.36093264 0.35876568 0.35735322
#   0.38171695 0.3967662 ]]
