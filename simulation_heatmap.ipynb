# %%
import numpy as np
import scipy
import robust_mean_estimate as rl
import importlib as il
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'fantasy'
# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "Helvetica"
# })

# %%
"heatmap -- Lognormal -- dense biased -- set data -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d)

inputfilename = 'data/heatmap-Lognormal-TopK_GD.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print(plot_heatmap.Run.runs)

# %%
"heatmap -- Lognormal -- dense biased -- plot -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d)

inputfilename = 'data/heatmap-Lognormal-TopK_GD.pkl'
outputfilename = 'figs/heatmap-Lognormal-TopK_GD.pdf'

# title = 'eps = {eps}, d = {d}. Model is Lognormal. Noise is constant -2 biased.'.format(eps = eps, d = d)
title = 'Lognormal'
xlabel = 'n'
ylabel = 'k'

heatmap = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

heatmap.plotheatmap_fromfile(yscale = 'log', outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, ys = ys, fontname = fontname)

# %%
"heatmap -- Pareto -- dense biased -- set data -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2)

inputfilename = 'data/heatmap-Pareto-TopK_GD.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print(plot_heatmap.Run.runs)

# %%
"heatmap -- Pareto -- dense biased -- plot -- TopK_GD"

il.reload(rl)

trials = 10

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d)

inputfilename = 'data/heatmap-Pareto-TopK_GD.pkl'
outputfilename = 'figs/heatmap-Pareto-TopK_GD.pdf'

# title = 'eps = {eps}, d = {d}. Model is Pareto. Noise is constant -2 biased.'.format(eps = eps, d = d)
title = 'Pareto'
xlabel = 'n'
ylabel = 'k'

heatmap = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

heatmap.plotheatmap_fromfile(yscale = 'log', outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, ys = ys, fontname = fontname)

# %%
"heatmap -- StudentT -- dense biased -- set data -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2)

inputfilename = 'data/heatmap-StudentT-TopK_GD.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print(plot_heatmap.Run.runs)

# %%
"heatmap -- 3 -- dense biased -- set data -- TopK_Filtered"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Top_K_Filtered

# Lognormal
model = rl.LognormalModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2)

inputfilename = 'data/heatmap-Lognormal-Full.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print('Lognormal Finished')

# Student t
model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2)

inputfilename = 'data/heatmap-StudentT-Full.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
# print(plot_heatmap.Run.runs)
print('T Finished')

# Pareto
model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2)

inputfilename = 'data/heatmap-Pareto-Full.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print('Pareto Finished')

# %%
"heatmap -- StudentT -- dense biased -- plot -- TopK_GD"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Topk_GD

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2.74)

inputfilename = 'data/heatmap-StudentT-TopK_GD.pkl'
outputfilename = 'figs/heatmap-StudentT-TopK_GD.pdf'

# title = 'eps = {eps}, d = {d}. Model is StudentT. Noise is constant -2 biased.'.format(eps = eps, d = d)
title = 'Student T'
xlabel = "n"
ylabel = "k"

heatmap = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

heatmap.plotheatmap_fromfile(yscale = 'log', outputfilename = outputfilename, filename = inputfilename, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, ys = ys, fontname = fontname)

# %%
"""Plot 3 heatmaps."""
il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Top_K_Filtered

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=2.74)

inputfilename1 = 'data/heatmap-Lognormal-Full.pkl'
inputfilename2 = 'data/heatmap-Pareto-Full.pkl'
inputfilename3 = 'data/heatmap-StudentT-Full.pkl'

outputfilename = 'figs/heatmap-3-Full.pdf'

# title = 'eps = {eps}, d = {d}. Model is StudentT. Noise is constant -2 biased.'.format(eps = eps, d = d)
title = '3 heatmaps'
xlabel = "sample size (n)"
ylabel = "sparsity (k)"

heatmap = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

heatmap.plotheatmap_3_fromfile(yscale = 'log', outputfilename = outputfilename, filename1 = inputfilename1, filename2 = inputfilename2, filename3 = inputfilename3, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, ys = ys, fontname = fontname)
# Out:
# heatmap input: [[0.68671656 0.62803278 0.64761809 0.59799646 0.62571547 0.57774644
#   0.60421733 0.60102032]
#  [0.66049945 0.58759226 0.59600333 0.58297299 0.56818522 0.52777871
#   0.54031213 0.57729876]
#  [0.5861269  0.54153175 0.53727321 0.5349556  0.52472291 0.50167381
#   0.51442528 0.52987619]
#  [0.51846577 0.48783972 0.48998306 0.46317839 0.4873691  0.50077144
#   0.45406755 0.48083716]
#  [0.4684073  0.44108996 0.40348487 0.42208229 0.39901522 0.42935511
#   0.41716692 0.42869517]]
# heatmap input: [[0.67965493 0.62236488 0.60479941 0.58754809 0.59339136 0.60112983
#   0.6040159  0.60332251]
#  [0.57706939 0.60028797 0.59180253 0.58675952 0.56794268 0.56510515
#   0.57166204 0.56552194]
#  [0.53788055 0.53460411 0.52549355 0.53640825 0.51606462 0.51783836
#   0.54764008 0.5450976 ]
#  [0.52685163 0.51655633 0.47407895 0.46000295 0.47137035 0.47971456
#   0.46803305 0.48984218]
#  [0.43465013 0.46294087 0.40094989 0.40673228 0.42644471 0.41156633
#   0.44644736 0.44732213]]
# heatmap input: [[0.61642941 0.62678319 0.59074206 0.60416256 0.59838386 0.57295308
#   0.61639597 0.59202631]
#  [0.62700761 0.57898063 0.54184891 0.56293332 0.57139701 0.52057159
#   0.54244618 0.53297912]
#  [0.55991595 0.52130589 0.53572462 0.49360385 0.50069603 0.49673013
#   0.5075918  0.51320975]
#  [0.51076244 0.51093688 0.47904699 0.4560642  0.46685916 0.46629027
#   0.45967626 0.44259349]
#  [0.42212534 0.40214578 0.38232127 0.42439451 0.40759251 0.4263763
#   0.42483043 0.40353412]]
