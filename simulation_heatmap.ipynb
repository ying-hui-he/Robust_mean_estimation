# %%
import numpy as np
import scipy
import robust_mean_estimate as rl
import importlib as il
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'fantasy'
# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "Helvetica"
# })

# %%
"heatmap -- Fisk -- dense biased -- set data -- Full_Filter"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Full_Filter

model = rl.FiskModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=3.1)

inputfilename = 'data/heatmap-Fisk-Full_Filter.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print(plot_heatmap.Run.runs)

# %%
"heatmap -- Pareto -- dense biased -- set data -- Full_Filter"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Full_Filter

model = rl.ParetoModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=3.1)

inputfilename = 'data/heatmap-Pareto-Full_Filter.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print(plot_heatmap.Run.runs)

# %%
"heatmap -- StudentT -- dense biased -- set data -- Full_Filter"

il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Full_Filter

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d, param=3.1)

inputfilename = 'data/heatmap-StudentT-Full_Filter.pkl'
plot_heatmap = rl.load_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)
plot_heatmap.setdata_tofile_heatmap(filename = inputfilename, trials = trials, xs = xs, ys = ys)
print(plot_heatmap.Run.runs)

# %%
"""Plot 3 heatmaps."""
il.reload(rl)

trials = 50

eps = 0.1
d = 100

xs = list(np.arange(200, 1000, 100))
ys = list(np.arange(4, 9, 1))

keys = rl.Full_Filter

model = rl.TModel()
noise_model = rl.DenseNoise(-2)
model_params = rl.Params(eps = eps, d = d)

inputfilename1 = 'data/heatmap-Fisk-Full_Filter.pkl'
inputfilename2 = 'data/heatmap-Pareto-Full_Filter.pkl'
inputfilename3 = 'data/heatmap-StudentT-Full_Filter.pkl'

outputfilename = 'figs/heatmap-3-Full_Filter.pdf'

# title = 'eps = {eps}, d = {d}. Model is StudentT. Noise is constant -2 biased.'.format(eps = eps, d = d)
title = '3 heatmaps'
xlabel = "sample size (n)"
ylabel = "sparsity (k)"

heatmap = rl.plot_data(model = model, noise_model = noise_model, params = model_params, loss = rl.err, keys = keys)

heatmap.plotheatmap_3_fromfile(yscale = 'log', outputfilename = outputfilename, filename1 = inputfilename1, filename2 = inputfilename2, filename3 = inputfilename3, title = title, xlabel = xlabel, ylabel = ylabel, figsize = figsize, fsize = fsize, fpad = fpad, xs = xs, ys = ys, fontname = fontname)
# Out:
# heatmap input: [[0.35811091 0.28722835 0.26621177 0.25630048 0.23933967 0.23380005
#   0.21230387 0.22673762]
#  [0.35585045 0.28880459 0.27382683 0.25485588 0.24446312 0.24528915
#   0.23702708 0.23054121]
#  [0.3425299  0.29934801 0.28138934 0.27871622 0.28191069 0.26075547
#   0.25349576 0.23175537]
#  [0.35881234 0.29286802 0.33271792 0.29017238 0.30306946 0.27493362
#   0.27891294 0.29283135]
#  [0.33952526 0.34680983 0.35175844 0.33405036 0.30786824 0.3129511
#   0.28922772 0.31353873]]
# heatmap input: [[0.41635309 0.40068839 0.35689757 0.33410476 0.31006685 0.29880096
#   0.31222778 0.28868249]
#  [0.40739788 0.33653731 0.38477668 0.32403656 0.34375486 0.33857564
#   0.32006497 0.32174009]
#  [0.42474456 0.34520053 0.35473546 0.3522409  0.34260933 0.32867397
#   0.31241372 0.33212668]
#  [0.40463003 0.37819517 0.38647966 0.36886632 0.36675778 0.36029176
#   0.3361879  0.35472403]
#  [0.40741627 0.39037639 0.3781832  0.35643588 0.3170363  0.33980383
#   0.32657012 0.31516145]]
# heatmap input: [[0.2870026  0.28805319 0.25342665 0.2327079  0.19097612 0.19979669
#   0.19958114 0.21267418]
#  [0.33468149 0.28324632 0.24873948 0.24049376 0.22338859 0.21869977
#   0.22662667 0.21282487]
#  [0.34513329 0.30144195 0.2746976  0.24661343 0.24859887 0.25670656
#   0.23912407 0.25755845]
#  [0.33711832 0.35236642 0.27950773 0.28398855 0.27470583 0.26995399
#   0.27476564 0.27273879]
#  [0.33575527 0.30768467 0.29792768 0.30796808 0.33782172 0.29481739
#   0.30903349 0.30174633]]
