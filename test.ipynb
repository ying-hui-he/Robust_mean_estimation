# %%
import numpy as np
import scipy
import robustlib as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'serif'

# %%
"loss vs sample complexity"

il.reload(rl)

trials_rsm1 = 10
d_rsm1, k_rsm1, eps_rsm1 = 10, 1, 0.1
xs = []

m_bounds_rsm1 = (2, 1000, 10)

model_rsm1 = rl.TailFlipModel()
keys_rsm1 = [rl.Top_K, rl.Oracle, rl.RME_sp]
model_params_rsm1 = rl.Params(d=d_rsm1, k=k_rsm1, eps=eps_rsm1)
ylims_rsm1 = (0, 1)

inputfilename_rsm1 = 'data/tflipping-loss-vs-k.pkl'
plot_m_loss_rsm1 = rl.load_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)
plot_m_loss_rsm1.setdata_tofile(inputfilename_rsm1, 'm', m_bounds_rsm1, trials_rsm1, ylims_rsm1, explicit_xs = False, xs = xs)
# Out:
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# Linear filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# condition 22 22
# Could not filter
# Linear filter...
# Filtered out 0/32, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/32, 0.0 false (nan vs 0.1)
# condition 32 32
# Could not filter
# Linear filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# condition 42 42
# Could not filter
# Linear filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# condition 52 52
# Could not filter
# Linear filter...
# Filtered out 0/62, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/62, 0.0 false (nan vs 0.1)
# condition 62 62
# Could not filter
# /Users/yinghui/Desktop/Random/Algorithm2/robust_sparse_mean_estimation/robustlib.py:286: RuntimeWarning: invalid value encountered in double_scalars
#   print(f"Filtered out {l - len(idx[0])}/{l}, {bad_filtered} false ({bad_filtered / (l - len(idx[0])):0.2f} vs {self.fdr})")
# /Users/yinghui/Desktop/Random/Algorithm2/robust_sparse_mean_estimation/robustlib.py:302: RuntimeWarning: invalid value encountered in double_scalars
#   print(f"Filtered out {l - len(idx[0])}/{l}, {bad_filtered} false ({bad_filtered / (l - len(idx[0])):0.2f} vs {self.fdr})")
# Linear filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# condition 72 72
# Could not filter
# Linear filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# condition 82 82
# Could not filter
# Linear filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# condition 92 92
# Could not filter
# Linear filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# condition 101 101
# Could not filter
# Linear filter...
# Filtered out 0/112, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/112, 0.0 false (nan vs 0.1)
# condition 112 112
# Could not filter
# Linear filter...
# Filtered out 0/122, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/122, 0.0 false (nan vs 0.1)
# condition 122 122
# Could not filter
# Linear filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# condition 132 132
# Could not filter
# Linear filter...
# Filtered out 0/142, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/142, 0.0 false (nan vs 0.1)
# condition 142 142
# Could not filter
# Quadratic filter...
# Filtered out 0/152, 0.0 false (nan vs 0.1)
# condition 152 152
# Could not filter
# Linear filter...
# Filtered out 0/162, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/162, 0.0 false (nan vs 0.1)
# condition 162 162
# Could not filter
# Linear filter...
# Filtered out 0/172, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/172, 0.0 false (nan vs 0.1)
# condition 172 172
# Could not filter
# Quadratic filter...
# Filtered out 0/182, 0.0 false (nan vs 0.1)
# condition 182 182
# Could not filter
# Quadratic filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# condition 192 192
# Could not filter
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# Linear filter...
# Filtered out 0/212, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/212, 0.0 false (nan vs 0.1)
# condition 212 212
# Could not filter
# Quadratic filter...
# Filtered out 0/222, 0.0 false (nan vs 0.1)
# condition 222 222
# Could not filter
# Linear filter...
# Filtered out 0/232, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/232, 0.0 false (nan vs 0.1)
# condition 232 232
# Could not filter
# Quadratic filter...
# Filtered out 0/242, 0.0 false (nan vs 0.1)
# condition 242 242
# Could not filter
# Linear filter...
# Filtered out 0/252, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/252, 0.0 false (nan vs 0.1)
# condition 252 252
# Could not filter
# Quadratic filter...
# Filtered out 0/262, 0.0 false (nan vs 0.1)
# condition 262 262
# Could not filter
# Quadratic filter...
# Filtered out 0/272, 0.0 false (nan vs 0.1)
# condition 272 272
# Could not filter
# Linear filter...
# Filtered out 0/282, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/282, 0.0 false (nan vs 0.1)
# condition 282 282
# Could not filter
# Quadratic filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# condition 292 292
# Could not filter
# Quadratic filter...
# Filtered out 0/302, 0.0 false (nan vs 0.1)
# condition 302 302
# Could not filter
# Quadratic filter...
# Filtered out 0/312, 0.0 false (nan vs 0.1)
# condition 312 312
# Could not filter
# Quadratic filter...
# Filtered out 0/322, 0.0 false (nan vs 0.1)
# condition 322 322
# Could not filter
# Quadratic filter...
# Filtered out 0/332, 0.0 false (nan vs 0.1)
# condition 332 332
# Could not filter
# Linear filter...
# Filtered out 0/342, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/342, 0.0 false (nan vs 0.1)
# condition 342 342
# Could not filter
# Quadratic filter...
# Filtered out 0/352, 0.0 false (nan vs 0.1)
# condition 352 352
# Could not filter
# Quadratic filter...
# Filtered out 0/362, 0.0 false (nan vs 0.1)
# condition 362 362
# Could not filter
# Linear filter...
# Filtered out 0/372, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/372, 0.0 false (nan vs 0.1)
# condition 372 372
# Could not filter
# Quadratic filter...
# Filtered out 0/382, 0.0 false (nan vs 0.1)
# condition 382 382
# Could not filter
# Linear filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# condition 392 392
# Could not filter
# Linear filter...
# Filtered out 0/402, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/402, 0.0 false (nan vs 0.1)
# condition 402 402
# Could not filter
# Quadratic filter...
# Filtered out 0/411, 0.0 false (nan vs 0.1)
# condition 411 411
# Could not filter
# Quadratic filter...
# Filtered out 0/422, 0.0 false (nan vs 0.1)
# condition 422 422
# Could not filter
# Quadratic filter...
# Filtered out 0/432, 0.0 false (nan vs 0.1)
# condition 432 432
# Could not filter
# Quadratic filter...
# Filtered out 0/442, 0.0 false (nan vs 0.1)
# condition 442 442
# Could not filter
# Linear filter...
# Filtered out 0/452, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/452, 0.0 false (nan vs 0.1)
# condition 452 452
# Could not filter
# Quadratic filter...
# Filtered out 0/462, 0.0 false (nan vs 0.1)
# condition 462 462
# Could not filter
# Quadratic filter...
# Filtered out 0/472, 0.0 false (nan vs 0.1)
# condition 472 472
# Could not filter
# Quadratic filter...
# Filtered out 0/482, 0.0 false (nan vs 0.1)
# condition 482 482
# Could not filter
# Quadratic filter...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# condition 492 492
# Could not filter
# Quadratic filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# condition 502 502
# Could not filter
# Quadratic filter...
# Filtered out 0/512, 0.0 false (nan vs 0.1)
# condition 512 512
# Could not filter
# Quadratic filter...
# Filtered out 0/522, 0.0 false (nan vs 0.1)
# condition 522 522
# Could not filter
# Quadratic filter...
# Filtered out 0/532, 0.0 false (nan vs 0.1)
# condition 532 532
# Could not filter
# Linear filter...
# Filtered out 0/542, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/542, 0.0 false (nan vs 0.1)
# condition 542 542
# Could not filter
# Quadratic filter...
# Filtered out 0/552, 0.0 false (nan vs 0.1)
# condition 552 552
# Could not filter
# Quadratic filter...
# Filtered out 0/562, 0.0 false (nan vs 0.1)
# condition 562 562
# Could not filter
# Quadratic filter...
# Filtered out 0/572, 0.0 false (nan vs 0.1)
# condition 572 572
# Could not filter
# Quadratic filter...
# Filtered out 0/582, 0.0 false (nan vs 0.1)
# condition 582 582
# Could not filter
# Linear filter...
# Filtered out 0/592, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/592, 0.0 false (nan vs 0.1)
# condition 592 592
# Could not filter
# Quadratic filter...
# Filtered out 0/602, 0.0 false (nan vs 0.1)
# condition 602 602
# Could not filter
# Quadratic filter...
# Filtered out 0/612, 0.0 false (nan vs 0.1)
# condition 612 612
# Could not filter
# Quadratic filter...
# Filtered out 0/622, 0.0 false (nan vs 0.1)
# condition 622 622
# Could not filter
# Quadratic filter...
# Filtered out 0/632, 0.0 false (nan vs 0.1)
# condition 632 632
# Could not filter
# Quadratic filter...
# Filtered out 0/642, 0.0 false (nan vs 0.1)
# condition 642 642
# Could not filter
# Quadratic filter...
# Filtered out 0/652, 0.0 false (nan vs 0.1)
# condition 652 652
# Could not filter
# Quadratic filter...
# Filtered out 0/662, 0.0 false (nan vs 0.1)
# condition 662 662
# Could not filter
# Quadratic filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# condition 672 672
# Could not filter
# Quadratic filter...
# Filtered out 0/682, 0.0 false (nan vs 0.1)
# condition 682 682
# Could not filter
# Quadratic filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# condition 692 692
# Could not filter
# Quadratic filter...
# Filtered out 0/702, 0.0 false (nan vs 0.1)
# condition 702 702
# Could not filter
# Quadratic filter...
# Filtered out 0/712, 0.0 false (nan vs 0.1)
# condition 712 712
# Could not filter
# Quadratic filter...
# Filtered out 0/722, 0.0 false (nan vs 0.1)
# condition 722 722
# Could not filter
# Quadratic filter...
# Filtered out 0/732, 0.0 false (nan vs 0.1)
# condition 732 732
# Could not filter
# Quadratic filter...
# Filtered out 0/742, 0.0 false (nan vs 0.1)
# condition 742 742
# Could not filter
# Quadratic filter...
# Filtered out 0/752, 0.0 false (nan vs 0.1)
# condition 752 752
# Could not filter
# Quadratic filter...
# Filtered out 0/762, 0.0 false (nan vs 0.1)
# condition 762 762
# Could not filter
# Quadratic filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# condition 772 772
# Could not filter
# Quadratic filter...
# Filtered out 0/782, 0.0 false (nan vs 0.1)
# condition 782 782
# Could not filter
# Quadratic filter...
# Filtered out 0/792, 0.0 false (nan vs 0.1)
# condition 792 792
# Could not filter
# Quadratic filter...
# Filtered out 0/802, 0.0 false (nan vs 0.1)
# condition 802 802
# Could not filter
# Quadratic filter...
# Filtered out 0/812, 0.0 false (nan vs 0.1)
# condition 812 812
# Could not filter
# Quadratic filter...
# Filtered out 0/822, 0.0 false (nan vs 0.1)
# condition 822 822
# Could not filter
# Linear filter...
# Filtered out 0/832, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/832, 0.0 false (nan vs 0.1)
# condition 832 832
# Could not filter
# Quadratic filter...
# Filtered out 0/842, 0.0 false (nan vs 0.1)
# condition 842 842
# Could not filter
# Quadratic filter...
# Filtered out 0/852, 0.0 false (nan vs 0.1)
# condition 852 852
# Could not filter
# Quadratic filter...
# Filtered out 0/862, 0.0 false (nan vs 0.1)
# condition 862 862
# Could not filter
# Quadratic filter...
# Filtered out 0/872, 0.0 false (nan vs 0.1)
# condition 872 872
# Could not filter
# Quadratic filter...
# Filtered out 0/882, 0.0 false (nan vs 0.1)
# condition 882 882
# Could not filter
# Quadratic filter...
# Filtered out 0/892, 0.0 false (nan vs 0.1)
# condition 892 892
# Could not filter
# Quadratic filter...
# Filtered out 0/902, 0.0 false (nan vs 0.1)
# condition 902 902
# Could not filter
# Quadratic filter...
# Filtered out 0/912, 0.0 false (nan vs 0.1)
# condition 912 912
# Could not filter
# Quadratic filter...
# Filtered out 0/922, 0.0 false (nan vs 0.1)
# condition 922 922
# Could not filter
# Quadratic filter...
# Filtered out 0/932, 0.0 false (nan vs 0.1)
# condition 932 932
# Could not filter
# Quadratic filter...
# Filtered out 0/942, 0.0 false (nan vs 0.1)
# condition 942 942
# Could not filter
# Quadratic filter...
# Filtered out 0/952, 0.0 false (nan vs 0.1)
# condition 952 952
# Could not filter
# Quadratic filter...
# Filtered out 0/962, 0.0 false (nan vs 0.1)
# condition 962 962
# Could not filter
# Quadratic filter...
# Filtered out 0/972, 0.0 false (nan vs 0.1)
# condition 972 972
# Could not filter
# Quadratic filter...
# Filtered out 0/982, 0.0 false (nan vs 0.1)
# condition 982 982
# Could not filter
# Quadratic filter...
# Filtered out 0/992, 0.0 false (nan vs 0.1)
# condition 992 992
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# Linear filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# condition 22 22
# Could not filter
# Quadratic filter...
# Filtered out 0/32, 0.0 false (nan vs 0.1)
# condition 32 32
# Could not filter
# Linear filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# condition 42 42
# Could not filter
# Linear filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# condition 52 52
# Could not filter
# Linear filter...
# Filtered out 0/61, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/61, 0.0 false (nan vs 0.1)
# condition 61 61
# Could not filter
# Linear filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# condition 72 72
# Could not filter
# Linear filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# condition 82 82
# Could not filter
# Linear filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# condition 92 92
# Could not filter
# Linear filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# condition 102 102
# Could not filter
# Linear filter...
# Filtered out 0/112, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/112, 0.0 false (nan vs 0.1)
# condition 112 112
# Could not filter
# Linear filter...
# Filtered out 0/122, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/122, 0.0 false (nan vs 0.1)
# condition 122 122
# Could not filter
# Linear filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# condition 132 132
# Could not filter
# Linear filter...
# Filtered out 0/142, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/142, 0.0 false (nan vs 0.1)
# condition 142 142
# Could not filter
# Linear filter...
# Filtered out 0/152, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/152, 0.0 false (nan vs 0.1)
# condition 152 152
# Could not filter
# Quadratic filter...
# Filtered out 0/162, 0.0 false (nan vs 0.1)
# condition 162 162
# Could not filter
# Linear filter...
# Filtered out 0/172, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/172, 0.0 false (nan vs 0.1)
# condition 172 172
# Could not filter
# Quadratic filter...
# Filtered out 0/182, 0.0 false (nan vs 0.1)
# condition 182 182
# Could not filter
# Linear filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# condition 192 192
# Could not filter
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# Linear filter...
# Filtered out 0/212, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/212, 0.0 false (nan vs 0.1)
# condition 212 212
# Could not filter
# Quadratic filter...
# Filtered out 0/222, 0.0 false (nan vs 0.1)
# condition 222 222
# Could not filter
# Linear filter...
# Filtered out 0/232, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/232, 0.0 false (nan vs 0.1)
# condition 232 232
# Could not filter
# Quadratic filter...
# Filtered out 0/242, 0.0 false (nan vs 0.1)
# condition 242 242
# Could not filter
# Linear filter...
# Filtered out 0/252, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/252, 0.0 false (nan vs 0.1)
# condition 252 252
# Could not filter
# Quadratic filter...
# Filtered out 0/262, 0.0 false (nan vs 0.1)
# condition 262 262
# Could not filter
# Quadratic filter...
# Filtered out 0/272, 0.0 false (nan vs 0.1)
# condition 272 272
# Could not filter
# Quadratic filter...
# Filtered out 0/282, 0.0 false (nan vs 0.1)
# condition 282 282
# Could not filter
# Quadratic filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# condition 292 292
# Could not filter
# Linear filter...
# Filtered out 0/302, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/302, 0.0 false (nan vs 0.1)
# condition 302 302
# Could not filter
# Quadratic filter...
# Filtered out 0/312, 0.0 false (nan vs 0.1)
# condition 312 312
# Could not filter
# Quadratic filter...
# Filtered out 0/322, 0.0 false (nan vs 0.1)
# condition 322 322
# Could not filter
# Quadratic filter...
# Filtered out 0/332, 0.0 false (nan vs 0.1)
# condition 332 332
# Could not filter
# Quadratic filter...
# Filtered out 0/342, 0.0 false (nan vs 0.1)
# condition 342 342
# Could not filter
# Quadratic filter...
# Filtered out 0/352, 0.0 false (nan vs 0.1)
# condition 352 352
# Could not filter
# Quadratic filter...
# Filtered out 0/362, 0.0 false (nan vs 0.1)
# condition 362 362
# Could not filter
# Quadratic filter...
# Filtered out 0/372, 0.0 false (nan vs 0.1)
# condition 372 372
# Could not filter
# Quadratic filter...
# Filtered out 0/382, 0.0 false (nan vs 0.1)
# condition 382 382
# Could not filter
# Quadratic filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# condition 392 392
# Could not filter
# Quadratic filter...
# Filtered out 0/402, 0.0 false (nan vs 0.1)
# condition 402 402
# Could not filter
# Linear filter...
# Filtered out 0/412, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/412, 0.0 false (nan vs 0.1)
# condition 412 412
# Could not filter
# Quadratic filter...
# Filtered out 0/422, 0.0 false (nan vs 0.1)
# condition 422 422
# Could not filter
# Quadratic filter...
# Filtered out 0/432, 0.0 false (nan vs 0.1)
# condition 432 432
# Could not filter
# Linear filter...
# Filtered out 0/442, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/442, 0.0 false (nan vs 0.1)
# condition 442 442
# Could not filter
# Quadratic filter...
# Filtered out 0/452, 0.0 false (nan vs 0.1)
# condition 452 452
# Could not filter
# Quadratic filter...
# Filtered out 0/462, 0.0 false (nan vs 0.1)
# condition 462 462
# Could not filter
# Quadratic filter...
# Filtered out 0/472, 0.0 false (nan vs 0.1)
# condition 472 472
# Could not filter
# Quadratic filter...
# Filtered out 0/482, 0.0 false (nan vs 0.1)
# condition 482 482
# Could not filter
# Quadratic filter...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# condition 492 492
# Could not filter
# Quadratic filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# condition 502 502
# Could not filter
# Quadratic filter...
# Filtered out 0/512, 0.0 false (nan vs 0.1)
# condition 512 512
# Could not filter
# Quadratic filter...
# Filtered out 0/522, 0.0 false (nan vs 0.1)
# condition 522 522
# Could not filter
# Quadratic filter...
# Filtered out 0/532, 0.0 false (nan vs 0.1)
# condition 532 532
# Could not filter
# Quadratic filter...
# Filtered out 0/542, 0.0 false (nan vs 0.1)
# condition 542 542
# Could not filter
# Linear filter...
# Filtered out 0/552, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/552, 0.0 false (nan vs 0.1)
# condition 552 552
# Could not filter
# Quadratic filter...
# Filtered out 0/562, 0.0 false (nan vs 0.1)
# condition 562 562
# Could not filter
# Quadratic filter...
# Filtered out 0/572, 0.0 false (nan vs 0.1)
# condition 572 572
# Could not filter
# Quadratic filter...
# Filtered out 0/582, 0.0 false (nan vs 0.1)
# condition 582 582
# Could not filter
# Quadratic filter...
# Filtered out 0/592, 0.0 false (nan vs 0.1)
# condition 592 592
# Could not filter
# Quadratic filter...
# Filtered out 0/602, 0.0 false (nan vs 0.1)
# condition 602 602
# Could not filter
# Linear filter...
# Filtered out 0/612, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/612, 0.0 false (nan vs 0.1)
# condition 612 612
# Could not filter
# Linear filter...
# Filtered out 0/622, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/622, 0.0 false (nan vs 0.1)
# condition 622 622
# Could not filter
# Quadratic filter...
# Filtered out 0/632, 0.0 false (nan vs 0.1)
# condition 632 632
# Could not filter
# Quadratic filter...
# Filtered out 0/642, 0.0 false (nan vs 0.1)
# condition 642 642
# Could not filter
# Quadratic filter...
# Filtered out 0/652, 0.0 false (nan vs 0.1)
# condition 652 652
# Could not filter
# Quadratic filter...
# Filtered out 0/661, 0.0 false (nan vs 0.1)
# condition 661 661
# Could not filter
# Quadratic filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# condition 672 672
# Could not filter
# Quadratic filter...
# Filtered out 0/682, 0.0 false (nan vs 0.1)
# condition 682 682
# Could not filter
# Quadratic filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# condition 692 692
# Could not filter
# Quadratic filter...
# Filtered out 0/702, 0.0 false (nan vs 0.1)
# condition 702 702
# Could not filter
# Quadratic filter...
# Filtered out 0/712, 0.0 false (nan vs 0.1)
# condition 712 712
# Could not filter
# Quadratic filter...
# Filtered out 0/722, 0.0 false (nan vs 0.1)
# condition 722 722
# Could not filter
# Quadratic filter...
# Filtered out 0/732, 0.0 false (nan vs 0.1)
# condition 732 732
# Could not filter
# Quadratic filter...
# Filtered out 0/742, 0.0 false (nan vs 0.1)
# condition 742 742
# Could not filter
# Quadratic filter...
# Filtered out 0/752, 0.0 false (nan vs 0.1)
# condition 752 752
# Could not filter
# Quadratic filter...
# Filtered out 0/762, 0.0 false (nan vs 0.1)
# condition 762 762
# Could not filter
# Quadratic filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# condition 772 772
# Could not filter
# Quadratic filter...
# Filtered out 0/782, 0.0 false (nan vs 0.1)
# condition 782 782
# Could not filter
# Quadratic filter...
# Filtered out 0/792, 0.0 false (nan vs 0.1)
# condition 792 792
# Could not filter
# Quadratic filter...
# Filtered out 0/802, 0.0 false (nan vs 0.1)
# condition 802 802
# Could not filter
# Quadratic filter...
# Filtered out 0/812, 0.0 false (nan vs 0.1)
# condition 812 812
# Could not filter
# Quadratic filter...
# Filtered out 0/822, 0.0 false (nan vs 0.1)
# condition 822 822
# Could not filter
# Quadratic filter...
# Filtered out 0/832, 0.0 false (nan vs 0.1)
# condition 832 832
# Could not filter
# Quadratic filter...
# Filtered out 0/842, 0.0 false (nan vs 0.1)
# condition 842 842
# Could not filter
# Quadratic filter...
# Filtered out 0/852, 0.0 false (nan vs 0.1)
# condition 852 852
# Could not filter
# Quadratic filter...
# Filtered out 0/862, 0.0 false (nan vs 0.1)
# condition 862 862
# Could not filter
# Quadratic filter...
# Filtered out 0/871, 0.0 false (nan vs 0.1)
# condition 871 871
# Could not filter
# Quadratic filter...
# Filtered out 0/882, 0.0 false (nan vs 0.1)
# condition 882 882
# Could not filter
# Quadratic filter...
# Filtered out 0/892, 0.0 false (nan vs 0.1)
# condition 892 892
# Could not filter
# Quadratic filter...
# Filtered out 0/902, 0.0 false (nan vs 0.1)
# condition 902 902
# Could not filter
# Quadratic filter...
# Filtered out 0/912, 0.0 false (nan vs 0.1)
# condition 912 912
# Could not filter
# Quadratic filter...
# Filtered out 0/922, 0.0 false (nan vs 0.1)
# condition 922 922
# Could not filter
# Quadratic filter...
# Filtered out 0/932, 0.0 false (nan vs 0.1)
# condition 932 932
# Could not filter
# Quadratic filter...
# Filtered out 0/942, 0.0 false (nan vs 0.1)
# condition 942 942
# Could not filter
# Quadratic filter...
# Filtered out 0/952, 0.0 false (nan vs 0.1)
# condition 952 952
# Could not filter
# Quadratic filter...
# Filtered out 0/962, 0.0 false (nan vs 0.1)
# condition 962 962
# Could not filter
# Quadratic filter...
# Filtered out 0/972, 0.0 false (nan vs 0.1)
# condition 972 972
# Could not filter
# Quadratic filter...
# Filtered out 0/982, 0.0 false (nan vs 0.1)
# condition 982 982
# Could not filter
# Quadratic filter...
# Filtered out 0/992, 0.0 false (nan vs 0.1)
# condition 992 992
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# Linear filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# condition 22 22
# Could not filter
# Linear filter...
# Filtered out 0/32, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/32, 0.0 false (nan vs 0.1)
# condition 32 32
# Could not filter
# Linear filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# condition 42 42
# Could not filter
# Linear filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# condition 52 52
# Could not filter
# Quadratic filter...
# Filtered out 0/62, 0.0 false (nan vs 0.1)
# condition 62 62
# Could not filter
# Quadratic filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# condition 72 72
# Could not filter
# Linear filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# condition 82 82
# Could not filter
# Linear filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# condition 92 92
# Could not filter
# Linear filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# condition 102 102
# Could not filter
# Linear filter...
# Filtered out 0/112, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/112, 0.0 false (nan vs 0.1)
# condition 112 112
# Could not filter
# Linear filter...
# Filtered out 0/122, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/122, 0.0 false (nan vs 0.1)
# condition 122 122
# Could not filter
# Linear filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# condition 132 132
# Could not filter
# Linear filter...
# Filtered out 0/142, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/142, 0.0 false (nan vs 0.1)
# condition 142 142
# Could not filter
# Quadratic filter...
# Filtered out 0/152, 0.0 false (nan vs 0.1)
# condition 152 152
# Could not filter
# Quadratic filter...
# Filtered out 0/161, 0.0 false (nan vs 0.1)
# condition 161 161
# Could not filter
# Linear filter...
# Filtered out 0/172, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/172, 0.0 false (nan vs 0.1)
# condition 172 172
# Could not filter
# Linear filter...
# Filtered out 0/182, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/182, 0.0 false (nan vs 0.1)
# condition 182 182
# Could not filter
# Linear filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# condition 192 192
# Could not filter
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# Linear filter...
# Filtered out 0/212, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/212, 0.0 false (nan vs 0.1)
# condition 212 212
# Could not filter
# Quadratic filter...
# Filtered out 0/222, 0.0 false (nan vs 0.1)
# condition 222 222
# Could not filter
# Linear filter...
# Filtered out 0/232, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/232, 0.0 false (nan vs 0.1)
# condition 232 232
# Could not filter
# Linear filter...
# Filtered out 0/241, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/241, 0.0 false (nan vs 0.1)
# condition 241 241
# Could not filter
# Linear filter...
# Filtered out 0/252, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/252, 0.0 false (nan vs 0.1)
# condition 252 252
# Could not filter
# Quadratic filter...
# Filtered out 0/262, 0.0 false (nan vs 0.1)
# condition 262 262
# Could not filter
# Quadratic filter...
# Filtered out 0/272, 0.0 false (nan vs 0.1)
# condition 272 272
# Could not filter
# Linear filter...
# Filtered out 0/282, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/282, 0.0 false (nan vs 0.1)
# condition 282 282
# Could not filter
# Quadratic filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# condition 292 292
# Could not filter
# Quadratic filter...
# Filtered out 0/302, 0.0 false (nan vs 0.1)
# condition 302 302
# Could not filter
# Linear filter...
# Filtered out 0/312, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/312, 0.0 false (nan vs 0.1)
# condition 312 312
# Could not filter
# Quadratic filter...
# Filtered out 0/322, 0.0 false (nan vs 0.1)
# condition 322 322
# Could not filter
# Quadratic filter...
# Filtered out 0/332, 0.0 false (nan vs 0.1)
# condition 332 332
# Could not filter
# Quadratic filter...
# Filtered out 0/342, 0.0 false (nan vs 0.1)
# condition 342 342
# Could not filter
# Quadratic filter...
# Filtered out 0/352, 0.0 false (nan vs 0.1)
# condition 352 352
# Could not filter
# Linear filter...
# Filtered out 0/362, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/362, 0.0 false (nan vs 0.1)
# condition 362 362
# Could not filter
# Quadratic filter...
# Filtered out 0/372, 0.0 false (nan vs 0.1)
# condition 372 372
# Could not filter
# Quadratic filter...
# Filtered out 0/382, 0.0 false (nan vs 0.1)
# condition 382 382
# Could not filter
# Quadratic filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# condition 392 392
# Could not filter
# Linear filter...
# Filtered out 0/402, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/402, 0.0 false (nan vs 0.1)
# condition 402 402
# Could not filter
# Quadratic filter...
# Filtered out 0/412, 0.0 false (nan vs 0.1)
# condition 412 412
# Could not filter
# Quadratic filter...
# Filtered out 0/422, 0.0 false (nan vs 0.1)
# condition 422 422
# Could not filter
# Quadratic filter...
# Filtered out 0/432, 0.0 false (nan vs 0.1)
# condition 432 432
# Could not filter
# Quadratic filter...
# Filtered out 0/442, 0.0 false (nan vs 0.1)
# condition 442 442
# Could not filter
# Quadratic filter...
# Filtered out 0/452, 0.0 false (nan vs 0.1)
# condition 452 452
# Could not filter
# Quadratic filter...
# Filtered out 0/462, 0.0 false (nan vs 0.1)
# condition 462 462
# Could not filter
# Quadratic filter...
# Filtered out 0/472, 0.0 false (nan vs 0.1)
# condition 472 472
# Could not filter
# Quadratic filter...
# Filtered out 0/482, 0.0 false (nan vs 0.1)
# condition 482 482
# Could not filter
# Quadratic filter...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# condition 492 492
# Could not filter
# Quadratic filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# condition 502 502
# Could not filter
# Quadratic filter...
# Filtered out 0/512, 0.0 false (nan vs 0.1)
# condition 512 512
# Could not filter
# Quadratic filter...
# Filtered out 0/522, 0.0 false (nan vs 0.1)
# condition 522 522
# Could not filter
# Quadratic filter...
# Filtered out 0/532, 0.0 false (nan vs 0.1)
# condition 532 532
# Could not filter
# Quadratic filter...
# Filtered out 0/542, 0.0 false (nan vs 0.1)
# condition 542 542
# Could not filter
# Quadratic filter...
# Filtered out 0/552, 0.0 false (nan vs 0.1)
# condition 552 552
# Could not filter
# Quadratic filter...
# Filtered out 0/562, 0.0 false (nan vs 0.1)
# condition 562 562
# Could not filter
# Quadratic filter...
# Filtered out 0/572, 0.0 false (nan vs 0.1)
# condition 572 572
# Could not filter
# Quadratic filter...
# Filtered out 0/582, 0.0 false (nan vs 0.1)
# condition 582 582
# Could not filter
# Quadratic filter...
# Filtered out 0/592, 0.0 false (nan vs 0.1)
# condition 592 592
# Could not filter
# Quadratic filter...
# Filtered out 0/602, 0.0 false (nan vs 0.1)
# condition 602 602
# Could not filter
# Quadratic filter...
# Filtered out 0/612, 0.0 false (nan vs 0.1)
# condition 612 612
# Could not filter
# Quadratic filter...
# Filtered out 0/622, 0.0 false (nan vs 0.1)
# condition 622 622
# Could not filter
# Quadratic filter...
# Filtered out 0/632, 0.0 false (nan vs 0.1)
# condition 632 632
# Could not filter
# Quadratic filter...
# Filtered out 0/642, 0.0 false (nan vs 0.1)
# condition 642 642
# Could not filter
# Quadratic filter...
# Filtered out 0/652, 0.0 false (nan vs 0.1)
# condition 652 652
# Could not filter
# Quadratic filter...
# Filtered out 0/662, 0.0 false (nan vs 0.1)
# condition 662 662
# Could not filter
# Linear filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# condition 672 672
# Could not filter
# Quadratic filter...
# Filtered out 0/682, 0.0 false (nan vs 0.1)
# condition 682 682
# Could not filter
# Quadratic filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# condition 692 692
# Could not filter
# Quadratic filter...
# Filtered out 0/702, 0.0 false (nan vs 0.1)
# condition 702 702
# Could not filter
# Quadratic filter...
# Filtered out 0/712, 0.0 false (nan vs 0.1)
# condition 712 712
# Could not filter
# Quadratic filter...
# Filtered out 0/722, 0.0 false (nan vs 0.1)
# condition 722 722
# Could not filter
# Quadratic filter...
# Filtered out 0/732, 0.0 false (nan vs 0.1)
# condition 732 732
# Could not filter
# Quadratic filter...
# Filtered out 0/742, 0.0 false (nan vs 0.1)
# condition 742 742
# Could not filter
# Quadratic filter...
# Filtered out 0/752, 0.0 false (nan vs 0.1)
# condition 752 752
# Could not filter
# Quadratic filter...
# Filtered out 0/762, 0.0 false (nan vs 0.1)
# condition 762 762
# Could not filter
# Linear filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# condition 772 772
# Could not filter
# Quadratic filter...
# Filtered out 0/782, 0.0 false (nan vs 0.1)
# condition 782 782
# Could not filter
# Quadratic filter...
# Filtered out 0/792, 0.0 false (nan vs 0.1)
# condition 792 792
# Could not filter
# Quadratic filter...
# Filtered out 0/802, 0.0 false (nan vs 0.1)
# condition 802 802
# Could not filter
# Quadratic filter...
# Filtered out 0/812, 0.0 false (nan vs 0.1)
# condition 812 812
# Could not filter
# Quadratic filter...
# Filtered out 0/822, 0.0 false (nan vs 0.1)
# condition 822 822
# Could not filter
# Quadratic filter...
# Filtered out 0/832, 0.0 false (nan vs 0.1)
# condition 832 832
# Could not filter
# Quadratic filter...
# Filtered out 0/842, 0.0 false (nan vs 0.1)
# condition 842 842
# Could not filter
# Quadratic filter...
# Filtered out 0/852, 0.0 false (nan vs 0.1)
# condition 852 852
# Could not filter
# Quadratic filter...
# Filtered out 0/862, 0.0 false (nan vs 0.1)
# condition 862 862
# Could not filter
# Quadratic filter...
# Filtered out 0/872, 0.0 false (nan vs 0.1)
# condition 872 872
# Could not filter
# Quadratic filter...
# Filtered out 0/882, 0.0 false (nan vs 0.1)
# condition 882 882
# Could not filter
# Quadratic filter...
# Filtered out 0/892, 0.0 false (nan vs 0.1)
# condition 892 892
# Could not filter
# Quadratic filter...
# Filtered out 0/902, 0.0 false (nan vs 0.1)
# condition 902 902
# Could not filter
# Quadratic filter...
# Filtered out 0/912, 0.0 false (nan vs 0.1)
# condition 912 912
# Could not filter
# Quadratic filter...
# Filtered out 0/922, 0.0 false (nan vs 0.1)
# condition 922 922
# Could not filter
# Quadratic filter...
# Filtered out 0/932, 0.0 false (nan vs 0.1)
# condition 932 932
# Could not filter
# Quadratic filter...
# Filtered out 0/942, 0.0 false (nan vs 0.1)
# condition 942 942
# Could not filter
# Quadratic filter...
# Filtered out 0/952, 0.0 false (nan vs 0.1)
# condition 952 952
# Could not filter
# Quadratic filter...
# Filtered out 0/962, 0.0 false (nan vs 0.1)
# condition 962 962
# Could not filter
# Quadratic filter...
# Filtered out 0/972, 0.0 false (nan vs 0.1)
# condition 972 972
# Could not filter
# Quadratic filter...
# Filtered out 0/982, 0.0 false (nan vs 0.1)
# condition 982 982
# Could not filter
# Quadratic filter...
# Filtered out 0/992, 0.0 false (nan vs 0.1)
# condition 992 992
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# Linear filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# condition 22 22
# Could not filter
# Linear filter...
# Filtered out 0/31, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/31, 0.0 false (nan vs 0.1)
# condition 31 31
# Could not filter
# Quadratic filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# condition 42 42
# Could not filter
# Linear filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# condition 52 52
# Could not filter
# Linear filter...
# Filtered out 0/62, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/62, 0.0 false (nan vs 0.1)
# condition 62 62
# Could not filter
# Linear filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# condition 72 72
# Could not filter
# Linear filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# condition 82 82
# Could not filter
# Linear filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# condition 92 92
# Could not filter
# Linear filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# condition 102 102
# Could not filter
# Quadratic filter...
# Filtered out 0/112, 0.0 false (nan vs 0.1)
# condition 112 112
# Could not filter
# Linear filter...
# Filtered out 0/122, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/122, 0.0 false (nan vs 0.1)
# condition 122 122
# Could not filter
# Linear filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# condition 132 132
# Could not filter
# Quadratic filter...
# Filtered out 0/142, 0.0 false (nan vs 0.1)
# condition 142 142
# Could not filter
# Quadratic filter...
# Filtered out 0/152, 0.0 false (nan vs 0.1)
# condition 152 152
# Could not filter
# Linear filter...
# Filtered out 0/162, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/162, 0.0 false (nan vs 0.1)
# condition 162 162
# Could not filter
# Linear filter...
# Filtered out 0/172, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/172, 0.0 false (nan vs 0.1)
# condition 172 172
# Could not filter
# Quadratic filter...
# Filtered out 0/182, 0.0 false (nan vs 0.1)
# condition 182 182
# Could not filter
# Quadratic filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# condition 192 192
# Could not filter
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# Quadratic filter...
# Filtered out 0/212, 0.0 false (nan vs 0.1)
# condition 212 212
# Could not filter
# Linear filter...
# Filtered out 0/222, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/222, 0.0 false (nan vs 0.1)
# condition 222 222
# Could not filter
# Linear filter...
# Filtered out 0/232, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/232, 0.0 false (nan vs 0.1)
# condition 232 232
# Could not filter
# Linear filter...
# Filtered out 0/242, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/242, 0.0 false (nan vs 0.1)
# condition 242 242
# Could not filter
# Linear filter...
# Filtered out 0/252, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/252, 0.0 false (nan vs 0.1)
# condition 252 252
# Could not filter
# Quadratic filter...
# Filtered out 0/261, 0.0 false (nan vs 0.1)
# condition 261 261
# Could not filter
# Quadratic filter...
# Filtered out 0/272, 0.0 false (nan vs 0.1)
# condition 272 272
# Could not filter
# Quadratic filter...
# Filtered out 0/282, 0.0 false (nan vs 0.1)
# condition 282 282
# Could not filter
# Linear filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# condition 292 292
# Could not filter
# Quadratic filter...
# Filtered out 0/302, 0.0 false (nan vs 0.1)
# condition 302 302
# Could not filter
# Quadratic filter...
# Filtered out 0/312, 0.0 false (nan vs 0.1)
# condition 312 312
# Could not filter
# Quadratic filter...
# Filtered out 0/322, 0.0 false (nan vs 0.1)
# condition 322 322
# Could not filter
# Quadratic filter...
# Filtered out 0/332, 0.0 false (nan vs 0.1)
# condition 332 332
# Could not filter
# Quadratic filter...
# Filtered out 0/342, 0.0 false (nan vs 0.1)
# condition 342 342
# Could not filter
# Linear filter...
# Filtered out 0/352, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/352, 0.0 false (nan vs 0.1)
# condition 352 352
# Could not filter
# Quadratic filter...
# Filtered out 0/362, 0.0 false (nan vs 0.1)
# condition 362 362
# Could not filter
# Quadratic filter...
# Filtered out 0/372, 0.0 false (nan vs 0.1)
# condition 372 372
# Could not filter
# Quadratic filter...
# Filtered out 0/382, 0.0 false (nan vs 0.1)
# condition 382 382
# Could not filter
# Quadratic filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# condition 392 392
# Could not filter
# Quadratic filter...
# Filtered out 0/402, 0.0 false (nan vs 0.1)
# condition 402 402
# Could not filter
# Quadratic filter...
# Filtered out 0/412, 0.0 false (nan vs 0.1)
# condition 412 412
# Could not filter
# Linear filter...
# Filtered out 0/422, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/422, 0.0 false (nan vs 0.1)
# condition 422 422
# Could not filter
# Quadratic filter...
# Filtered out 0/432, 0.0 false (nan vs 0.1)
# condition 432 432
# Could not filter
# Quadratic filter...
# Filtered out 0/442, 0.0 false (nan vs 0.1)
# condition 442 442
# Could not filter
# Quadratic filter...
# Filtered out 0/452, 0.0 false (nan vs 0.1)
# condition 452 452
# Could not filter
# Quadratic filter...
# Filtered out 0/462, 0.0 false (nan vs 0.1)
# condition 462 462
# Could not filter
# Quadratic filter...
# Filtered out 0/472, 0.0 false (nan vs 0.1)
# condition 472 472
# Could not filter
# Quadratic filter...
# Filtered out 0/482, 0.0 false (nan vs 0.1)
# condition 482 482
# Could not filter
# Quadratic filter...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# condition 492 492
# Could not filter
# Quadratic filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# condition 502 502
# Could not filter
# Quadratic filter...
# Filtered out 0/512, 0.0 false (nan vs 0.1)
# condition 512 512
# Could not filter
# Quadratic filter...
# Filtered out 0/522, 0.0 false (nan vs 0.1)
# condition 522 522
# Could not filter
# Quadratic filter...
# Filtered out 0/532, 0.0 false (nan vs 0.1)
# condition 532 532
# Could not filter
# Quadratic filter...
# Filtered out 0/542, 0.0 false (nan vs 0.1)
# condition 542 542
# Could not filter
# Quadratic filter...
# Filtered out 0/552, 0.0 false (nan vs 0.1)
# condition 552 552
# Could not filter
# Quadratic filter...
# Filtered out 0/562, 0.0 false (nan vs 0.1)
# condition 562 562
# Could not filter
# Quadratic filter...
# Filtered out 0/571, 0.0 false (nan vs 0.1)
# condition 571 571
# Could not filter
# Quadratic filter...
# Filtered out 0/582, 0.0 false (nan vs 0.1)
# condition 582 582
# Could not filter
# Quadratic filter...
# Filtered out 0/592, 0.0 false (nan vs 0.1)
# condition 592 592
# Could not filter
# Quadratic filter...
# Filtered out 0/602, 0.0 false (nan vs 0.1)
# condition 602 602
# Could not filter
# Quadratic filter...
# Filtered out 0/612, 0.0 false (nan vs 0.1)
# condition 612 612
# Could not filter
# Quadratic filter...
# Filtered out 0/622, 0.0 false (nan vs 0.1)
# condition 622 622
# Could not filter
# Quadratic filter...
# Filtered out 0/632, 0.0 false (nan vs 0.1)
# condition 632 632
# Could not filter
# Quadratic filter...
# Filtered out 0/642, 0.0 false (nan vs 0.1)
# condition 642 642
# Could not filter
# Linear filter...
# Filtered out 0/652, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/652, 0.0 false (nan vs 0.1)
# condition 652 652
# Could not filter
# Quadratic filter...
# Filtered out 0/662, 0.0 false (nan vs 0.1)
# condition 662 662
# Could not filter
# Quadratic filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# condition 672 672
# Could not filter
# Quadratic filter...
# Filtered out 0/682, 0.0 false (nan vs 0.1)
# condition 682 682
# Could not filter
# Quadratic filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# condition 692 692
# Could not filter
# Quadratic filter...
# Filtered out 0/702, 0.0 false (nan vs 0.1)
# condition 702 702
# Could not filter
# Quadratic filter...
# Filtered out 0/712, 0.0 false (nan vs 0.1)
# condition 712 712
# Could not filter
# Quadratic filter...
# Filtered out 0/722, 0.0 false (nan vs 0.1)
# condition 722 722
# Could not filter
# Quadratic filter...
# Filtered out 0/732, 0.0 false (nan vs 0.1)
# condition 732 732
# Could not filter
# Quadratic filter...
# Filtered out 0/742, 0.0 false (nan vs 0.1)
# condition 742 742
# Could not filter
# Quadratic filter...
# Filtered out 0/752, 0.0 false (nan vs 0.1)
# condition 752 752
# Could not filter
# Quadratic filter...
# Filtered out 0/762, 0.0 false (nan vs 0.1)
# condition 762 762
# Could not filter
# Linear filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# condition 772 772
# Could not filter
# Quadratic filter...
# Filtered out 0/782, 0.0 false (nan vs 0.1)
# condition 782 782
# Could not filter
# Quadratic filter...
# Filtered out 0/792, 0.0 false (nan vs 0.1)
# condition 792 792
# Could not filter
# Quadratic filter...
# Filtered out 0/802, 0.0 false (nan vs 0.1)
# condition 802 802
# Could not filter
# Quadratic filter...
# Filtered out 0/812, 0.0 false (nan vs 0.1)
# condition 812 812
# Could not filter
# Quadratic filter...
# Filtered out 0/822, 0.0 false (nan vs 0.1)
# condition 822 822
# Could not filter
# Quadratic filter...
# Filtered out 0/832, 0.0 false (nan vs 0.1)
# condition 832 832
# Could not filter
# Quadratic filter...
# Filtered out 0/842, 0.0 false (nan vs 0.1)
# condition 842 842
# Could not filter
# Quadratic filter...
# Filtered out 0/852, 0.0 false (nan vs 0.1)
# condition 852 852
# Could not filter
# Quadratic filter...
# Filtered out 0/862, 0.0 false (nan vs 0.1)
# condition 862 862
# Could not filter
# Quadratic filter...
# Filtered out 0/872, 0.0 false (nan vs 0.1)
# condition 872 872
# Could not filter
# Quadratic filter...
# Filtered out 0/882, 0.0 false (nan vs 0.1)
# condition 882 882
# Could not filter
# Quadratic filter...
# Filtered out 0/892, 0.0 false (nan vs 0.1)
# condition 892 892
# Could not filter
# Quadratic filter...
# Filtered out 0/902, 0.0 false (nan vs 0.1)
# condition 902 902
# Could not filter
# Quadratic filter...
# Filtered out 0/912, 0.0 false (nan vs 0.1)
# condition 912 912
# Could not filter
# Quadratic filter...
# Filtered out 0/922, 0.0 false (nan vs 0.1)
# condition 922 922
# Could not filter
# Quadratic filter...
# Filtered out 0/932, 0.0 false (nan vs 0.1)
# condition 932 932
# Could not filter
# Quadratic filter...
# Filtered out 0/942, 0.0 false (nan vs 0.1)
# condition 942 942
# Could not filter
# Quadratic filter...
# Filtered out 0/952, 0.0 false (nan vs 0.1)
# condition 952 952
# Could not filter
# Quadratic filter...
# Filtered out 0/962, 0.0 false (nan vs 0.1)
# condition 962 962
# Could not filter
# Quadratic filter...
# Filtered out 0/972, 0.0 false (nan vs 0.1)
# condition 972 972
# Could not filter
# Quadratic filter...
# Filtered out 0/982, 0.0 false (nan vs 0.1)
# condition 982 982
# Could not filter
# Quadratic filter...
# Filtered out 0/992, 0.0 false (nan vs 0.1)
# condition 992 992
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# Linear filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# condition 22 22
# Could not filter
# Linear filter...
# Filtered out 0/31, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/31, 0.0 false (nan vs 0.1)
# condition 31 31
# Could not filter
# Linear filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# condition 42 42
# Could not filter
# Linear filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# condition 52 52
# Could not filter
# Linear filter...
# Filtered out 0/62, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/62, 0.0 false (nan vs 0.1)
# condition 62 62
# Could not filter
# Linear filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# condition 72 72
# Could not filter
# Linear filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# condition 82 82
# Could not filter
# Linear filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# condition 92 92
# Could not filter
# Linear filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# condition 102 102
# Could not filter
# Quadratic filter...
# Filtered out 0/112, 0.0 false (nan vs 0.1)
# condition 112 112
# Could not filter
# Linear filter...
# Filtered out 0/121, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/121, 0.0 false (nan vs 0.1)
# condition 121 121
# Could not filter
# Linear filter...
# ...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# condition 492 492
# Could not filter
# Quadratic filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# condition 502 502
# Could not filter
# Quadratic filter...
# Filtered out 0/512, 0.0 false (nan vs 0.1)
# condition 512 512
# Could not filter
# Quadratic filter...
# Filtered out 0/522, 0.0 false (nan vs 0.1)
# condition 522 522
# Could not filter
# Quadratic filter...
# Filtered out 0/532, 0.0 false (nan vs 0.1)
# condition 532 532
# Could not filter
# Quadratic filter...
# Filtered out 0/542, 0.0 false (nan vs 0.1)
# condition 542 542
# Could not filter
# Quadratic filter...
# Filtered out 0/552, 0.0 false (nan vs 0.1)
# condition 552 552
# Could not filter
# Quadratic filter...
# Filtered out 0/562, 0.0 false (nan vs 0.1)
# condition 562 562
# Could not filter
# Quadratic filter...
# Filtered out 0/572, 0.0 false (nan vs 0.1)
# condition 572 572
# Could not filter
# Quadratic filter...
# Filtered out 0/582, 0.0 false (nan vs 0.1)
# condition 582 582
# Could not filter
# Quadratic filter...
# Filtered out 0/592, 0.0 false (nan vs 0.1)
# condition 592 592
# Could not filter
# Quadratic filter...
# Filtered out 0/602, 0.0 false (nan vs 0.1)
# condition 602 602
# Could not filter
# Quadratic filter...
# Filtered out 0/612, 0.0 false (nan vs 0.1)
# condition 612 612
# Could not filter
# Quadratic filter...
# Filtered out 0/622, 0.0 false (nan vs 0.1)
# condition 622 622
# Could not filter
# Quadratic filter...
# Filtered out 0/632, 0.0 false (nan vs 0.1)
# condition 632 632
# Could not filter
# Quadratic filter...
# Filtered out 0/642, 0.0 false (nan vs 0.1)
# condition 642 642
# Could not filter
# Quadratic filter...
# Filtered out 0/652, 0.0 false (nan vs 0.1)
# condition 652 652
# Could not filter
# Quadratic filter...
# Filtered out 0/662, 0.0 false (nan vs 0.1)
# condition 662 662
# Could not filter
# Quadratic filter...
# Filtered out 0/671, 0.0 false (nan vs 0.1)
# condition 671 671
# Could not filter
# Quadratic filter...
# Filtered out 0/682, 0.0 false (nan vs 0.1)
# condition 682 682
# Could not filter
# Quadratic filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# condition 692 692
# Could not filter
# Quadratic filter...
# Filtered out 0/702, 0.0 false (nan vs 0.1)
# condition 702 702
# Could not filter
# Quadratic filter...
# Filtered out 0/712, 0.0 false (nan vs 0.1)
# condition 712 712
# Could not filter
# Quadratic filter...
# Filtered out 0/722, 0.0 false (nan vs 0.1)
# condition 722 722
# Could not filter
# Quadratic filter...
# Filtered out 0/732, 0.0 false (nan vs 0.1)
# condition 732 732
# Could not filter
# Quadratic filter...
# Filtered out 0/742, 0.0 false (nan vs 0.1)
# condition 742 742
# Could not filter
# Quadratic filter...
# Filtered out 0/752, 0.0 false (nan vs 0.1)
# condition 752 752
# Could not filter
# Quadratic filter...
# Filtered out 0/762, 0.0 false (nan vs 0.1)
# condition 762 762
# Could not filter
# Quadratic filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# condition 772 772
# Could not filter
# Quadratic filter...
# Filtered out 0/782, 0.0 false (nan vs 0.1)
# condition 782 782
# Could not filter
# Quadratic filter...
# Filtered out 0/792, 0.0 false (nan vs 0.1)
# condition 792 792
# Could not filter
# Linear filter...
# Filtered out 0/802, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/802, 0.0 false (nan vs 0.1)
# condition 802 802
# Could not filter
# Quadratic filter...
# Filtered out 0/812, 0.0 false (nan vs 0.1)
# condition 812 812
# Could not filter
# Quadratic filter...
# Filtered out 0/822, 0.0 false (nan vs 0.1)
# condition 822 822
# Could not filter
# Quadratic filter...
# Filtered out 0/832, 0.0 false (nan vs 0.1)
# condition 832 832
# Could not filter
# Quadratic filter...
# Filtered out 0/842, 0.0 false (nan vs 0.1)
# condition 842 842
# Could not filter
# Quadratic filter...
# Filtered out 0/852, 0.0 false (nan vs 0.1)
# condition 852 852
# Could not filter
# Quadratic filter...
# Filtered out 0/862, 0.0 false (nan vs 0.1)
# condition 862 862
# Could not filter
# Quadratic filter...
# Filtered out 0/872, 0.0 false (nan vs 0.1)
# condition 872 872
# Could not filter
# Quadratic filter...
# Filtered out 0/882, 0.0 false (nan vs 0.1)
# condition 882 882
# Could not filter
# Quadratic filter...
# Filtered out 0/892, 0.0 false (nan vs 0.1)
# condition 892 892
# Could not filter
# Quadratic filter...
# Filtered out 0/902, 0.0 false (nan vs 0.1)
# condition 902 902
# Could not filter
# Quadratic filter...
# Filtered out 0/912, 0.0 false (nan vs 0.1)
# condition 912 912
# Could not filter
# Quadratic filter...
# Filtered out 0/922, 0.0 false (nan vs 0.1)
# condition 922 922
# Could not filter
# Quadratic filter...
# Filtered out 0/932, 0.0 false (nan vs 0.1)
# condition 932 932
# Could not filter
# Quadratic filter...
# Filtered out 0/942, 0.0 false (nan vs 0.1)
# condition 942 942
# Could not filter
# Quadratic filter...
# Filtered out 0/952, 0.0 false (nan vs 0.1)
# condition 952 952
# Could not filter
# Quadratic filter...
# Filtered out 0/962, 0.0 false (nan vs 0.1)
# condition 962 962
# Could not filter
# Quadratic filter...
# Filtered out 0/972, 0.0 false (nan vs 0.1)
# condition 972 972
# Could not filter
# Quadratic filter...
# Filtered out 0/982, 0.0 false (nan vs 0.1)
# condition 982 982
# Could not filter
# Quadratic filter...
# Filtered out 0/992, 0.0 false (nan vs 0.1)
# condition 992 992
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/12, 0.0 false (nan vs 0.1)
# condition 12 12
# Could not filter
# Linear filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/22, 0.0 false (nan vs 0.1)
# condition 22 22
# Could not filter
# Linear filter...
# Filtered out 0/31, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/31, 0.0 false (nan vs 0.1)
# condition 31 31
# Could not filter
# Linear filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/42, 0.0 false (nan vs 0.1)
# condition 42 42
# Could not filter
# Linear filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/52, 0.0 false (nan vs 0.1)
# condition 52 52
# Could not filter
# Quadratic filter...
# Filtered out 0/62, 0.0 false (nan vs 0.1)
# condition 62 62
# Could not filter
# Linear filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/72, 0.0 false (nan vs 0.1)
# condition 72 72
# Could not filter
# Linear filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/82, 0.0 false (nan vs 0.1)
# condition 82 82
# Could not filter
# Linear filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/92, 0.0 false (nan vs 0.1)
# condition 92 92
# Could not filter
# Linear filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# condition 102 102
# Could not filter
# Quadratic filter...
# Filtered out 0/112, 0.0 false (nan vs 0.1)
# condition 112 112
# Could not filter
# Quadratic filter...
# Filtered out 0/122, 0.0 false (nan vs 0.1)
# condition 122 122
# Could not filter
# Linear filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/132, 0.0 false (nan vs 0.1)
# condition 132 132
# Could not filter
# Linear filter...
# Filtered out 0/142, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/142, 0.0 false (nan vs 0.1)
# condition 142 142
# Could not filter
# Quadratic filter...
# Filtered out 0/152, 0.0 false (nan vs 0.1)
# condition 152 152
# Could not filter
# Linear filter...
# Filtered out 0/162, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/162, 0.0 false (nan vs 0.1)
# condition 162 162
# Could not filter
# Quadratic filter...
# Filtered out 0/172, 0.0 false (nan vs 0.1)
# condition 172 172
# Could not filter
# Quadratic filter...
# Filtered out 0/182, 0.0 false (nan vs 0.1)
# condition 182 182
# Could not filter
# Quadratic filter...
# Filtered out 0/192, 0.0 false (nan vs 0.1)
# condition 192 192
# Could not filter
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# Quadratic filter...
# Filtered out 0/212, 0.0 false (nan vs 0.1)
# condition 212 212
# Could not filter
# Quadratic filter...
# Filtered out 0/222, 0.0 false (nan vs 0.1)
# condition 222 222
# Could not filter
# Quadratic filter...
# Filtered out 0/232, 0.0 false (nan vs 0.1)
# condition 232 232
# Could not filter
# Linear filter...
# Filtered out 0/242, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/242, 0.0 false (nan vs 0.1)
# condition 242 242
# Could not filter
# Quadratic filter...
# Filtered out 0/252, 0.0 false (nan vs 0.1)
# condition 252 252
# Could not filter
# Quadratic filter...
# Filtered out 0/262, 0.0 false (nan vs 0.1)
# condition 262 262
# Could not filter
# Linear filter...
# Filtered out 0/272, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/272, 0.0 false (nan vs 0.1)
# condition 272 272
# Could not filter
# Linear filter...
# Filtered out 0/282, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/282, 0.0 false (nan vs 0.1)
# condition 282 282
# Could not filter
# Quadratic filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# condition 292 292
# Could not filter
# Linear filter...
# Filtered out 0/302, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/302, 0.0 false (nan vs 0.1)
# condition 302 302
# Could not filter
# Quadratic filter...
# Filtered out 0/312, 0.0 false (nan vs 0.1)
# condition 312 312
# Could not filter
# Linear filter...
# Filtered out 0/322, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/322, 0.0 false (nan vs 0.1)
# condition 322 322
# Could not filter
# Linear filter...
# Filtered out 0/332, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/332, 0.0 false (nan vs 0.1)
# condition 332 332
# Could not filter
# Quadratic filter...
# Filtered out 0/342, 0.0 false (nan vs 0.1)
# condition 342 342
# Could not filter
# Quadratic filter...
# Filtered out 0/352, 0.0 false (nan vs 0.1)
# condition 352 352
# Could not filter
# Quadratic filter...
# Filtered out 0/362, 0.0 false (nan vs 0.1)
# condition 362 362
# Could not filter
# Quadratic filter...
# Filtered out 0/372, 0.0 false (nan vs 0.1)
# condition 372 372
# Could not filter
# Quadratic filter...
# Filtered out 0/382, 0.0 false (nan vs 0.1)
# condition 382 382
# Could not filter
# Quadratic filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# condition 392 392
# Could not filter
# Quadratic filter...
# Filtered out 0/402, 0.0 false (nan vs 0.1)
# condition 402 402
# Could not filter
# Quadratic filter...
# Filtered out 0/412, 0.0 false (nan vs 0.1)
# condition 412 412
# Could not filter
# Quadratic filter...
# Filtered out 0/422, 0.0 false (nan vs 0.1)
# condition 422 422
# Could not filter
# Quadratic filter...
# Filtered out 0/432, 0.0 false (nan vs 0.1)
# condition 432 432
# Could not filter
# Quadratic filter...
# Filtered out 0/442, 0.0 false (nan vs 0.1)
# condition 442 442
# Could not filter
# Quadratic filter...
# Filtered out 0/452, 0.0 false (nan vs 0.1)
# condition 452 452
# Could not filter
# Quadratic filter...
# Filtered out 0/462, 0.0 false (nan vs 0.1)
# condition 462 462
# Could not filter
# Quadratic filter...
# Filtered out 0/472, 0.0 false (nan vs 0.1)
# condition 472 472
# Could not filter
# Quadratic filter...
# Filtered out 0/482, 0.0 false (nan vs 0.1)
# condition 482 482
# Could not filter
# Quadratic filter...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# condition 492 492
# Could not filter
# Quadratic filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# condition 502 502
# Could not filter
# Quadratic filter...
# Filtered out 0/512, 0.0 false (nan vs 0.1)
# condition 512 512
# Could not filter
# Quadratic filter...
# Filtered out 0/522, 0.0 false (nan vs 0.1)
# condition 522 522
# Could not filter
# Quadratic filter...
# Filtered out 0/532, 0.0 false (nan vs 0.1)
# condition 532 532
# Could not filter
# Quadratic filter...
# Filtered out 0/542, 0.0 false (nan vs 0.1)
# condition 542 542
# Could not filter
# Quadratic filter...
# Filtered out 0/552, 0.0 false (nan vs 0.1)
# condition 552 552
# Could not filter
# Linear filter...
# Filtered out 0/562, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/562, 0.0 false (nan vs 0.1)
# condition 562 562
# Could not filter
# Quadratic filter...
# Filtered out 0/572, 0.0 false (nan vs 0.1)
# condition 572 572
# Could not filter
# Quadratic filter...
# Filtered out 0/582, 0.0 false (nan vs 0.1)
# condition 582 582
# Could not filter
# Quadratic filter...
# Filtered out 0/592, 0.0 false (nan vs 0.1)
# condition 592 592
# Could not filter
# Quadratic filter...
# Filtered out 0/602, 0.0 false (nan vs 0.1)
# condition 602 602
# Could not filter
# Quadratic filter...
# Filtered out 0/612, 0.0 false (nan vs 0.1)
# condition 612 612
# Could not filter
# Quadratic filter...
# Filtered out 0/622, 0.0 false (nan vs 0.1)
# condition 622 622
# Could not filter
# Quadratic filter...
# Filtered out 0/632, 0.0 false (nan vs 0.1)
# condition 632 632
# Could not filter
# Quadratic filter...
# Filtered out 0/642, 0.0 false (nan vs 0.1)
# condition 642 642
# Could not filter
# Quadratic filter...
# Filtered out 0/652, 0.0 false (nan vs 0.1)
# condition 652 652
# Could not filter
# Quadratic filter...
# Filtered out 0/662, 0.0 false (nan vs 0.1)
# condition 662 662
# Could not filter
# Quadratic filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# condition 672 672
# Could not filter
# Quadratic filter...
# Filtered out 0/682, 0.0 false (nan vs 0.1)
# condition 682 682
# Could not filter
# Quadratic filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# condition 692 692
# Could not filter
# Quadratic filter...
# Filtered out 0/702, 0.0 false (nan vs 0.1)
# condition 702 702
# Could not filter
# Quadratic filter...
# Filtered out 0/712, 0.0 false (nan vs 0.1)
# condition 712 712
# Could not filter
# Quadratic filter...
# Filtered out 0/722, 0.0 false (nan vs 0.1)
# condition 722 722
# Could not filter
# Quadratic filter...
# Filtered out 0/732, 0.0 false (nan vs 0.1)
# condition 732 732
# Could not filter
# Quadratic filter...
# Filtered out 0/742, 0.0 false (nan vs 0.1)
# condition 742 742
# Could not filter
# Quadratic filter...
# Filtered out 0/752, 0.0 false (nan vs 0.1)
# condition 752 752
# Could not filter
# Quadratic filter...
# Filtered out 0/762, 0.0 false (nan vs 0.1)
# condition 762 762
# Could not filter
# Quadratic filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# condition 772 772
# Could not filter
# Quadratic filter...
# Filtered out 0/782, 0.0 false (nan vs 0.1)
# condition 782 782
# Could not filter
# Quadratic filter...
# Filtered out 0/792, 0.0 false (nan vs 0.1)
# condition 792 792
# Could not filter
# Quadratic filter...
# Filtered out 0/802, 0.0 false (nan vs 0.1)
# condition 802 802
# Could not filter
# Quadratic filter...
# Filtered out 0/812, 0.0 false (nan vs 0.1)
# condition 812 812
# Could not filter
# Quadratic filter...
# Filtered out 0/822, 0.0 false (nan vs 0.1)
# condition 822 822
# Could not filter
# Quadratic filter...
# Filtered out 0/832, 0.0 false (nan vs 0.1)
# condition 832 832
# Could not filter
# Quadratic filter...
# Filtered out 0/842, 0.0 false (nan vs 0.1)
# condition 842 842
# Could not filter
# Quadratic filter...
# Filtered out 0/852, 0.0 false (nan vs 0.1)
# condition 852 852
# Could not filter
# Quadratic filter...
# Filtered out 0/862, 0.0 false (nan vs 0.1)
# condition 862 862
# Could not filter
# Quadratic filter...
# Filtered out 0/872, 0.0 false (nan vs 0.1)
# condition 872 872
# Could not filter
# Quadratic filter...
# Filtered out 0/882, 0.0 false (nan vs 0.1)
# condition 882 882
# Could not filter
# Quadratic filter...
# Filtered out 0/892, 0.0 false (nan vs 0.1)
# condition 892 892
# Could not filter
# Quadratic filter...
# Filtered out 0/902, 0.0 false (nan vs 0.1)
# condition 902 902
# Could not filter
# Quadratic filter...
# Filtered out 0/912, 0.0 false (nan vs 0.1)
# condition 912 912
# Could not filter
# Quadratic filter...
# Filtered out 0/922, 0.0 false (nan vs 0.1)
# condition 922 922
# Could not filter
# Quadratic filter...
# Filtered out 0/932, 0.0 false (nan vs 0.1)
# condition 932 932
# Could not filter
# Quadratic filter...
# Filtered out 0/942, 0.0 false (nan vs 0.1)
# condition 942 942
# Could not filter
# Quadratic filter...
# Filtered out 0/952, 0.0 false (nan vs 0.1)
# condition 952 952
# Could not filter
# Quadratic filter...
# Filtered out 0/962, 0.0 false (nan vs 0.1)
# condition 962 962
# Could not filter
# Quadratic filter...
# Filtered out 0/972, 0.0 false (nan vs 0.1)
# condition 972 972
# Could not filter
# Quadratic filter...
# Filtered out 0/982, 0.0 false (nan vs 0.1)
# condition 982 982
# Could not filter
# Quadratic filter...
# Filtered out 0/992, 0.0 false (nan vs 0.1)
# condition 992 992
# Could not filter

# %%
outputfilename_rsm1 = 'self_out/tflipping-loss-vs-k.pdf'

title_rsm1 = 'd = {d}, k = {k}, eps = {eps}. Noise is tail-flipping.'.format(d=d_rsm1,k=k_rsm1,eps=eps_rsm1)
xlabel_rsm1 = 'm'
ylabel_rsm1 = 'L2 Loss'
plot_m_loss_rsm1_plt = rl.plot_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)


plot_m_loss_rsm1_plt.plotxy_fromfile(outputfilename_rsm1, inputfilename_rsm1,'m', m_bounds_rsm1, (0, 0.8), title_rsm1, xlabel_rsm1, ylabel_rsm1, figsize = figsize, fontname = fontname, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el427615753525280481537678"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el427615753525280481537678", {"width": 800.0, "height": 400.0, "axes": [], "data": {}, "id": "el427615753525280", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#          mpld3.draw_figure("fig_el427615753525280481537678", {"width": 800.0, "height": 400.0, "axes": [], "data": {}, "id": "el427615753525280", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://d3js.org/d3.v5.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#                  mpld3.draw_figure("fig_el427615753525280481537678", {"width": 800.0, "height": 400.0, "axes": [], "data": {}, "id": "el427615753525280", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>
