# %%
import numpy as np
import scipy
import robustlib as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'serif'

# %%
"loss vs sample complexity"

il.reload(rl)

trials_rsm1 = 10
d_rsm1, k_rsm1, eps_rsm1 = 10, 4, 0.1
# TODO dimension problem
xs = []

m_bounds_rsm1 = (2, 1000, 100)

# model_rsm1 = rl.TailFlipModel()
model_rsm1 = rl.DenseNoiseModel(2)
keys_rsm1 = [rl.Top_K, rl.Top_K_Filtered, rl.RME_sp, rl.Oracle]
model_params_rsm1 = rl.Params(d=d_rsm1, k=k_rsm1, eps=eps_rsm1)
ylims_rsm1 = (0, 1)

inputfilename_rsm1 = 'data/constant-loss-vs-m.pkl'
plot_m_loss_rsm1 = rl.load_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)
plot_m_loss_rsm1.setdata_tofile(inputfilename_rsm1, 'm', m_bounds_rsm1, trials_rsm1, ylims_rsm1, explicit_xs = False, xs = xs)
# Out:
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# condition 101 101
# Could not filter
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# Linear filter...
# Filtered out 9/301, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# condition 292 292
# Could not filter
# Linear filter...
# Filtered out 10/398, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/388, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/388, 0.0 false (nan vs 0.1)
# condition 388 388
# Could not filter
# Linear filter...
# Filtered out 11/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/490, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/490, 0.0 false (nan vs 0.1)
# condition 490 490
# Could not filter
# Linear filter...
# Filtered out 4/602, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/598, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/598, 0.0 false (nan vs 0.1)
# condition 598 598
# Could not filter
# Linear filter...
# Filtered out 14/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/686, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/686, 0.0 false (nan vs 0.1)
# condition 686 686
# Could not filter
# Linear filter...
# Filtered out 15/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/786, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/786, 0.0 false (nan vs 0.1)
# condition 786 786
# Could not filter
# Linear filter...
# Filtered out 21/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/878, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/878, 0.0 false (nan vs 0.1)
# condition 878 878
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/99, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/99, 0.0 false (nan vs 0.1)
# condition 99 99
# Could not filter
# Linear filter...
# Filtered out 3/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# Linear filter...
# Filtered out 3/300, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# condition 297 297
# Could not filter
# Linear filter...
# Filtered out 11/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/389, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/389, 0.0 false (nan vs 0.1)
# condition 389 389
# Could not filter
# Linear filter...
# Filtered out 10/502, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# condition 492 492
# Could not filter
# Linear filter...
# Filtered out 9/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/590, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/590, 0.0 false (nan vs 0.1)
# condition 590 590
# Could not filter
# Linear filter...
# Filtered out 7/702, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/695, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/695, 0.0 false (nan vs 0.1)
# condition 695 695
# Could not filter
# Linear filter...
# Filtered out 8/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/792, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/792, 0.0 false (nan vs 0.1)
# condition 792 792
# Could not filter
# Linear filter...
# Filtered out 23/900, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/877, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/877, 0.0 false (nan vs 0.1)
# condition 877 877
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 3/101, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# condition 98 98
# Could not filter
# Linear filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/202, 0.0 false (nan vs 0.1)
# condition 202 202
# Could not filter
# Linear filter...
# Filtered out 0/300, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/300, 0.0 false (nan vs 0.1)
# condition 300 300
# Could not filter
# Linear filter...
# Filtered out 11/402, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/391, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/391, 0.0 false (nan vs 0.1)
# condition 391 391
# Could not filter
# Linear filter...
# Filtered out 14/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/487, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/487, 0.0 false (nan vs 0.1)
# condition 487 487
# Could not filter
# Linear filter...
# Filtered out 13/598, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/585, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/585, 0.0 false (nan vs 0.1)
# condition 585 585
# Could not filter
# Linear filter...
# Filtered out 7/699, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# condition 692 692
# Could not filter
# Linear filter...
# Filtered out 23/799, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/776, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/776, 0.0 false (nan vs 0.1)
# condition 776 776
# Could not filter
# Linear filter...
# Filtered out 26/902, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/876, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/876, 0.0 false (nan vs 0.1)
# condition 876 876
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 7/101, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/94, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/94, 0.0 false (nan vs 0.1)
# condition 94 94
# Could not filter
# Linear filter...
# Filtered out 3/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# Linear filter...
# Filtered out 7/301, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# condition 294 294
# Could not filter
# Linear filter...
# Filtered out 9/399, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/390, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/390, 0.0 false (nan vs 0.1)
# condition 390 390
# Could not filter
# Linear filter...
# Filtered out 8/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/492, 0.0 false (nan vs 0.1)
# condition 492 492
# Could not filter
# Linear filter...
# Filtered out 16/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/583, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/583, 0.0 false (nan vs 0.1)
# condition 583 583
# Could not filter
# Linear filter...
# Filtered out 18/701, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/683, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/683, 0.0 false (nan vs 0.1)
# condition 683 683
# Could not filter
# Linear filter...
# Filtered out 12/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/788, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/788, 0.0 false (nan vs 0.1)
# condition 788 788
# Could not filter
# Linear filter...
# Filtered out 29/900, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/871, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/871, 0.0 false (nan vs 0.1)
# condition 871 871
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# condition 101 101
# Could not filter
# Linear filter...
# Filtered out 6/199, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# condition 193 193
# Could not filter
# Linear filter...
# Filtered out 10/300, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/290, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/290, 0.0 false (nan vs 0.1)
# condition 290 290
# Could not filter
# Linear filter...
# Filtered out 11/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/389, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/389, 0.0 false (nan vs 0.1)
# condition 389 389
# Could not filter
# Linear filter...
# Filtered out 7/502, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/495, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/495, 0.0 false (nan vs 0.1)
# condition 495 495
# Could not filter
# Linear filter...
# Filtered out 19/601, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/582, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/582, 0.0 false (nan vs 0.1)
# condition 582 582
# Could not filter
# Linear filter...
# Filtered out 23/701, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/678, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/678, 0.0 false (nan vs 0.1)
# condition 678 678
# Could not filter
# Linear filter...
# Filtered out 19/802, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/783, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/783, 0.0 false (nan vs 0.1)
# condition 783 783
# Could not filter
# Linear filter...
# Filtered out 24/900, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/876, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/876, 0.0 false (nan vs 0.1)
# condition 876 876
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 3/99, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/96, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/96, 0.0 false (nan vs 0.1)
# condition 96 96
# Could not filter
# Linear filter...
# Filtered out 4/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/196, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/196, 0.0 false (nan vs 0.1)
# condition 196 196
# Could not filter
# Linear filter...
# Filtered out 3/302, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/299, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/299, 0.0 false (nan vs 0.1)
# condition 299 299
# Could not filter
# Linear filter...
# Filtered out 8/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# condition 392 392
# Could not filter
# Linear filter...
# Filtered out 13/498, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/485, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/485, 0.0 false (nan vs 0.1)
# condition 485 485
# Could not filter
# Linear filter...
# Filtered out 13/601, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/588, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/588, 0.0 false (nan vs 0.1)
# condition 588 588
# Could not filter
# Linear filter...
# Filtered out 5/701, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/696, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/696, 0.0 false (nan vs 0.1)
# condition 696 696
# Could not filter
# Linear filter...
# Filtered out 12/797, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/785, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/785, 0.0 false (nan vs 0.1)
# condition 785 785
# Could not filter
# Linear filter...
# Filtered out 11/901, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/890, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/890, 0.0 false (nan vs 0.1)
# condition 890 890
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# condition 102 102
# Could not filter
# Linear filter...
# Filtered out 3/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# Linear filter...
# Filtered out 4/301, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# condition 297 297
# Could not filter
# Linear filter...
# Filtered out 13/402, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/389, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/389, 0.0 false (nan vs 0.1)
# condition 389 389
# Could not filter
# Linear filter...
# Filtered out 17/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/484, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/484, 0.0 false (nan vs 0.1)
# condition 484 484
# Could not filter
# Linear filter...
# Filtered out 9/602, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/593, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/593, 0.0 false (nan vs 0.1)
# condition 593 593
# Could not filter
# Linear filter...
# Filtered out 20/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/680, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/680, 0.0 false (nan vs 0.1)
# condition 680 680
# Could not filter
# Linear filter...
# Filtered out 18/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/782, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/782, 0.0 false (nan vs 0.1)
# condition 782 782
# Could not filter
# Linear filter...
# Filtered out 10/901, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/891, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/891, 0.0 false (nan vs 0.1)
# condition 891 891
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# condition 101 101
# Could not filter
# Linear filter...
# Filtered out 5/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/195, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/195, 0.0 false (nan vs 0.1)
# condition 195 195
# Could not filter
# Linear filter...
# Filtered out 5/302, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# condition 297 297
# Could not filter
# Linear filter...
# Filtered out 7/401, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/394, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/394, 0.0 false (nan vs 0.1)
# condition 394 394
# Could not filter
# Linear filter...
# Filtered out 11/497, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/486, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/486, 0.0 false (nan vs 0.1)
# condition 486 486
# Could not filter
# Linear filter...
# Filtered out 19/600, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/581, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/581, 0.0 false (nan vs 0.1)
# condition 581 581
# Could not filter
# Linear filter...
# Filtered out 11/702, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/691, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/691, 0.0 false (nan vs 0.1)
# condition 691 691
# Could not filter
# Linear filter...
# Filtered out 11/802, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/791, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/791, 0.0 false (nan vs 0.1)
# condition 791 791
# Could not filter
# Linear filter...
# Filtered out 19/897, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/878, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/878, 0.0 false (nan vs 0.1)
# condition 878 878
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 2/102, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# condition 100 100
# Could not filter
# Linear filter...
# Filtered out 4/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# Linear filter...
# Filtered out 9/302, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/293, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/293, 0.0 false (nan vs 0.1)
# condition 293 293
# Could not filter
# Linear filter...
# Filtered out 3/401, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/398, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/398, 0.0 false (nan vs 0.1)
# condition 398 398
# Could not filter
# Linear filter...
# Filtered out 0/500, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/500, 0.0 false (nan vs 0.1)
# condition 500 500
# Could not filter
# Linear filter...
# Filtered out 15/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/584, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/584, 0.0 false (nan vs 0.1)
# condition 584 584
# Could not filter
# Linear filter...
# Filtered out 21/702, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/681, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/681, 0.0 false (nan vs 0.1)
# condition 681 681
# Could not filter
# Linear filter...
# Filtered out 26/798, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/772, 0.0 false (nan vs 0.1)
# condition 772 772
# Could not filter
# Linear filter...
# Filtered out 19/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/880, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/880, 0.0 false (nan vs 0.1)
# condition 880 880
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# condition 100 100
# Could not filter
# Linear filter...
# Filtered out 5/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# Linear filter...
# Filtered out 7/301, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# condition 294 294
# Could not filter
# Linear filter...
# Filtered out 10/401, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/391, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/391, 0.0 false (nan vs 0.1)
# condition 391 391
# Could not filter
# Linear filter...
# Filtered out 12/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/488, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/488, 0.0 false (nan vs 0.1)
# condition 488 488
# Could not filter
# Linear filter...
# Filtered out 17/602, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/585, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/585, 0.0 false (nan vs 0.1)
# condition 585 585
# Could not filter
# Linear filter...
# Filtered out 13/697, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/684, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/684, 0.0 false (nan vs 0.1)
# condition 684 684
# Could not filter
# Linear filter...
# Filtered out 23/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/777, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/777, 0.0 false (nan vs 0.1)
# condition 777 777
# Could not filter
# Linear filter...
# Filtered out 23/901, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/878, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/878, 0.0 false (nan vs 0.1)
# condition 878 878
# Could not filter
# runtime: 351.817911708029

# %%
outputfilename_rsm1 = 'self_out/stage2.pdf'

title_rsm1 = 'd = {d}, k = {k}, eps = {eps}. Noise is dense.'.format(d=d_rsm1,k=k_rsm1,eps=eps_rsm1)
xlabel_rsm1 = 'm'
ylabel_rsm1 = 'L2 Loss'
plot_m_loss_rsm1_plt = rl.plot_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)


plot_m_loss_rsm1_plt.plotxy_fromfile(outputfilename_rsm1, inputfilename_rsm1,'m', m_bounds_rsm1, (0, 0.5), title_rsm1, xlabel_rsm1, ylabel_rsm1, figsize = figsize, fontname = fontname, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el69707111461081443884147405"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el69707111461081443884147405", {"width": 800.0, "height": 400.0, "axes": [], "data": {}, "id": "el6970711146108144", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#          mpld3.draw_figure("fig_el69707111461081443884147405", {"width": 800.0, "height": 400.0, "axes": [], "data": {}, "id": "el6970711146108144", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://d3js.org/d3.v5.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#                  mpld3.draw_figure("fig_el69707111461081443884147405", {"width": 800.0, "height": 400.0, "axes": [], "data": {}, "id": "el6970711146108144", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>
