# %%
import numpy as np
import scipy
import robustlib as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'serif'

# %%
"loss vs sample complexity"

il.reload(rl)

trials_rsm1 = 10
d_rsm1, k_rsm1, eps_rsm1 = 10, 1, 0.1
xs = []

m_bounds_rsm1 = (2, 1000, 10)

model_rsm1 = rl.TailFlipModel()
keys_rsm1 = [rl.Top_K, rl.Oracle, rl.RME_sp]
model_params_rsm1 = rl.Params(d=d_rsm1, k=k_rsm1, eps=eps_rsm1)
ylims_rsm1 = (0, 1)

inputfilename_rsm1 = 'data/tflipping-loss-vs-k.pkl'
plot_m_loss_rsm1 = rl.load_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)
plot_m_loss_rsm1.setdata_tofile(inputfilename_rsm1, 'm', m_bounds_rsm1, trials_rsm1, ylims_rsm1, explicit_xs = False, xs = xs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 18
#      16 inputfilename_rsm1 = 'data/tflipping-loss-vs-k.pkl'
#      17 plot_m_loss_rsm1 = rl.load_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)
# ---> 18 plot_m_loss_rsm1.setdata_tofile(inputfilename_rsm1, 'm', m_bounds_rsm1, trials_rsm1, ylims_rsm1, explicit_xs = False, xs = xs)
#
# File ~/Desktop/Random/Algorithm2/robust_sparse_mean_estimation/robustlib.py:916, in load_data.setdata_tofile(self, filename, xvar_name, bounds, trials, ylims, y_is_m, mrange, relative, explicit_xs, xs, medianerr)
#     915 def setdata_tofile(self, filename, xvar_name, bounds, trials, ylims, y_is_m = False, mrange = [], relative=False,  explicit_xs = False, xs = [], medianerr = False):
# --> 916     self.setdata(xvar_name, bounds, trials, ylims, y_is_m, mrange, relative,  explicit_xs, xs, medianerr)
#     917     with open(filename, 'wb') as g:
#     918         pickle.dump(self.Run.runs, g, -1)
#
# File ~/Desktop/Random/Algorithm2/robust_sparse_mean_estimation/robustlib.py:923, in load_data.setdata(self, xvar_name, bounds, trials, ylims, y_is_m, mrange, relative, explicit_xs, xs, medianerr)
#     920 def setdata(self, xvar_name, bounds, trials, ylims, y_is_m = False, mrange = [], relative=False,  explicit_xs = False, xs = [], medianerr = False):
#     922     Runs_l_samples = RunCollection(self.get_dataxy, (xvar_name, bounds, y_is_m, mrange, relative,  explicit_xs, xs, medianerr))
# --> 923     Runs_l_samples.run(trials)
#     924     self.Run = Runs_l_samples
#
# File ~/Desktop/Random/Algorithm2/robust_sparse_mean_estimation/robustlib.py:26, in RunCollection.run(self, trials)
#      24 def run(self, trials):
#      25     for i in range(trials):
# ---> 26         self.runs.append(self.func(*self.inp))
#
# File ~/Desktop/Random/Algorithm2/robust_sparse_mean_estimation/robustlib.py:903, in load_data.get_dataxy(self, xvar_name, bounds, y_is_m, mrange, relative, explicit_xs, xs, medianerr)
#     901             results.setdefault(f.__name__, []).append(self.loss(func.alg(S_copy, indicator_copy), tm)/self.loss(O.alg(S_copy, indicator_copy), tm))
#     902         else:
# --> 903             results.setdefault(f.__name__, []).append(self.loss(func.alg(S_copy, indicator_copy), tm))
#     905 else:
#     906     for f in self.keys:
#
# File ~/Desktop/Random/Algorithm2/robust_sparse_mean_estimation/robustlib.py:705, in Top_K.alg(self, S, indicator)
#     704 def alg(self, S, indicator):
# --> 705     top_indices = self.GD(S)
#     706     S_new = self.trim_data(S, top_indices)
#     707     return S_new
#
# File ~/Desktop/Random/Algorithm2/robust_sparse_mean_estimation/robustlib.py:669, in Top_K.GD(self, S)
#     667 K = m / 3 # number of subgroups
#     668 k = self.params.k
# --> 669 X_grouped = np.split(S, K)
#     670 X_grouped = np.mean(X_grouped, axis=1)
#     672 # gradient descent
#
# File <__array_function__ internals>:180, in split(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/numpy/lib/shape_base.py:872, in split(ary, indices_or_sections, axis)
#     870     N = ary.shape[axis]
#     871     if N % sections:
# --> 872         raise ValueError(
#     873             'array split does not result in an equal division') from None
#     874 return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division

# %%
outputfilename_rsm1 = 'self_out/tflipping-loss-vs-k.pdf'

title_rsm1 = 'd = {d}, k = {k}, eps = {eps}. Noise is tail-flipping.'.format(d=d_rsm1,k=k_rsm1,eps=eps_rsm1)
xlabel_rsm1 = 'm'
ylabel_rsm1 = 'L2 Loss'
plot_m_loss_rsm1_plt = rl.plot_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)


plot_m_loss_rsm1_plt.plotxy_fromfile(outputfilename_rsm1, inputfilename_rsm1,'m', m_bounds_rsm1, (0, 0.8), title_rsm1, xlabel_rsm1, ylabel_rsm1, figsize = figsize, fontname = fontname, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el3909647551625928440444112"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el3909647551625928440444112", {"width": 800.0, "height": 400.0, "axes": [], "data": {}, "id": "el390964755162592", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#          mpld3.draw_figure("fig_el3909647551625928440444112", {"width": 800.0, "height": 400.0, "axes": [], "data": {}, "id": "el390964755162592", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://d3js.org/d3.v5.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.9.js", function(){
#
#                  mpld3.draw_figure("fig_el3909647551625928440444112", {"width": 800.0, "height": 400.0, "axes": [], "data": {}, "id": "el390964755162592", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#             })
#          });
# }
# </script>
