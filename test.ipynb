# %%
import numpy as np
import scipy
import robustlib as rl
import importlib as il
from scipy import special
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

fsize = 20
fpad = 10
figsize = (8,4)
fontname = 'serif'

# %%
"loss vs sample complexity"

il.reload(rl)

trials_rsm1 = 10
d_rsm1, k_rsm1, eps_rsm1 = 10, 4, 0.1
# TODO dimension problem
xs = []

m_bounds_rsm1 = (2, 1000, 100)

# model_rsm1 = rl.TailFlipModel()
model_rsm1 = rl.DenseNoiseModel(2)
keys_rsm1 = [rl.Top_K, rl.Top_K_Filtered, rl.RME_sp, rl.Oracle]
model_params_rsm1 = rl.Params(d=d_rsm1, k=k_rsm1, eps=eps_rsm1)
ylims_rsm1 = (0, 1)

inputfilename_rsm1 = 'data/constant-loss-vs-m.pkl'
plot_m_loss_rsm1 = rl.load_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)
plot_m_loss_rsm1.setdata_tofile(inputfilename_rsm1, 'm', m_bounds_rsm1, trials_rsm1, ylims_rsm1, explicit_xs = False, xs = xs)
# Out:
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# /Users/chenruidemac/Documents/GitHub/Robust_mean_estimation/robustlib.py:307: RuntimeWarning: invalid value encountered in double_scalars
#   f"Filtered out {l - len(idx[0])}/{l}, {bad_filtered} false ({bad_filtered / (l - len(idx[0])):0.2f} vs {self.fdr})")
# /Users/chenruidemac/Documents/GitHub/Robust_mean_estimation/robustlib.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   f"Filtered out {l - len(idx[0])}/{l}, {bad_filtered} false ({bad_filtered / (l - len(idx[0])):0.2f} vs {self.fdr})")
# Linear filter...
# Filtered out 2/100, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# condition 98 98
# Could not filter
# Linear filter...
# Filtered out 4/99, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/95, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/95, 0.0 false (nan vs 0.1)
# condition 95 95
# Could not filter
# Linear filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/201, 0.0 false (nan vs 0.1)
# condition 201 201
# Could not filter
# Linear filter...
# Filtered out 3/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# Linear filter...
# Filtered out 4/302, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/298, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/298, 0.0 false (nan vs 0.1)
# condition 298 298
# Could not filter
# Linear filter...
# Filtered out 8/302, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# condition 294 294
# Could not filter
# Linear filter...
# Filtered out 11/399, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/388, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/388, 0.0 false (nan vs 0.1)
# condition 388 388
# Could not filter
# Linear filter...
# Filtered out 11/397, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 5/386, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/381, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/381, 0.0 false (nan vs 0.1)
# condition 381 381
# Could not filter
# Linear filter...
# Filtered out 4/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/497, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/497, 0.0 false (nan vs 0.1)
# condition 497 497
# Could not filter
# Linear filter...
# Filtered out 10/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 4/491, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/487, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/487, 0.0 false (nan vs 0.1)
# condition 487 487
# Could not filter
# Linear filter...
# Filtered out 11/598, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/587, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/587, 0.0 false (nan vs 0.1)
# condition 587 587
# Could not filter
# Linear filter...
# Filtered out 19/596, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 8/577, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/569, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/569, 0.0 false (nan vs 0.1)
# condition 569 569
# Could not filter
# Linear filter...
# Filtered out 17/701, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/684, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/684, 0.0 false (nan vs 0.1)
# condition 684 684
# Could not filter
# Linear filter...
# Filtered out 16/701, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 13/685, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# condition 672 672
# Could not filter
# Linear filter...
# Filtered out 32/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/769, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/769, 0.0 false (nan vs 0.1)
# condition 769 769
# Could not filter
# Linear filter...
# Filtered out 21/798, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 17/777, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/760, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/760, 0.0 false (nan vs 0.1)
# condition 760 760
# Could not filter
# Linear filter...
# Filtered out 24/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/875, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/875, 0.0 false (nan vs 0.1)
# condition 875 875
# Could not filter
# Linear filter...
# Filtered out 26/896, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 9/870, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/861, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/861, 0.0 false (nan vs 0.1)
# condition 861 861
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# condition 101 101
# Could not filter
# Linear filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# condition 101 101
# Could not filter
# Linear filter...
# Filtered out 4/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# Linear filter...
# Filtered out 5/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/196, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/196, 0.0 false (nan vs 0.1)
# condition 196 196
# Could not filter
# Linear filter...
# Filtered out 8/301, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/293, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/293, 0.0 false (nan vs 0.1)
# condition 293 293
# Could not filter
# Linear filter...
# Filtered out 6/301, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/295, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/295, 0.0 false (nan vs 0.1)
# condition 295 295
# Could not filter
# Linear filter...
# Filtered out 15/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/385, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/385, 0.0 false (nan vs 0.1)
# condition 385 385
# Could not filter
# Linear filter...
# Filtered out 18/398, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 9/380, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 2/371, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/369, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/369, 0.0 false (nan vs 0.1)
# condition 369 369
# Could not filter
# Linear filter...
# Filtered out 11/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/490, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/490, 0.0 false (nan vs 0.1)
# condition 490 490
# Could not filter
# Linear filter...
# Filtered out 16/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 8/484, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 8/476, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/468, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/468, 0.0 false (nan vs 0.1)
# condition 468 468
# Could not filter
# Linear filter...
# Filtered out 20/601, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/581, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/581, 0.0 false (nan vs 0.1)
# condition 581 581
# Could not filter
# Linear filter...
# Filtered out 19/600, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 8/581, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 7/573, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/566, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/566, 0.0 false (nan vs 0.1)
# condition 566 566
# Could not filter
# Linear filter...
# Filtered out 29/699, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/670, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/670, 0.0 false (nan vs 0.1)
# condition 670 670
# Could not filter
# Linear filter...
# Filtered out 25/699, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/674, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/674, 0.0 false (nan vs 0.1)
# condition 674 674
# Could not filter
# Linear filter...
# Filtered out 16/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/785, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/785, 0.0 false (nan vs 0.1)
# condition 785 785
# Could not filter
# Linear filter...
# Filtered out 14/799, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 5/785, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/780, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/780, 0.0 false (nan vs 0.1)
# condition 780 780
# Could not filter
# Linear filter...
# Filtered out 18/902, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/884, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/884, 0.0 false (nan vs 0.1)
# condition 884 884
# Could not filter
# Linear filter...
# Filtered out 28/901, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 13/873, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/860, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/860, 0.0 false (nan vs 0.1)
# condition 860 860
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 4/101, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/97, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/97, 0.0 false (nan vs 0.1)
# condition 97 97
# Could not filter
# Linear filter...
# Filtered out 3/101, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# condition 98 98
# Could not filter
# Linear filter...
# Filtered out 10/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/191, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/191, 0.0 false (nan vs 0.1)
# condition 191 191
# Could not filter
# Linear filter...
# Filtered out 7/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/195, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/195, 0.0 false (nan vs 0.1)
# condition 195 195
# Could not filter
# Linear filter...
# Filtered out 0/302, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/302, 0.0 false (nan vs 0.1)
# condition 302 302
# Could not filter
# Linear filter...
# Filtered out 11/300, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/289, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/286, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/286, 0.0 false (nan vs 0.1)
# condition 286 286
# Could not filter
# Linear filter...
# Filtered out 17/401, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/384, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/384, 0.0 false (nan vs 0.1)
# condition 384 384
# Could not filter
# Linear filter...
# Filtered out 9/397, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 5/388, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/383, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/383, 0.0 false (nan vs 0.1)
# condition 383 383
# Could not filter
# Linear filter...
# Filtered out 9/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/491, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/491, 0.0 false (nan vs 0.1)
# condition 491 491
# Could not filter
# Linear filter...
# Filtered out 25/498, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/473, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/473, 0.0 false (nan vs 0.1)
# condition 473 473
# Could not filter
# Linear filter...
# Filtered out 10/601, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/591, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/591, 0.0 false (nan vs 0.1)
# condition 591 591
# Could not filter
# Linear filter...
# Filtered out 14/601, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 17/587, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 2/570, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/568, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/568, 0.0 false (nan vs 0.1)
# condition 568 568
# Could not filter
# Linear filter...
# Filtered out 23/701, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/678, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/678, 0.0 false (nan vs 0.1)
# condition 678 678
# Could not filter
# Linear filter...
# Filtered out 19/699, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 8/680, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# condition 672 672
# Could not filter
# Linear filter...
# Filtered out 15/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/785, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/785, 0.0 false (nan vs 0.1)
# condition 785 785
# Could not filter
# Linear filter...
# Filtered out 29/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 15/772, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/757, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/757, 0.0 false (nan vs 0.1)
# condition 757 757
# Could not filter
# Linear filter...
# Filtered out 26/900, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/874, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/874, 0.0 false (nan vs 0.1)
# condition 874 874
# Could not filter
# Linear filter...
# Filtered out 23/898, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 18/875, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/857, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/857, 0.0 false (nan vs 0.1)
# condition 857 857
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 2/101, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/99, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/99, 0.0 false (nan vs 0.1)
# condition 99 99
# Could not filter
# Linear filter...
# Filtered out 3/102, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/99, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/99, 0.0 false (nan vs 0.1)
# condition 99 99
# Could not filter
# Linear filter...
# Filtered out 3/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# Linear filter...
# Filtered out 8/201, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# condition 193 193
# Could not filter
# Linear filter...
# Filtered out 5/300, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/295, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/295, 0.0 false (nan vs 0.1)
# condition 295 295
# Could not filter
# Linear filter...
# Filtered out 6/302, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 4/296, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# condition 292 292
# Could not filter
# Linear filter...
# Filtered out 8/398, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/390, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/390, 0.0 false (nan vs 0.1)
# condition 390 390
# Could not filter
# Linear filter...
# Filtered out 8/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 4/392, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 2/388, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/386, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/386, 0.0 false (nan vs 0.1)
# condition 386 386
# Could not filter
# Linear filter...
# Filtered out 8/498, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/490, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/490, 0.0 false (nan vs 0.1)
# condition 490 490
# Could not filter
# Linear filter...
# Filtered out 12/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 8/488, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/480, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/480, 0.0 false (nan vs 0.1)
# condition 480 480
# Could not filter
# Linear filter...
# Filtered out 11/600, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/589, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/589, 0.0 false (nan vs 0.1)
# condition 589 589
# Could not filter
# Linear filter...
# Filtered out 23/602, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 8/579, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/571, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/571, 0.0 false (nan vs 0.1)
# condition 571 571
# Could not filter
# Linear filter...
# Filtered out 9/701, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# condition 692 692
# Could not filter
# Linear filter...
# Filtered out 24/702, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 7/678, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/671, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 3/671, 0.0 false (0.00 vs 0.1)
# condition 668 671
# Linear filter...
# Filtered out 0/668, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/668, 0.0 false (nan vs 0.1)
# condition 668 668
# Could not filter
# Linear filter...
# Filtered out 16/799, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/783, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/783, 0.0 false (nan vs 0.1)
# condition 783 783
# Could not filter
# Linear filter...
# Filtered out 15/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 16/786, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/770, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/770, 0.0 false (nan vs 0.1)
# condition 770 770
# Could not filter
# Linear filter...
# Filtered out 17/902, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/885, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/885, 0.0 false (nan vs 0.1)
# condition 885 885
# Could not filter
# Linear filter...
# Filtered out 19/897, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 8/878, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/870, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/870, 0.0 false (nan vs 0.1)
# condition 870 870
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# condition 100 100
# Could not filter
# Linear filter...
# Filtered out 2/100, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# condition 98 98
# Could not filter
# Linear filter...
# Filtered out 5/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# Linear filter...
# Filtered out 5/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 6/197, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 2/191, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/189, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/189, 0.0 false (nan vs 0.1)
# condition 189 189
# Could not filter
# Linear filter...
# Filtered out 8/299, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/291, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/291, 0.0 false (nan vs 0.1)
# condition 291 291
# Could not filter
# Linear filter...
# Filtered out 6/299, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 9/293, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/284, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/284, 0.0 false (nan vs 0.1)
# condition 284 284
# Could not filter
# Linear filter...
# Filtered out 14/401, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/387, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/387, 0.0 false (nan vs 0.1)
# condition 387 387
# Could not filter
# Linear filter...
# Filtered out 12/401, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 6/389, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/383, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/380, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/380, 0.0 false (nan vs 0.1)
# condition 380 380
# Could not filter
# Linear filter...
# Filtered out 14/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/487, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/487, 0.0 false (nan vs 0.1)
# condition 487 487
# Could not filter
# Linear filter...
# Filtered out 15/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 9/485, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/476, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/476, 0.0 false (nan vs 0.1)
# condition 476 476
# Could not filter
# Linear filter...
# Filtered out 0/600, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/600, 0.0 false (nan vs 0.1)
# condition 600 600
# Could not filter
# Linear filter...
# Filtered out 8/600, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/592, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 4/592, 0.0 false (0.00 vs 0.1)
# condition 588 592
# Linear filter...
# Filtered out 0/588, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/588, 0.0 false (nan vs 0.1)
# condition 588 588
# Could not filter
# Linear filter...
# Filtered out 0/700, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/700, 0.0 false (nan vs 0.1)
# condition 700 700
# Could not filter
# Linear filter...
# Filtered out 15/701, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 11/686, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 6/675, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/669, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/669, 0.0 false (nan vs 0.1)
# condition 669 669
# Could not filter
# Linear filter...
# Filtered out 23/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/777, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/777, 0.0 false (nan vs 0.1)
# condition 777 777
# Could not filter
# Linear filter...
# Filtered out 26/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 10/775, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/765, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/765, 0.0 false (nan vs 0.1)
# condition 765 765
# Could not filter
# Linear filter...
# Filtered out 23/898, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/875, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/875, 0.0 false (nan vs 0.1)
# condition 875 875
# Could not filter
# Linear filter...
# Filtered out 23/897, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 9/874, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 14/865, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/851, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/851, 0.0 false (nan vs 0.1)
# condition 851 851
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# condition 101 101
# Could not filter
# Linear filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/102, 0.0 false (nan vs 0.1)
# condition 102 102
# Could not filter
# Linear filter...
# Filtered out 3/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# Linear filter...
# Filtered out 4/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# Linear filter...
# Filtered out 0/299, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/299, 0.0 false (nan vs 0.1)
# condition 299 299
# Could not filter
# Linear filter...
# Filtered out 2/299, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# condition 297 297
# Could not filter
# Linear filter...
# Filtered out 8/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/392, 0.0 false (nan vs 0.1)
# condition 392 392
# Could not filter
# Linear filter...
# Filtered out 12/399, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/387, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/387, 0.0 false (nan vs 0.1)
# condition 387 387
# Could not filter
# Linear filter...
# Filtered out 9/502, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/493, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/493, 0.0 false (nan vs 0.1)
# condition 493 493
# Could not filter
# Linear filter...
# Filtered out 11/500, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/489, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/489, 0.0 false (nan vs 0.1)
# condition 489 489
# Could not filter
# Linear filter...
# Filtered out 9/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/590, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/590, 0.0 false (nan vs 0.1)
# condition 590 590
# Could not filter
# Linear filter...
# Filtered out 20/599, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 5/579, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/574, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/574, 0.0 false (nan vs 0.1)
# condition 574 574
# Could not filter
# Linear filter...
# Filtered out 23/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/677, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/677, 0.0 false (nan vs 0.1)
# condition 677 677
# Could not filter
# Linear filter...
# Filtered out 17/699, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 7/682, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 11/675, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 4/664, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/660, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/660, 0.0 false (nan vs 0.1)
# condition 660 660
# Could not filter
# Linear filter...
# Filtered out 32/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/769, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/769, 0.0 false (nan vs 0.1)
# condition 769 769
# Could not filter
# Linear filter...
# Filtered out 31/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 10/769, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/759, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/759, 0.0 false (nan vs 0.1)
# condition 759 759
# Could not filter
# Linear filter...
# Filtered out 10/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/889, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/889, 0.0 false (nan vs 0.1)
# condition 889 889
# Could not filter
# Linear filter...
# Filtered out 30/897, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 10/867, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/857, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/857, 0.0 false (nan vs 0.1)
# condition 857 857
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 3/101, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# condition 98 98
# Could not filter
# Linear filter...
# Filtered out 2/102, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 4/100, 0.0 false (0.00 vs 0.1)
# condition 96 100
# Linear filter...
# Filtered out 0/96, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/96, 0.0 false (nan vs 0.1)
# condition 96 96
# Could not filter
# Linear filter...
# Filtered out 7/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/195, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/195, 0.0 false (nan vs 0.1)
# condition 195 195
# Could not filter
# Linear filter...
# Filtered out 7/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/193, 0.0 false (nan vs 0.1)
# condition 193 193
# Could not filter
# Linear filter...
# Filtered out 0/301, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/301, 0.0 false (nan vs 0.1)
# condition 301 301
# Could not filter
# Linear filter...
# Filtered out 11/301, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 4/290, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/286, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/286, 0.0 false (nan vs 0.1)
# condition 286 286
# Could not filter
# Linear filter...
# Filtered out 9/402, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/393, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/393, 0.0 false (nan vs 0.1)
# condition 393 393
# Could not filter
# Linear filter...
# Filtered out 16/401, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 9/385, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/376, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/376, 0.0 false (nan vs 0.1)
# condition 376 376
# Could not filter
# Linear filter...
# Filtered out 9/502, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/493, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/493, 0.0 false (nan vs 0.1)
# condition 493 493
# Could not filter
# Linear filter...
# Filtered out 19/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 9/482, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/473, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/473, 0.0 false (nan vs 0.1)
# condition 473 473
# Could not filter
# Linear filter...
# Filtered out 8/601, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/593, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/593, 0.0 false (nan vs 0.1)
# condition 593 593
# Could not filter
# Linear filter...
# Filtered out 9/600, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 15/591, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/576, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/576, 0.0 false (nan vs 0.1)
# condition 576 576
# Could not filter
# Linear filter...
# Filtered out 27/699, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/672, 0.0 false (nan vs 0.1)
# condition 672 672
# Could not filter
# Linear filter...
# Filtered out 24/698, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 14/674, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/660, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/660, 0.0 false (nan vs 0.1)
# condition 660 660
# Could not filter
# Linear filter...
# Filtered out 12/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/789, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/789, 0.0 false (nan vs 0.1)
# condition 789 789
# Could not filter
# Linear filter...
# Filtered out 22/800, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 8/778, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/770, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/770, 0.0 false (nan vs 0.1)
# condition 770 770
# Could not filter
# Linear filter...
# Filtered out 10/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/889, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/889, 0.0 false (nan vs 0.1)
# condition 889 889
# Could not filter
# Linear filter...
# Filtered out 12/900, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 5/888, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/883, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/883, 0.0 false (nan vs 0.1)
# condition 883 883
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 3/101, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# condition 98 98
# Could not filter
# Linear filter...
# Filtered out 8/102, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/94, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/94, 0.0 false (nan vs 0.1)
# condition 94 94
# Could not filter
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# Linear filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/199, 0.0 false (nan vs 0.1)
# condition 199 199
# Could not filter
# Linear filter...
# Filtered out 3/300, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/297, 0.0 false (nan vs 0.1)
# condition 297 297
# Could not filter
# Linear filter...
# Filtered out 6/300, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/294, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 4/294, 0.0 false (0.00 vs 0.1)
# condition 290 294
# Linear filter...
# Filtered out 3/290, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/287, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/284, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/284, 0.0 false (nan vs 0.1)
# condition 284 284
# Could not filter
# Linear filter...
# Filtered out 0/402, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/402, 0.0 false (nan vs 0.1)
# condition 402 402
# Could not filter
# Linear filter...
# Filtered out 9/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/391, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/391, 0.0 false (nan vs 0.1)
# condition 391 391
# Could not filter
# Linear filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# condition 502 502
# Could not filter
# Linear filter...
# Filtered out 5/499, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/494, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/494, 0.0 false (nan vs 0.1)
# condition 494 494
# Could not filter
# Linear filter...
# Filtered out 13/601, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/588, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/588, 0.0 false (nan vs 0.1)
# condition 588 588
# Could not filter
# Linear filter...
# Filtered out 25/601, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 5/576, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/571, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/571, 0.0 false (nan vs 0.1)
# condition 571 571
# Could not filter
# Linear filter...
# Filtered out 11/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/689, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/689, 0.0 false (nan vs 0.1)
# condition 689 689
# Could not filter
# Linear filter...
# Filtered out 23/699, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 18/676, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/658, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/658, 0.0 false (nan vs 0.1)
# condition 658 658
# Could not filter
# Linear filter...
# Filtered out 12/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/789, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/789, 0.0 false (nan vs 0.1)
# condition 789 789
# Could not filter
# Linear filter...
# Filtered out 22/799, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 13/777, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/764, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/764, 0.0 false (nan vs 0.1)
# condition 764 764
# Could not filter
# Linear filter...
# Filtered out 19/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/880, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/880, 0.0 false (nan vs 0.1)
# condition 880 880
# Could not filter
# Linear filter...
# Filtered out 25/899, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 23/874, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 5/851, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/846, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/846, 0.0 false (nan vs 0.1)
# condition 846 846
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/100, 0.0 false (nan vs 0.1)
# condition 100 100
# Could not filter
# Linear filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/98, 0.0 false (nan vs 0.1)
# condition 98 98
# Could not filter
# Linear filter...
# Filtered out 2/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/198, 0.0 false (nan vs 0.1)
# condition 198 198
# Could not filter
# Linear filter...
# Filtered out 5/199, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 4/194, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/190, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/190, 0.0 false (nan vs 0.1)
# condition 190 190
# Could not filter
# Linear filter...
# Filtered out 7/299, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/292, 0.0 false (nan vs 0.1)
# condition 292 292
# Could not filter
# Linear filter...
# Filtered out 14/302, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/288, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/285, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/285, 0.0 false (nan vs 0.1)
# condition 285 285
# Could not filter
# Linear filter...
# Filtered out 0/397, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/397, 0.0 false (nan vs 0.1)
# condition 397 397
# Could not filter
# Linear filter...
# Filtered out 11/396, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/385, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/385, 0.0 false (nan vs 0.1)
# condition 385 385
# Could not filter
# Linear filter...
# Filtered out 10/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/491, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/491, 0.0 false (nan vs 0.1)
# condition 491 491
# Could not filter
# Linear filter...
# Filtered out 19/501, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 4/482, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/478, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 2/478, 0.0 false (0.00 vs 0.1)
# condition 476 478
# Linear filter...
# Filtered out 0/476, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/476, 0.0 false (nan vs 0.1)
# condition 476 476
# Could not filter
# Linear filter...
# Filtered out 15/602, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/587, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/587, 0.0 false (nan vs 0.1)
# condition 587 587
# Could not filter
# Linear filter...
# Filtered out 11/600, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/589, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 2/589, 0.0 false (0.00 vs 0.1)
# condition 587 589
# Linear filter...
# Filtered out 0/587, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/587, 0.0 false (nan vs 0.1)
# condition 587 587
# Could not filter
# Linear filter...
# Filtered out 23/701, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/678, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/678, 0.0 false (nan vs 0.1)
# condition 678 678
# Could not filter
# Linear filter...
# Filtered out 18/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 10/682, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/672, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/669, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/669, 0.0 false (nan vs 0.1)
# condition 669 669
# Could not filter
# Linear filter...
# Filtered out 18/798, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/780, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/780, 0.0 false (nan vs 0.1)
# condition 780 780
# Could not filter
# Linear filter...
# Filtered out 23/797, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 9/774, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 4/765, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/761, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/761, 0.0 false (nan vs 0.1)
# condition 761 761
# Could not filter
# Linear filter...
# Filtered out 18/900, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/882, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/882, 0.0 false (nan vs 0.1)
# condition 882 882
# Could not filter
# Linear filter...
# Filtered out 19/900, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/881, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/881, 0.0 false (nan vs 0.1)
# condition 881 881
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/2, 0.0 false (nan vs 0.1)
# condition 2 2
# Could not filter
# Linear filter...
# Filtered out 2/101, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/99, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/99, 0.0 false (nan vs 0.1)
# condition 99 99
# Could not filter
# Linear filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/101, 0.0 false (nan vs 0.1)
# condition 101 101
# Could not filter
# Linear filter...
# Filtered out 3/200, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# Linear filter...
# Filtered out 5/202, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/197, 0.0 false (nan vs 0.1)
# condition 197 197
# Could not filter
# Linear filter...
# Filtered out 16/302, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/286, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/286, 0.0 false (nan vs 0.1)
# condition 286 286
# Could not filter
# Linear filter...
# Filtered out 11/300, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/289, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 3/286, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/283, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/283, 0.0 false (nan vs 0.1)
# condition 283 283
# Could not filter
# Linear filter...
# Filtered out 13/400, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/387, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/387, 0.0 false (nan vs 0.1)
# condition 387 387
# Could not filter
# Linear filter...
# Filtered out 7/401, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 7/394, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/387, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/387, 0.0 false (nan vs 0.1)
# condition 387 387
# Could not filter
# Linear filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/502, 0.0 false (nan vs 0.1)
# condition 502 502
# Could not filter
# Linear filter...
# Filtered out 10/499, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 4/489, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/485, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/485, 0.0 false (nan vs 0.1)
# condition 485 485
# Could not filter
# Linear filter...
# Filtered out 19/600, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/581, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/581, 0.0 false (nan vs 0.1)
# condition 581 581
# Could not filter
# Linear filter...
# Filtered out 20/600, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 15/580, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/565, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/565, 0.0 false (nan vs 0.1)
# condition 565 565
# Could not filter
# Linear filter...
# Filtered out 8/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/692, 0.0 false (nan vs 0.1)
# condition 692 692
# Could not filter
# Linear filter...
# Filtered out 17/700, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/683, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/683, 0.0 false (nan vs 0.1)
# condition 683 683
# Could not filter
# Linear filter...
# Filtered out 22/799, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/777, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/777, 0.0 false (nan vs 0.1)
# condition 777 777
# Could not filter
# Linear filter...
# Filtered out 12/801, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 16/789, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 11/773, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/762, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/762, 0.0 false (nan vs 0.1)
# condition 762 762
# Could not filter
# Linear filter...
# Filtered out 19/902, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/883, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/883, 0.0 false (nan vs 0.1)
# condition 883 883
# Could not filter
# Linear filter...
# Filtered out 22/901, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 7/879, 0.0 false (0.00 vs 0.1)
# Linear filter...
# Filtered out 0/872, 0.0 false (nan vs 0.1)
# Quadratic filter...
# Filtered out 0/872, 0.0 false (nan vs 0.1)
# condition 872 872
# Could not filter
# runtime: 482.001976292

# %%
outputfilename_rsm1 = 'self_out/stage2.pdf'

title_rsm1 = 'd = {d}, k = {k}, eps = {eps}. Noise is dense.'.format(d=d_rsm1,k=k_rsm1,eps=eps_rsm1)
xlabel_rsm1 = 'm'
ylabel_rsm1 = 'L2 Loss'
plot_m_loss_rsm1_plt = rl.plot_data(model_rsm1, model_params_rsm1, rl.err, keys_rsm1)


plot_m_loss_rsm1_plt.plotxy_fromfile(outputfilename_rsm1, inputfilename_rsm1,'m', m_bounds_rsm1, (0, 0.5), title_rsm1, xlabel_rsm1, ylabel_rsm1, figsize = figsize, fontname = fontname, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-21c6b307f36b> in <module>
#       7
#       8
# ----> 9 plot_m_loss_rsm1_plt.plotxy_fromfile(outputfilename_rsm1, inputfilename_rsm1,'m', m_bounds_rsm1, (0, 0.5), title_rsm1, xlabel_rsm1, ylabel_rsm1, figsize = figsize, fontname = fontname, fsize = fsize, fpad = fpad, explicit_xs = False, xs = xs)
#
# ~/Documents/GitHub/Robust_mean_estimation/robustlib.py in plotxy_fromfile(self, outputfilename, filename, xvar_name, bounds, ylims, title, xlabel, ylabel, figsize, fsize, fpad, relative, explicit_xs, xs, fontname)
#    1100     def plotxy_fromfile(self, outputfilename, filename, xvar_name, bounds, ylims, title, xlabel, ylabel, figsize=(1, 1), fsize=10, fpad=10, relative=False,  explicit_xs=False, xs=[], fontname='Arial'):
#    1101
# -> 1102         self.plot_xloss_fromfile(outputfilename, filename, xvar_name, bounds, title, xlabel, ylabel, ylims, figsize=figsize,
#    1103                                  fsize=fsize, fpad=fpad, relative=relative, explicit_xs=explicit_xs, xs=xs, fontname=fontname)
#    1104         plt.figure()
#
# ~/Documents/GitHub/Robust_mean_estimation/robustlib.py in plot_xloss_fromfile(self, outputfilename, filename, xvar_name, bounds, title, xlabel, ylabel, ylims, y_is_m, relative, explicit_xs, xs, fsize, fpad, figsize, fontname)
#    1095     def plot_xloss_fromfile(self, outputfilename, filename, xvar_name, bounds, title, xlabel, ylabel, ylims, y_is_m=False, relative=False, explicit_xs=False, xs=[], fsize=10, fpad=10, figsize=(1, 1), fontname='Arial'):
#    1096         Run = self.readdata(filename)
# -> 1097         self.plot_xloss(outputfilename, Run, xvar_name, bounds, title, xlabel, ylabel,
#    1098                         ylims, y_is_m, relative, explicit_xs, xs, fsize, fpad, figsize, fontname)
#    1099
#
# ~/Documents/GitHub/Robust_mean_estimation/robustlib.py in plot_xloss(self, outputfilename, runs, xvar_name, bounds, title, xlabel, ylabel, ylims, y_is_m, relative, explicit_xs, xs, fsize, fpad, figsize, fontname)
#    1090         plt.legend()
#    1091         plt.ylim(*ylims)
# -> 1092         plt.savefig(outputfilename, bbox_inches='tight')
#    1093         plt.tight_layout()
#    1094
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2584             file = filename._file
#    2585         else:
# -> 2586             file = PdfFile(filename, metadata=metadata)
#    2587         try:
#    2588             file.newPage(width, height)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     560         self.original_file_like = None
#     561         self.tell_base = 0
# --> 562         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     563         if not opened:
#     564             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     406             fh = bz2.BZ2File(fname, flag)
#     407         else:
# --> 408             fh = open(fname, flag, encoding=encoding)
#     409         opened = True
#     410     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'self_out/stage2.pdf'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/lib/python3.8/site-packages/mpld3/_display.py in <lambda>(fig, kwds)
#     408     formatter = ip.display_formatter.formatters['text/html']
#     409     formatter.for_type(Figure,
# --> 410                        lambda fig, kwds=kwargs: fig_to_html(fig, **kwds))
#     411
#     412
#
# ~/.local/lib/python3.8/site-packages/mpld3/_display.py in fig_to_html(fig, d3_url, mpld3_url, no_extras, template_type, figid, use_http, **kwargs)
#     238
#     239     renderer = MPLD3Renderer()
# --> 240     Exporter(renderer, close_mpl=False, **kwargs).run(fig)
#     241
#     242     fig, figure_json, extra_css, extra_js = renderer.finished_figures[0]
#
# ~/.local/lib/python3.8/site-packages/mpld3/mplexporter/exporter.py in run(self, fig)
#      49             import matplotlib.pyplot as plt
#      50             plt.close(fig)
# ---> 51         self.crawl_fig(fig)
#      52
#      53     @staticmethod
#
# ~/.local/lib/python3.8/site-packages/mpld3/mplexporter/exporter.py in crawl_fig(self, fig)
#     116                                        props=utils.get_figure_properties(fig)):
#     117             for ax in fig.axes:
# --> 118                 self.crawl_ax(ax)
#     119
#     120     def crawl_ax(self, ax):
#
# ~/.local/lib/python3.8/site-packages/mpld3/mplexporter/exporter.py in crawl_ax(self, ax)
#     121         """Crawl the axes and process all elements within"""
#     122         with self.renderer.draw_axes(ax=ax,
# --> 123                                      props=utils.get_axes_properties(ax)):
#     124             for line in ax.lines:
#     125                 self.draw_line(ax, line)
#
# ~/.local/lib/python3.8/site-packages/mpld3/mplexporter/utils.py in get_axes_properties(ax)
#     266              'frame_on': ax.get_frame_on(),
#     267              'patch_visible':ax.patch.get_visible(),
# --> 268              'axes': [get_axis_properties(ax.xaxis),
#     269                       get_axis_properties(ax.yaxis)]}
#     270
#
# ~/.local/lib/python3.8/site-packages/mpld3/mplexporter/utils.py in get_axis_properties(axis)
#     230
#     231     # Get associated grid
# --> 232     props['grid'] = get_grid_style(axis)
#     233
#     234     # get axis visibility
#
# ~/.local/lib/python3.8/site-packages/mpld3/mplexporter/utils.py in get_grid_style(axis)
#     240 def get_grid_style(axis):
#     241     gridlines = axis.get_gridlines()
# --> 242     if axis._gridOnMajor and len(gridlines) > 0:
#     243         color = color_to_hex(gridlines[0].get_color())
#     244         alpha = gridlines[0].get_alpha()
#
# AttributeError: 'XAxis' object has no attribute '_gridOnMajor'
